# %%
import pandas as pd
import numpy as np

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

import os

# %%
user = os.environ['USERNAME']
datafolder = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/original_data/".format(user)
file = 'Debitoren_active_gesamt_14092018_incl_DUNS.xlsx'
df = pd.read_excel(datafolder+file)

# %%
df.shape
# Out:
# (6500, 18)

# %%
dfs = []
for i in range(df.shape[0]//10, df.shape[0]+1, df.shape[0]//10):
    if i==650:
        start=0
    else:
        start=end
    end=i
    dfs.append(df.iloc[start:end])

# %%
dfs[-1]
# Out:
#        Kunden Id  K-Debitoren Id Debitoren Id  \
# 5850     2004049            9381       490025
# 5851  che2004026            9382           85
# 5852        IF01            5501  0297-106659
# 5853  che2004026            9383           31
# 5854     2004047            9389        10851
# 5855     2004049            9390       490026
# 5856     2004073            9391            3
# 5857     2004073            9392            4
# 5858     2004050            9393          613
# 5859  che2004024            9399      2857191
# 5860     2004069            9400            7
# 5861     2004034            9409       340022
# 5862     2004052            9410        11936
# 5863        IF01            5841  0322-100006
# 5864        IF01            5841  0279-100006
# 5865  che2004023            9419       230011
# 5866     2004034            9420       340023
# 5867     2004027            9429           26
# 5868     2004078            9439       100017
# 5869     2004036            9439         1733
# 5870     2004036            9440         1735
# 5871        IF01            6139  0289-582766
# 5872     2004078            9440       100015
# 5873     2004036            9441         1740
# 5874     2004036            9442         1738
# 5875     2004036            9443         1742
# 5876     2004022            9444        36827
# 5877     2004067            9444        36827
# 5878     2004067            9445        62332
# 5879     2004056            9449           94
# ...          ...             ...          ...
# 6470  che2004039           10814      2169513
# 6471  che2004038           10815        59322
# 6472  che2004038           10816     44152703
# 6473     2004078           10817       101765
# 6474     2004050           10818          499
# 6475        IF01            6860  0284-110073
# 6476     2004050           10819         7065
# 6477     2004034           10823       340028
# 6478     2004082           10824      2004542
# 6479        IF01            5380     0301-598
# 6480     2004082           10825      1517205
# 6481     2004090           10826      1462680
# 6482     2004090           10827      2004793
# 6483     2004047           10828        11005
# 6484        IF01            5771    0285-9117
# 6485     2004052           10829         9632
# 6486     2004062           10833           49
# 6487        IF01            6370      0304-53
# 6488        IF01            5504  0297-106656
# 6489     2004090           10843      2004581
# 6490     2004090           10844      1288591
# 6491     2004090           10845     11801310
# 6492     2004090           10845      1526647
# 6493     2004090           10846      1723780
# 6494        IF01            5573  0297-106557
# 6495     2004090           10847      1818313
# 6496     2004071           10848           14
# 6497     2004083           10853           28
# 6498     2004078           10863       101838
# 6499     2004054           10873          391
#
#                          Debitorenname 1  DUNS  UID Namenszusatz  \
# 5850         Migros-Genossenschafts-Bund   NaN  NaN          NaN
# 5851                      INTERMETAL SRL   NaN  NaN          NaN
# 5852                      Tell Klinik AG   NaN  NaN          NaN
# 5853                       KRONOSTAHL SA   NaN  NaN          NaN
# 5854                           Findea AG   NaN  NaN          NaN
# 5855                         Trivadis AG   NaN  NaN          NaN
# 5856    Karlen Maçonnerie Génie-civil SA   NaN  NaN          NaN
# 5857                  Laurent Membrez SA   NaN  NaN          NaN
# 5858                           Wernli AG   NaN  NaN          NaN
# 6482                   CH-2732 Loveresse; Le Presson 10  Schweizer Franken
# 6483                 CH-8003 Zürich; Rotacherstrasse 18  Schweizer Franken
# 6484                   CH-8044 Zürich; Keltenstrasse 48  Schweizer Franken
# 6485                CH-8308 Illnau; Bisikonerstrasse 32  Schweizer Franken
# 6486                  CH-7130 Ilanz; via S. Clau Sura 2  Schweizer Franken
# 6487                CH-8804 Au ZH; Steinacherstrasse 15  Schweizer Franken
# 6488             CH-8047 Zürich; Albisriederstrasse 358  Schweizer Franken
# 6489                  CH-4624 Härkingen; Gunzgerstr.  2  Schweizer Franken
# 6490                  CH-6056 Kägiswil; Kreuzstrasse 33  Schweizer Franken
# 6491                    CH-6370 Stans; Breitstrasse 106  Schweizer Franken
# 6492                    CH-6370 Stans; Breitstrasse 106  Schweizer Franken
# 6493              CH-1762 Givisiez; Route des Fluides 3  Schweizer Franken
# 6494                    CH-8127 Forch; Forchstrasse 111  Schweizer Franken
# 6495                    CH-6430 Schwyz; Grundstrasse 10  Schweizer Franken
# 6496              CH-5312 Döttingen; Gewerbestrasse  21  Schweizer Franken
# 6497                CH-4852 Rothrist; Helblingstrasse 7  Schweizer Franken
# 6498                    CH-9115 Dicken; Wilketstrasse 1  Schweizer Franken
# 6499                     CH-8004 Zürich; Hardstrasse 67  Schweizer Franken
#
#      Genehmigtes Limit Verfügbares Limit Mahnsperre Mahnsperre bis  \
# 5850              0,00              0,00      keine            NaN
# 5851        200'000,00        125'224,73      keine            NaN
# 5852              0,00              0,00      keine            NaN
# 5853              0,00       -225'000,00      keine            NaN
# 5854              0,00              0,00      keine            NaN
# 5855              0,00              0,00      keine            NaN
# 5856        100'000,00         88'069,40   temporär     30.06.2018
# 5857        200'000,00        190'173,45      keine            NaN
# 5858              0,00              0,00      keine            NaN
# 5859              0,00              0,00      keine            NaN
# 5860        150'000,00        -88'038,75      keine            NaN
# 5861         50'000,00         15'965,70      keine            NaN
# 5862         50'000,00         50'000,00      keine            NaN
# 5863              0,00              0,00      keine            NaN
# 5864              0,00              0,00      keine            NaN
# 5865        100'000,00        100'000,00      keine            NaN
# 5866         85'000,00         85'000,00      keine            NaN
# 5867        200'000,00              0,00      keine            NaN
# 5868         50'000,00         34'873,05      keine            NaN
# 5869              0,00              0,00      keine            NaN
# 5870              0,00              0,00      keine            NaN
# 5871              0,00              0,00      keine            NaN
# 5872         50'000,00         50'000,00      keine            NaN
# 5873              0,00              0,00      keine            NaN
# 5874              0,00              0,00      keine            NaN
# 5875              0,00              0,00      keine            NaN
# 5876        200'000,00              0,00      keine            NaN
# 5877        150'000,00         16'042,20      keine            NaN
# 5878         30'000,00         30'000,00      keine            NaN
# 5879              0,00              0,00      keine            NaN
# ...                ...               ...        ...            ...
# 6470         49'000,00         32'658,40      keine            NaN
# 6471         87'000,00         77'926,20      keine            NaN
# 6472        101'000,00         64'238,20      keine            NaN
# 6473         50'000,00         50'000,00      keine            NaN
# 6474              0,00              0,00      keine            NaN
# 6475              0,00              0,00      keine            NaN
# 6476              0,00              0,00      keine            NaN
# 6477        140'000,00         24'269,00      keine            NaN
# 6478              0,00              0,00      keine            NaN
# 6479              0,00              0,00      keine            NaN
# 6480              0,00              0,00      keine            NaN
# 6481              0,00              0,00      keine            NaN
# 6482              0,00              0,00      keine            NaN
# 6483              0,00              0,00      keine            NaN
# 6484              0,00              0,00      keine            NaN
# 6485         50'000,00         50'000,00      keine            NaN
# 6486              0,00              0,00      keine            NaN
# 6487              0,00              0,00      keine            NaN
# 6488              0,00              0,00      keine            NaN
# 6489              0,00              0,00      keine            NaN
# 6490              0,00              0,00      keine            NaN
# 6491              0,00              0,00      keine            NaN
# 6492              0,00              0,00      keine            NaN
# 6493              0,00              0,00      keine            NaN
# 6494              0,00              0,00      keine            NaN
# 6495              0,00              0,00      keine            NaN
# 6496              0,00              0,00      keine            NaN
# 6497         50'000,00         50'000,00      keine            NaN
# 6498         10'000,00         10'000,00      keine            NaN
# 6499         20'000,00         20'000,00      keine            NaN
#
#       Sperre Debitor Eigene Factoringgebühren Zahlungsbedingung  \
# 5850  nicht gesperrt                     Nein            20 Net
# 5851  nicht gesperrt                     Nein            90 NET
# 5852  nicht gesperrt                     Nein            30 Net
# 5853  nicht gesperrt                     Nein            90 NET
# 5854  nicht gesperrt                     Nein            30 Net
# 5855  nicht gesperrt                     Nein            20 Net
# 5856  nicht gesperrt                     Nein     10 Tage nette
# 5857  nicht gesperrt                     Nein     10 Tage nette
# 5858  nicht gesperrt                     Nein            10 Net
# 5859  nicht gesperrt                     Nein            30 Net
# 5860  nicht gesperrt                     Nein                30
# 5861  nicht gesperrt                     Nein            10 Net
# 5862  nicht gesperrt                     Nein            10 Net
# 5863  nicht gesperrt                     Nein            30 Net
# 5864  nicht gesperrt                     Nein            30 Net
# 5865  nicht gesperrt                     Nein           120 Net
# 5866  nicht gesperrt                     Nein            10 Net
# 5867  nicht gesperrt                     Nein             60NET
# 5868  nicht gesperrt                     Nein     10 Tage netto
# 5869  nicht gesperrt                     Nein            10 Net
# 5870  nicht gesperrt                     Nein            10 Net
# 5871  nicht gesperrt                     Nein            30 Net
# 5872  nicht gesperrt                     Nein     30 Tage netto
# 5873  nicht gesperrt                     Nein            10 Net
# 5874  nicht gesperrt                     Nein            10 Net
# 5875  nicht gesperrt                     Nein            10 Net
# 5876  nicht gesperrt                     Nein             90NET
# 5877  nicht gesperrt                     Nein                90
# 5878  nicht gesperrt                     Nein                30
# 5879  nicht gesperrt                     Nein            10 Net
# ...              ...                      ...               ...
# 6470  nicht gesperrt                     Nein     30 Tage netto
# 6471  nicht gesperrt                     Nein     30 Tage netto
# 6472  nicht gesperrt                     Nein     30 Tage netto
# 6473  nicht gesperrt                     Nein     10 Tage netto
# 6474  nicht gesperrt                     Nein            10 Net
# 6475  nicht gesperrt                     Nein            30 Net
# 6476  nicht gesperrt                     Nein            10 Net
# 6477  nicht gesperrt                     Nein            10 Net
# 6478  nicht gesperrt                     Nein     30 Tage netto
# 6479  nicht gesperrt                     Nein            30 Net
# 6480  nicht gesperrt                     Nein     10 Tage netto
# 6481  nicht gesperrt                     Nein     30 Tage netto
# 6482  nicht gesperrt                     Nein     10 Tage netto
# 6483  nicht gesperrt                     Nein            30 Net
# 6484  nicht gesperrt                     Nein            30 Net
# 6485  nicht gesperrt                     Nein            10 Net
# 6486  nicht gesperrt                     Nein            10 Net
# 6487  nicht gesperrt                     Nein            30 Net
# 6488  nicht gesperrt                     Nein            30 Net
# 6489  nicht gesperrt                     Nein     30 Tage netto
# 6490  nicht gesperrt                     Nein     30 Tage netto
# 6491  nicht gesperrt                     Nein     30 Tage netto
# 6492  nicht gesperrt                     Nein     30 Tage netto
# 6493  nicht gesperrt                     Nein     30 Tage netto
# 6494  nicht gesperrt                     Nein            30 Net
# 6495  nicht gesperrt                     Nein     30 Tage netto
# 6496  nicht gesperrt                     Nein     30 Tage netto
# 6497  nicht gesperrt                     Nein     10 Tage netto
# 6498  nicht gesperrt                     Nein     10 Tage netto
# 6499  nicht gesperrt                     Nein            10 Net
#
#      Limitgrundlage  Telefon 1
# 5850       KV-Limit        NaN
# 5851       KV-Limit        NaN
# 5852     kein Limit        NaN
# 5853       KV-Limit        NaN
# 5854       KV-Limit        NaN
# 5855       KV-Limit        NaN
# 5856       KV-Limit        NaN
# 5857       KV-Limit        NaN
# 5858       KV-Limit        NaN
# 5859       KV-Limit        NaN
# 5860       KV-Limit        NaN
# 5861       KV-Limit        NaN
# 5862       KV-Limit        NaN
# 5863     kein Limit        NaN
# 5864     kein Limit        NaN
# 5865       KV-Limit        NaN
# 5866       KV-Limit        NaN
# 5867       KV-Limit        NaN
# 5868       KV-Limit        NaN
# 5869       KV-Limit        NaN
# 5870       KV-Limit        NaN
# 5871     kein Limit        NaN
# 5872       KV-Limit        NaN
# 5873       KV-Limit        NaN
# 5874       KV-Limit        NaN
# 5875       KV-Limit        NaN
# 5876       KV-Limit        NaN
# 5877       KV-Limit        NaN
# 5878       KV-Limit        NaN
# 5879       KV-Limit        NaN
# ...             ...        ...
# 6470       KV-Limit        NaN
# 6471       KV-Limit        NaN
# 6472       KV-Limit        NaN
# 6473       KV-Limit        NaN
# 6474     kein Limit        NaN
# 6475     kein Limit        NaN
# 6476     kein Limit        NaN
# 6477       KV-Limit        NaN
# 6478     kein Limit        NaN
# 6479     kein Limit        NaN
# 6480     kein Limit        NaN
# 6481     kein Limit        NaN
# 6482     kein Limit        NaN
# 6483     kein Limit        NaN
# 6484       KV-Limit        NaN
# 6485       KV-Limit        NaN
# 6486     kein Limit        NaN
# 6487     kein Limit        NaN
# 6488     kein Limit        NaN
# 6489     kein Limit        NaN
# 6490     kein Limit        NaN
# 6491     kein Limit        NaN
# 6492     kein Limit        NaN
# 6493     kein Limit        NaN
# 6494     kein Limit        NaN
# 6495     kein Limit        NaN
# 6496     kein Limit        NaN
# 6497       KV-Limit        NaN
# 6498       KV-Limit        NaN
# 6499       KV-Limit        NaN
#
# [650 rows x 18 columns]

# %%
#adds = df.Anschrift.str.split(' ').apply(lambda x:x[0])

# %%
def geolocator(address):
    """
    This function, given a string representing the address, will return latitude and longitude, if available.
    NaN otherwise.
    """
    geoloc = Nominatim(user_agent='lon-lat-retrieval', timeout=12)
    geocoder = RateLimiter(geoloc.geocode, min_delay_seconds=1, max_retries=2) #rate limiter to avoid being blocked
    location = geocoder(address.split(' ')[0])
    
    if len(address)<3:
        print('--WARNING-- Geolocation data not available for address: {}'.format(address))
        lat = np.nan
        lon = np.nan
        return lon, lat
        
    if location:
        lat = location.latitude
        lon = location.longitude
        return lon, lat
    
    else:
        #make a second attempt using only the entire address
        print('Making a second attempt with the entire address {}'.format(address))
        location = geocoder(address)
        
        if location:
            lat = location.latitude
            lon = location.longitude
            return lon, lat
            
        else:
            print('--WARNING-- Geolocation data not available for address: {}'.format(address))
            lat = np.nan
            lon = np.nan
            return lon, lat

# %% [markdown]
# ### Saving longitude and latitude data into dataframes

# %% [markdown]
# Geopy is used to retrieve latitude and longitude information for the companies of the given dataset. In order to avoid exceeding requests number, the dataset is split in 'sub-dataset'.

# %%
datafolder2 = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/".format(user)

# %%
#lonlat_0 = dfs[0].Anschrift.apply(geolocator)
#lonlat_0.to_pickle(datafolder2+'lonlat_0.pkl')
#done

# %%
#lonlat_1 = dfs[1].Anschrift.apply(geolocator)
#lonlat_1.to_pickle(datafolder2+'lonlat_1.pkl')
#done

# %%
#lonlat_2 = dfs[2].Anschrift.apply(geolocator)
#lonlat_2.to_pickle(datafolder2+'lonlat_2.pkl')
#done

# %%
lonlat_3 = dfs[3].Anschrift.apply(geolocator)
lonlat_3.to_pickle(datafolder2+'lonlat_3.pkl')

# %%
lonlat_4 = dfs[4].Anschrift.apply(geolocator)
lonlat_4.to_pickle(datafolder2+'lonlat_4.pkl')

# %%
lonlat_5 = dfs[5].Anschrift.apply(geolocator)
lonlat_5.to_pickle(datafolder2+'lonlat_5.pkl')

# %%
lonlat_6 = dfs[6].Anschrift.apply(geolocator)
lonlat_6.to_pickle(datafolder2+'lonlat_6.pkl')

# %%
lonlat_7 = dfs[7].Anschrift.apply(geolocator)
lonlat_7.to_pickle(datafolder2+'lonlat_7.pkl')

# %%
lonlat_8 = dfs[8].Anschrift.apply(geolocator)
lonlat_8.to_pickle(datafolder2+'lonlat_8.pkl')

# %%
lonlat_9 = dfs[9].Anschrift.apply(geolocator)
lonlat_9.to_pickle(datafolder2+'lonlat_9.pkl')

# %% [markdown]
# ### Merging sub df into a single df

# %%
to_concat = []
for n in range(3):
    load = pd.read_pickle(datafolder2+'lonlat_'+str(n)+'.pkl')
    dfs[n]['longitude'] = load.apply(lambda x:x[0])
    dfs[n]['latitude'] = load.apply(lambda x:x[1])
dfs[1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#      Kunden Id  K-Debitoren Id Debitoren Id  \
# 650    2004008            2233      1100012
# 651    2004009            2234          584
# 652    2004008            2234          658
# 653       IF01            5875     0255-405
# 654    2004008            2234      1100015
# 655       IF01            5569  0297-106567
# 656    2004078            2235       101209
# 657    2004008            2235          689
# 658    2004008            2235      1100024
# 659    2004024            2236          130
# 660    2004008            2236          723
# 661    2004008            2236      1100033
# 662    2004008            2237      1140001
# 656   Schweizer Franken         50'000,00         50'000,00      keine
# 657   Schweizer Franken              0,00              0,00      keine
# 658   Schweizer Franken              0,00              0,00      keine
# 659   Schweizer Franken         50'000,00         50'000,00      keine
# 660   Schweizer Franken              0,00              0,00      keine
# 661   Schweizer Franken              0,00              0,00      keine
# 662   Schweizer Franken              0,00              0,00      keine
# 663   Schweizer Franken              0,00              0,00      keine
# 664   Schweizer Franken              0,00              0,00      keine
# 665   Schweizer Franken              0,00              0,00      keine
# 666   Schweizer Franken              0,00              0,00      keine
# 667   Schweizer Franken              0,00              0,00      keine
# 668   Schweizer Franken              0,00              0,00      keine
# 669   Schweizer Franken              0,00              0,00      keine
# 670   Schweizer Franken              0,00              0,00      keine
# 671   Schweizer Franken              0,00              0,00      keine
# 672   Schweizer Franken              0,00              0,00      keine
# 673   Schweizer Franken              0,00              0,00      keine
# 674   Schweizer Franken              0,00              0,00      keine
# 675   Schweizer Franken              0,00              0,00      keine
# 676   Schweizer Franken              0,00              0,00      keine
# 677   Schweizer Franken              0,00              0,00      keine
# 678   Schweizer Franken              0,00              0,00      keine
# 679   Schweizer Franken              0,00              0,00      keine
# ...                 ...               ...               ...        ...
# 1270  Schweizer Franken              0,00              0,00      keine
# 1271  Schweizer Franken              0,00              0,00      keine
# 1272  Schweizer Franken              0,00              0,00      keine
# 1273  Schweizer Franken              0,00              0,00      keine
# 1274  Schweizer Franken              0,00              0,00      keine
# 1275  Schweizer Franken              0,00              0,00      keine
# 1276  Schweizer Franken              0,00              0,00      keine
# 1277  Schweizer Franken              0,00              0,00      keine
# 1278  Schweizer Franken              0,00              0,00      keine
# 1279  Schweizer Franken              0,00              0,00      keine
# 1280  Schweizer Franken              0,00              0,00      keine
# 1281  Schweizer Franken              0,00              0,00      keine
# 1282  Schweizer Franken              0,00              0,00      keine
# 1283  Schweizer Franken              0,00              0,00      keine
# 1284  Schweizer Franken         50'000,00         25'785,74   komplett
# 1285  Schweizer Franken        100'000,00        100'000,00      keine
# 1286  Schweizer Franken              0,00              0,00      keine
# 1287  Schweizer Franken              0,00              0,00      keine
# 1288  Schweizer Franken              0,00              0,00      keine
# 1289  Schweizer Franken         80'000,00         77'817,99      keine
# 1290  Schweizer Franken              0,00              0,00      keine
# 1291  Schweizer Franken              0,00              0,00      keine
# 1292  Schweizer Franken              0,00              0,00      keine
# 1293  Schweizer Franken        100'000,00        100'000,00      keine
# 1294  Schweizer Franken              0,00              0,00      keine
# 1295  Schweizer Franken              0,00              0,00      keine
# 1296  Schweizer Franken              0,00              0,00      keine
# 1297  Schweizer Franken              0,00              0,00      keine
# 1298  Schweizer Franken         20'000,00         20'000,00      keine
# 1299  Schweizer Franken              0,00              0,00      keine
#
#      Mahnsperre bis     Sperre Debitor Eigene Factoringgebühren  \
# 650             NaN     nicht gesperrt                     Nein
# 651             NaN     nicht gesperrt                     Nein
# 652             NaN     nicht gesperrt                     Nein
# 653             NaN     nicht gesperrt                     Nein
# 654             NaN     nicht gesperrt                     Nein
# 655             NaN     nicht gesperrt                     Nein
# 656             NaN     nicht gesperrt                     Nein
# 657             NaN     nicht gesperrt                     Nein
# 658             NaN     nicht gesperrt                     Nein
# 659             NaN     nicht gesperrt                     Nein
# 660             NaN     nicht gesperrt                     Nein
# 661             NaN     nicht gesperrt                     Nein
# 662             NaN     nicht gesperrt                     Nein
# 663             NaN     nicht gesperrt                     Nein
# 664             NaN     nicht gesperrt                     Nein
# 665             NaN     nicht gesperrt                     Nein
# 666             NaN     nicht gesperrt                     Nein
# 667             NaN     nicht gesperrt                     Nein
# 668             NaN     nicht gesperrt                     Nein
# 669             NaN     nicht gesperrt                     Nein
# 670             NaN     nicht gesperrt                     Nein
# 671             NaN     nicht gesperrt                     Nein
# 672             NaN     nicht gesperrt                     Nein
# 673             NaN     nicht gesperrt                     Nein
# 674             NaN     nicht gesperrt                     Nein
# 675             NaN     nicht gesperrt                     Nein
# 676             NaN     nicht gesperrt                     Nein
# 677             NaN     nicht gesperrt                     Nein
# 678             NaN     nicht gesperrt                     Nein
# 679             NaN     nicht gesperrt                     Nein
# ...             ...                ...                      ...
# 1270            NaN     nicht gesperrt                     Nein
# 1271            NaN     nicht gesperrt                     Nein
# 1272            NaN     nicht gesperrt                     Nein
# 1273            NaN     nicht gesperrt                     Nein
# 1274            NaN     nicht gesperrt                     Nein
# 1275            NaN     nicht gesperrt                     Nein
# 1276            NaN     nicht gesperrt                     Nein
# 1277            NaN     nicht gesperrt                     Nein
# 1278            NaN     nicht gesperrt                     Nein
# 1279            NaN     nicht gesperrt                     Nein
# 1280            NaN     nicht gesperrt                     Nein
# 1281            NaN     nicht gesperrt                     Nein
# 1282            NaN     nicht gesperrt                     Nein
# 1283            NaN     nicht gesperrt                     Nein
# 1284            NaN  komplett gesperrt                     Nein
# 1285            NaN     nicht gesperrt                     Nein
# 1286            NaN     nicht gesperrt                     Nein
# 1287            NaN     nicht gesperrt                     Nein
# 1288            NaN     nicht gesperrt                     Nein
# 1289            NaN     nicht gesperrt                     Nein
# 1290            NaN     nicht gesperrt                     Nein
# 1291            NaN     nicht gesperrt                     Nein
# 1292            NaN     nicht gesperrt                     Nein
# 1293            NaN     nicht gesperrt                     Nein
# 1294            NaN     nicht gesperrt                     Nein
# 1295            NaN     nicht gesperrt                     Nein
# 1296            NaN     nicht gesperrt                     Nein
# 1297            NaN     nicht gesperrt                     Nein
# 1298            NaN     nicht gesperrt                     Nein
# 1299            NaN     nicht gesperrt                     Nein
#
#      Zahlungsbedingung Limitgrundlage  Telefon 1  longitude   latitude
# 650             10 Net     kein Limit        NaN   9.277761  47.385170
# 651             10 Net     kein Limit        NaN   7.649345  46.303715
# 652             10 Net     kein Limit        NaN   7.649345  46.303715
# 653             30 Net     kein Limit        NaN   8.671503  47.225315
# 654             10 Net     kein Limit        NaN   7.621981  46.327346
# 655             30 Net     kein Limit        NaN   8.554134  47.410708
# 656      10 Tage netto       KV-Limit        NaN   9.458928  47.364845
# 657             10 Net       KV-Limit        NaN   8.500358  47.401200
# 658             10 Net       KV-Limit        NaN   9.458928  47.364845
# 659             30 Net       KV-Limit        NaN  16.846245  46.843442
# 660             10 Net     kein Limit        NaN   9.304474  47.407096
# 661             10 Net     kein Limit        NaN   8.521851  47.377598
# 662             10 Net     kein Limit        NaN   8.613070  47.400110
# 663             30 Net     kein Limit        NaN   8.600113  47.253582
# 664             10 Net     kein Limit        NaN   7.886166  46.293408
# 665             10 Net     kein Limit        NaN   7.886166  46.293408
# 666             10 Net     kein Limit        NaN   7.649345  46.303715
# 667             30 Net     kein Limit        NaN   8.267581  47.438706
# 668             10 Net     kein Limit        NaN   7.649345  46.303715
# 669             10 Net     kein Limit        NaN   7.886166  46.293408
# 670             10 Net     kein Limit        NaN   8.771104  47.251139
# 671             30 Net     kein Limit        NaN   8.854521  47.414094
# 672             10 Net     kein Limit        NaN   8.759445  47.280283
# 673             10 Net     kein Limit        NaN   7.982508  46.310983
# 674             10 Net     kein Limit        NaN   8.600113  47.253582
# 675             10 Net     kein Limit        NaN   8.547488  47.320634
# 676             10 Net     kein Limit        NaN   9.407332  46.863598
# 677             30 Net     kein Limit        NaN   7.982584  47.321680
# 678             10 Net     kein Limit        NaN   8.766908  46.677626
# 679             10 Net       KV-Limit        NaN   8.540926  47.519766
# ...                ...            ...        ...        ...        ...
# 1270            10 Net     kein Limit        NaN   7.567460  47.549989
# 1271            30 Net       KV-Limit        NaN   6.072396  46.229930
# 1272            30 Net     kein Limit        NaN  10.376184  53.610869
# 1273            30 Net       KV-Limit        NaN   6.205191  46.246035
# 1274            30 Net       KV-Limit        NaN   6.114257  49.585751
# 1275            30 Net     kein Limit        NaN   6.129439  46.210067
# 1276            30 Net     kein Limit        NaN   6.111734  46.168499
# 1277            30 Net       KV-Limit        NaN   6.161014  46.287516
# 1278            30 Net       KV-Limit        NaN   8.075958  47.388815
# 1279            30 Net     kein Limit        NaN   7.075882  47.176577
# 1280            30 Net     kein Limit        NaN   8.693835  47.253897
# 1281            30 Net     kein Limit        NaN   8.709189  47.191948
# 1282            30 Net     kein Limit        NaN   8.855028  47.190040
# 1283            30 Net       KV-Limit        NaN   8.932988  47.554151
# 1284            30 Net     kein Limit        NaN   6.145260  46.216364
# 1285            30 Net       KV-Limit        NaN   8.547488  47.320634
# 1286            30 Net       KV-Limit        NaN   7.607744  47.564747
# 1287            30 Net       KV-Limit        NaN  16.846245  46.843442
# 1288            30 Net       KV-Limit        NaN   7.592513  47.547486
# 1289            10 Net       KV-Limit        NaN   7.607744  47.564747
# 1290            30 Net     kein Limit        NaN   9.192008  46.785315
# 1291            30 Net     kein Limit        NaN   8.160550  47.348297
# 1292            30 Net       KV-Limit        NaN   9.178937  47.414486
# 1293            30 Net       KV-Limit        NaN   5.452186  43.711711
# 1294            30 Net     kein Limit        NaN   8.569197  47.429378
# 1295            30 Net     kein Limit        NaN   8.614917  47.420144
# 1296            30 Net     kein Limit        NaN   2.142746  41.395492
# 1297            30 Net     kein Limit        NaN   2.142746  41.395492
# 1298            30 Net       KV-Limit        NaN   6.793384  50.913008
# 1299            30 Net       KV-Limit        NaN   2.288699  48.860858
#
# [650 rows x 20 columns]

# %% [markdown]
# ### Adding lon lat data to df
