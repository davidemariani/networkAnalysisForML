# %% [markdown]
# # Models loop automation - Pastdue90 tuned models

# %% [markdown]
# This notebook uses as inputs the outputs from the pipeline ('05_preproc_pipeline_1.ipynb' notebook) and performs model assessment of performances and general exploration for the transaction credit events prediction "is_pastdue90".
# All the experiments produce useful data for visualizing results and can be tracked on MLflow.

# %%
import pandas as pd
import numpy as np
import pickle

from scripts_ml.models_utils import *
from scripts_viz.visualization_utils import *

from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from bokeh.io import show, output_notebook
output_notebook()
# Out:
# C:\ProgramData\Anaconda3\envs\thesis_mlflow\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
#linear model Stochastic Gradient Descent with semi-optimized hyperparameters using random search
sgd_rs_1 = SGDClassifier(random_state=42, max_iter=350, loss='log', learning_rate='optimal', eta0=0.001, tol=0.0001) #from benchmark_imp_shuffle_tuning
sgd_rs_2 = SGDClassifier(random_state=42, max_iter=200, loss='log', learning_rate='constant', eta0=0.001, tol=0.0001) #from benchmark_imp_time_tuning
sgd_rs_3 = SGDClassifier(random_state=42, max_iter=180, loss='log', learning_rate='adaptive', eta0=0.01, tol=0.0001) #from benchmark_p90_shuffle_tuning
sgd_rs_4 = SGDClassifier(random_state=42, max_iter=320, loss='log', learning_rate='constant', eta0=0.01, tol=0.0001) #from benchmark_p90_time_tuning
sgd_rs_5 = SGDClassifier(random_state=42, max_iter=320, loss='log', learning_rate='adaptive', eta0=0.01, tol=0.0001) #from both benchmark_p180_shuffle_tuning and benchmark_p180_time_tuning

sgd_models = [sgd_rs_1, sgd_rs_2, sgd_rs_3, sgd_rs_4, sgd_rs_5]

# %%
#random forest models parameters from randomized grid search

#from benchmark_imp_shuffle_tuning
rf_opt_1 = {'n_estimators': 350,
 'min_samples_split': 10,
 'min_samples_leaf': 1,
 'max_leaf_nodes': 80,
 'max_features': 15,
 'max_depth': 80,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_imp_time_tuning
rf_opt_2 = {'n_estimators': 180,
 'min_samples_split': 10,
 'min_samples_leaf': 1,
 'max_leaf_nodes': 25,
 'max_features': 10,
 'max_depth': None,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_p90_shuffle_tuning
rf_opt_3 = {'n_estimators': 280,
 'min_samples_split': 10,
 'min_samples_leaf': 1,
 'max_leaf_nodes': 100,
 'max_features': 15,
 'max_depth': 280,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_p90_time_tuning
rf_opt_4 = {'n_estimators': 300,
 'min_samples_split': 5,
 'min_samples_leaf': 2,
 'max_leaf_nodes': 80,
 'max_features': 'sqrt',
 'max_depth': None,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_p180_shuffle_tuning
rf_opt_5 = {'n_estimators': 250,
 'min_samples_split': 15,
 'min_samples_leaf': 1,
 'max_leaf_nodes': 100,
 'max_features': 'auto',
 'max_depth': 180,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_p180_time_tuning 
rf_opt_6 = {'n_estimators': 180,
 'min_samples_split': 5,
 'min_samples_leaf': 2,
 'max_leaf_nodes': 80,
 'max_features': 'sqrt',
 'max_depth': 80,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

rf_parameters = [rf_opt_1, rf_opt_2, rf_opt_3, rf_opt_4, rf_opt_5, rf_opt_6]

rf_models = [RandomForestClassifier(**params) for params in rf_parameters]

# %%
models = sgd_models+rf_models

# %%
prefixes_shuffle = ['shuffle_p90_']
postfixes_shuffle = ['_19072_750']
preproc_folder = "benchmarks_shuffle" #folder with the correct preprocessing data
expname = preproc_folder+"_opt_p90" #experiment name

# %%
datafolder = "../data/preproc_traintest/"+preproc_folder+'/'
output_path = "../data/models/"

# %% [markdown]
# ## Experiment in Shuffle Mode

# %%
experiment_shuffle = models_loop(models, datafolder, prefixes_shuffle, postfixes_shuffle, mlf_tracking=True, save_model=True,
                                experiment_name=expname, save_results_for_viz=False)
# Out:
# ----Loop 1 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.765
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99813 0.00187]
#  [0.07478 0.00487]]
# AUC 0.780
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__SGDClassifier_190817_103916.pkl
# - Creating the new experiment 'benchmarks_shuffle_opt_p90',  the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 2 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.767
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99616 0.00384]
#  [0.07309 0.00656]]
# AUC 0.779
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__SGDClassifier_190817_103922.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 3 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.770
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99719 0.00281]
#  [0.07459 0.00506]]
# AUC 0.782
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__SGDClassifier_190817_103932.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 4 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.767
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99175 0.00825]
#  [0.07103 0.00862]]
# AUC 0.775
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__SGDClassifier_190817_103937.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 5 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.770
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99719 0.00281]
#  [0.07459 0.00506]]
# AUC 0.782
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__SGDClassifier_190817_103945.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 6 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.960
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.90667 0.09333]
#  [0.00759 0.07206]]
# AUC 0.961
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__RandomForestClassifier_190817_10423.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 7 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.931
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.81737 0.18263]
#  [0.00862 0.07103]]
# AUC 0.932
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__RandomForestClassifier_190817_104247.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 8 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.963
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.91576 0.08424]
#  [0.0075  0.07215]]
# AUC 0.964
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__RandomForestClassifier_190817_104437.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 9 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.958
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.90217 0.09783]
#  [0.00778 0.07187]]
# AUC 0.960
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__RandomForestClassifier_190817_104528.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 10 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.961
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.91248 0.08752]
#  [0.00768 0.07196]]
# AUC 0.963
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__RandomForestClassifier_190817_104613.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 11 of 11 for credit event shuffle_p90_----
# Training, validation and testing of experiment with prefix shuffle_p90_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_p90__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.957
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.90255 0.09745]
#  [0.0075  0.07215]]
# AUC 0.960
# - Saving the model to ../data/models/benchmarks_shuffle_opt_p90/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_p90/shuffle_p90__RandomForestClassifier_190817_104645.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# Experiment done!

# %% [markdown]
# ## Experiment in Time mode

# %%
preproc_folder = "benchmarks_time" #folder with the correct preprocessing data
expname = preproc_folder+"_opt_p90" #experiment name
datafolder = "../data/preproc_traintest/"+preproc_folder+'/'
prefixes_time = ['time_2018-04-30_p90_']
postfixes_time = ['_190710_745']

# %%
experiment_time = models_loop(models, datafolder, prefixes_time, postfixes_time, 
                              timeSeqValid = True, train_window = 12000, test_window = 3000,
                              mlf_tracking=True, save_model=True,
                                experiment_name=expname, save_results_for_viz=False)
# Out:
# ----Loop 1 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6946915934292958
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.5954713923586196
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.6175966098274646
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.608130241681728
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.7125079437236466
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.578479786636721
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.8342916260234696
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.853586071562774
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.883909039934203
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.8572201098246058
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.760970148852079
# Validation AUC 0.706
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.96273 0.03727]
#  [0.01231 0.00735]]
# AUC 0.772
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__SGDClassifier_190817_104650.pkl
# - Creating the new experiment 'benchmarks_time_opt_p90',  the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 2 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6229466549040191
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.5771662473688384
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.5879413197208239
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.6166433510087783
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.7624107635715909
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.582693711398091
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.8523567142561556
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.8264339693540981
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.8897367417016405
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.8724135673127291
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.7650264891038557
# Validation AUC 0.706
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.97442 0.02558]
#  [0.01266 0.00699]]
# AUC 0.773
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__SGDClassifier_190817_104656.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 3 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6803412098404225
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.5772035112092498
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.6104104306102086
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.5987280347748292
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.749192871290803
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.5847332959011791
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.8478756170376284
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.827957079036366
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.8922655354207291
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.8716131392135257
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.7670609383942204
# Validation AUC 0.710
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.97291 0.02709]
#  [0.01248 0.00717]]
# AUC 0.774
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__SGDClassifier_190817_10473.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 4 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6516634747456701
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.5873077448592621
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.6070944990663822
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.596701170135768
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.7450621349945958
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.5851010668163953
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.8489527356566463
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.8167959584150976
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.8968127333622588
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.8702843608316323
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.7678000857554462
# Validation AUC 0.702
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.96503 0.03497]
#  [0.01222 0.00744]]
# AUC 0.775
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__SGDClassifier_190817_10478.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 5 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6803412098404225
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.5772035112092498
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.6104104306102086
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.5987280347748292
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.749192871290803
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.5847332959011791
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.8478756170376284
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.827957079036366
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.8922655354207291
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.8716131392135257
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.7670609383942204
# Validation AUC 0.710
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.97291 0.02709]
#  [0.01248 0.00717]]
# AUC 0.774
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__SGDClassifier_190817_104714.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 6 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6113419747847547
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.7857959795182645
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.7648167455788619
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.856744847054378
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.9452033825187055
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.8685022459292533
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.9241683662912713
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9272297607615548
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9344542104113417
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.8950186051552537
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.8982479337063756
# Validation AUC 0.833
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.81675 0.18325]
#  [0.00593 0.01372]]
# AUC 0.838
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__RandomForestClassifier_190817_10487.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 7 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6548897112195557
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.7376147893494212
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.7557558567547469
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.8354134512128542
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.9370143891566433
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.8568479786636721
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.9143590198338801
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9179650118992944
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9234093615701876
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.9011482587019743
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.8836874483090209
# Validation AUC 0.849
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.76027 0.23973]
#  [0.00478 0.01487]]
# AUC 0.827
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__RandomForestClassifier_190817_104827.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 8 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6138301376899797
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.8010087034954438
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.7645034635415694
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.8563621183305526
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.9473847174353718
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.8681611454239191
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.9277171824657858
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9278226378856832
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9288464694033074
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.8987396362059934
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.8988507334961132
# Validation AUC 0.835
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.82587 0.17413]
#  [0.00655 0.0131 ]]
# AUC 0.842
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__RandomForestClassifier_190817_104911.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 9 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6778069827692101
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.7781138954949929
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.7819395085395826
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.8821049663045909
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.9445365735994693
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.8923638405390231
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.9277508793709911
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9304571834161413
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9282359147095863
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.915746193168476
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.8882963550347238
# Validation AUC 0.856
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.81905 0.18095]
#  [0.00531 0.01434]]
# AUC 0.855
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__RandomForestClassifier_190817_104934.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 10 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6803666847200973
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.7925569778452137
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.7788160305733374
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.8811894736403405
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.9463282601737646
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.8887380685008422
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.929229404983595
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9315811448373763
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9289114006114607
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.9155875751883095
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.8881366848523231
# Validation AUC 0.855
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.82817 0.17183]
#  [0.00549 0.01416]]
# AUC 0.856
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__RandomForestClassifier_190817_104955.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 11 of 11 for credit event time_2018-04-30_p90_----
# Training, validation and testing of experiment with prefix time_2018-04-30_p90_ and postfix _190710_745 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_p90__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.6953930250477391
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.7762134396340117
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.7820509945926151
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.8816930640664268
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.9439665969319833
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.8902266984839977
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.9242197984097424
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9288480647989646
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.927637943583337
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.9158929571358898
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.8893826504891469
# Validation AUC 0.860
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.8156  0.1844 ]
#  [0.0054  0.01425]]
# AUC 0.852
# - Saving the model to ../data/models/benchmarks_time_opt_p90/...
# - Saving model to ../data/models/benchmarks_time_opt_p90/time_2018-04-30_p90__RandomForestClassifier_190817_105011.pkl
# - Activating existing experiment 'benchmarks_time_opt_p90', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# Experiment done!
