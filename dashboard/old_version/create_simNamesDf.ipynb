# %%
#create anonimized dataset

import pandas as pd
import numpy as np
from sim_names import *

datafolder = 'C:/Users/DavideMariani/Tradeteq Dropbox/Tradeteq Team/Clients/#GoFactoring/data analysis/'
filename = 'instruments_with_score.pkl'
df = pd.read_pickle(datafolder+filename)

# %%
allnames = list(df.customer_name_1.unique()) + list(df.debtor_name_1.unique())
len(allnames)
# Out:
# 3364

# %%
simNames = sim_names(len(allnames))

# %%
len(simNames)
# Out:
# 3364

# %%
dictnames = dict(zip(allnames,simNames))

# %%
df['customer_name_1'] = df['customer_name_1'].apply(lambda x:dictnames[x])
df['debtor_name_1'] = df['debtor_name_1'].apply(lambda x:dictnames[x])

# %%
df.head()
# Out:
#              customer_id customer_name_1 debtor_id         debtor_name_1  \
# uid
# 2744:79/231      2004008       Lutz Inc.        79       Medusa Abo Sarl
# 2861:79/232      2004008       Lutz Inc.        79       Medusa Abo Sarl
# 2932:79/233      2004008       Lutz Inc.        79       Medusa Abo Sarl
# 1472:489/688     2004009   Xhosa Limited       489  Langley Guam Limited
# 2042:512/645     2004009   Xhosa Limited       512           Darrell Ltd
#
#              invoice_number invoice_date   due_date  invoice_amount  \
# uid
# 2744:79/231            2744   2013-07-23 2013-08-02          913.70
# 2861:79/232            2861   2013-07-30 2013-08-09         2233.45
# 2932:79/233            2932   2013-08-06 2013-08-16         1370.50
# 1472:489/688           1472   2013-08-13 2013-08-23         9195.10
# 2042:512/645           2042   2013-08-13 2013-08-23         4594.60
#
#               purchase_amount  purchase_amount_open  ... c_pd_mismatch_mean  \
# uid                                                  ...
# 2744:79/231               0.0                   0.0  ...                NaN
# 2861:79/232               0.0                   0.0  ...                NaN
# 2932:79/233               0.0                   0.0  ...                NaN
# 1472:489/688              0.0                   0.0  ...                NaN
# 2042:512/645              0.0                   0.0  ...                NaN
#
#               c_pd_mismatch_std c_repaid_r c_impaired1_r c_impaired2_r  \
# uid
# 2744:79/231                 NaN        NaN           NaN           NaN
# 2861:79/232                 NaN        0.0           0.0           0.0
# 2932:79/233                 NaN        0.0           0.0           0.0
# 1472:489/688                NaN        NaN           NaN           NaN
# 2042:512/645                NaN        0.0           0.0           0.0
#
#               c_pastdue90_r c_pastdue180_r  score_f0  score_f1  score_f2
# uid
# 2744:79/231             NaN            NaN  0.595210  0.256625  0.249184
# 2861:79/232             0.0            0.0  0.528232  0.248512  0.242951
# 2932:79/233             0.0            0.0  0.385557  0.246348  0.236226
# 1472:489/688            NaN            NaN  0.590854  0.247408  0.250373
# 2042:512/645            0.0            0.0  0.588450  0.243131  0.235739
#
# [5 rows x 116 columns]

# %%
df.to_pickle(datafolder+'instruments_with_score_simnames.pkl')
