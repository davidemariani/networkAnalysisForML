# %% [markdown]
# # Social network exploration

# %% [markdown]
# This notebook starts from the output generated at step 4 (04_trades_featureEng.ipynb), building and exploring the network of buyers and sellers.

# %%
import numpy as np
import pandas as pd 
from network_analysis_exp import *
from network_bond_graph import *
from network_modelling import *
from network_visualization import *
import networkx as nx
import seaborn as sns

from bokeh.io import show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Importing data

# %%
datafolder = ".."+"/data/"
filename = "04_network_snapshots.pkl"

df = pd.read_pickle(datafolder+filename)

# %%
#selecting intervals of 6 months
snapshots = ['sshot_1_', 'sshot_6_', 'sshot_12_', 'sshot_18_', 'sshot_24_', 'sshot_30_', 'sshot_36_', 'sshot_42_',
'sshot_58_', 'sshot_61_'][::-1]

# %%
graph_list = []

for s in snapshots:
    
    sn = df[df[s]][[c for c in df.columns if s in c] \
                          +['has_purchase', 'due_date', 'invoice_date', 'customer_name_1', 
                           'debtor_name_1', 'customer_id', 'debtor_id', 'uid']]
    
    #node df
    print("creating nodes df for snapshot {}..".format(s))
    nodes_df = create_nodes_df(sn)

    #edge df
    print("creating edges df for snapshot {}..".format(s))
    edges_df = create_edges_df(sn, fields=[s+'cd_pastdue90_r'])
    
    print("adding network info for snapshot {}..".format(s))
    if s=='sshot_61_': #if the snapshot is the last snapshot

        #adding coordinates to nodes df
        graph, edges_df, nodes_df_main = network_info(edges_df, nodes_df)
        
        #pos, sizes_dict = nodes_post(nodes_df, edges_df, 'Company_Name', nxk=0.085)
        #nodes_df_main['size'] = [sizes_dict[i] for i in list(nodes_df.Company_Name)]
        nodes_df = nodes_df_main.copy()
    else:
        #node df
        nodes_df['size'] = [nodes_df_main.loc[nodes_df.Company_Name==c, 'size'] for c in nodes_df.Company_Name]
        nodes_df['coords'] = [nodes_df_main.loc[nodes_df.Company_Name==c, 'coords'] for c in nodes_df.Company_Name]
    
    print("Appending graph for snapshot {}".format(s))
    #graph to visualize
    g = graph_from_coordinates(nodes_df, edges_df, to_highlight=s+'cd_pastdue90_r')
    
    graph_list.append(g)
# Out:
# creating nodes df for snapshot sshot_61_..
# creating edges df for snapshot sshot_61_..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-904cb0eae1c8> in <module>
#      14     #edge df
#      15     print("creating edges df for snapshot {}..".format(s))
# ---> 16     edges_df = create_edges_df(sn, fields=[s+'cd_pastdue90_r'])
#      17
#      18     print("adding network info for snapshot {}..".format(s))
#
# ~\Tradeteq Dropbox\Davide Mariani\thesis_project\networkAnalysisForML\network_modelling.py in create_edges_df(df, sellers_colname, buyers_colname, sellersid_colname, fields)
#     151     if len(fields)>0:
#     152         for f in fields: #this step assumes that the stats have been already created for the whole dataset
# --> 153             edges_df[f]=list([d.loc[(d[sellers_colname] == edges_df.iloc[k]['xs']) & (d[buyers_colname] == edges_df.iloc[k]['ys']), f].values[0] for k in range(len(edges_df))])
#     154
#     155     return edges_df
#
# ~\Tradeteq Dropbox\Davide Mariani\thesis_project\networkAnalysisForML\network_modelling.py in <listcomp>(.0)
#     151     if len(fields)>0:
#     152         for f in fields: #this step assumes that the stats have been already created for the whole dataset
# --> 153             edges_df[f]=list([d.loc[(d[sellers_colname] == edges_df.iloc[k]['xs']) & (d[buyers_colname] == edges_df.iloc[k]['ys']), f].values[0] for k in range(len(edges_df))])
#     154
#     155     return edges_df
#
# ~\Anaconda3\envs\mlflow\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1764
#    1765             with np.errstate(all='ignore'):
# -> 1766                 res = na_op(values, other)
#    1767             if is_scalar(res):
#    1768                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\Anaconda3\envs\mlflow\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1623
#    1624         if is_object_dtype(x.dtype):
# -> 1625             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1626
#    1627         elif is_datetimelike_v_numeric(x, y):
#
# KeyboardInterrupt:

# %%
#node df
nodes_df = create_nodes_df(sn)
nodes_df.head()
# Out:
#                     Company_Name         ID    Type  Type_2
# 0               jobs united GmbH  '2004008'  seller  seller
# 1               PM Personal GmbH  '2004009'  seller  seller
# 2            inter personal GmbH  '2004016'  seller  seller
# 3  United Personal Management AG  '2004019'  seller  seller
# 4                   CDP SWISS AG  '2004004'  seller  seller

# %%
#edge df
edges_df = create_edges_df(sn, fields=[snapshot+'cd_pastdue90_r'])
edges_df.head()
# Out:
#                                 xs                 ys  \
# jobs united GmbH  jobs united GmbH    Quadroni Linard
# jobs united GmbH  jobs united GmbH    Quadroni Linard
# jobs united GmbH  jobs united GmbH    Quadroni Linard
# PM Personal GmbH  PM Personal GmbH    Style Interiors
# PM Personal GmbH  PM Personal GmbH  Elektropartner AG
#
#                                           edges_couples  \
# jobs united GmbH    (jobs united GmbH, Quadroni Linard)
# jobs united GmbH    (jobs united GmbH, Quadroni Linard)
# jobs united GmbH    (jobs united GmbH, Quadroni Linard)
# PM Personal GmbH    (PM Personal GmbH, Style Interiors)
# PM Personal GmbH  (PM Personal GmbH, Elektropartner AG)
#
#                   sshot_52_cd_pastdue90_r
# jobs united GmbH                      NaN
# jobs united GmbH                      NaN
# jobs united GmbH                      NaN
# PM Personal GmbH                      NaN
# PM Personal GmbH                      NaN

# %%
graph, edges, nodes = create_network(edges_df, nodes_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-86df4be9762d> in <module>
# ----> 1 graph, edges, nodes = create_network(edges_df, nodes_df)
#
# NameError: name 'edges_df' is not defined

# %%
#adding coordinate
pos, sizes_dict = nodes_post(nodes_df, edges_df, 'Company_Name', nxk=0.085)
nodes_df['size'] = [sizes_dict[i] for i in list(nodes_df.Company_Name)]
nodes_df.head()
# Out:
#                     Company_Name         ID    Type  Type_2       size  \
# 0               jobs united GmbH  '2004008'  seller  seller   6.325301
# 1               PM Personal GmbH  '2004009'  seller  seller   7.192771
# 2            inter personal GmbH  '2004016'  seller  seller   6.433735
# 3  United Personal Management AG  '2004019'  seller  seller  15.000000
# 4                   CDP SWISS AG  '2004004'  seller  seller   6.108434
#
#                                         coords
# 0   [0.18979007566578743, -0.6942682756546106]
# 1    [0.1460464939349956, -0.5083801205265108]
# 2   [-0.3465431580638848, -0.5401932871495295]
# 3  [-0.09831388479306391, -0.5748918496780919]
# 4   [-0.8907403757514246, 0.11913010883453203]

# %%
g = graph_from_coordinates(nodes_df, edges_df, to_highlight=snapshot+'cd_pastdue90_r')

show(g)
# Out:
#   <div class="bk-root" id="7217b64b-2f1c-4898-8f1f-f961ce71216a" data-root-id="1544"></div>

# %% [markdown]
# ### Undirected Graph

# %% [markdown]
# Flows go from buyer to seller. There are parallel edges with opposite directions for hybrid cases.
# The graph will be initially modelled as an undirected graph since some of the networkx functions don't work on directed.

# %%
g = nx.Graph() #some networkx functions only work on undirected graphs

for cus in df.customer_name_1.unique():
    for debt in df.loc[df.customer_name_1==cus, 'debtor_name_1'].unique():
        
        df_tmp = df[df.customer_name_1==cus]
        df_tmp2 = df_tmp[df_tmp.debtor_name_1==debt]
        g.add_edge(debt, cus)

# %% [markdown]
# ### 2. Adding impairment_1 features derived from bond graph formalims

# %%
df = build_bgtfeat(df,g)

# %%
df.describe()
# Out:
#        invoice_amount  purchase_amount  purchase_amount_open  \
# count    5.982000e+04     5.982000e+04          5.982000e+04
# mean     6.840900e+03     5.494234e+03          8.477222e+02
# std      2.760891e+04     2.603158e+04          1.012066e+04
# min      5.110000e+00     0.000000e+00          0.000000e+00
# 25%      1.519963e+03     4.328875e+02          0.000000e+00
# 50%      2.216450e+03     2.016150e+03          0.000000e+00
# 75%      4.221188e+03     2.871200e+03          0.000000e+00
# max      1.777910e+06     1.777910e+06          1.146584e+06
#
#        discharge_amount  document_stack_id  test_characteristic_id  \
# count       2696.000000       59820.000000             1803.000000
# mean        7384.895312        9937.816165                5.013866
# std        12381.438747        5677.861583                0.116966
# min            0.010000           1.000000                5.000000
# 25%          390.912500        5542.000000                5.000000
# 50%         2233.450000        9842.000000                5.000000
# 75%         7894.417500       14654.000000                5.000000
# max       128552.400000       19868.000000                6.000000
#
#             bill_id  purchase_examination  deduction_amount      nrecords  \
# count  59820.000000          11975.000000      47603.000000  59820.000000
# mean   37925.601204             25.601754         12.552649      2.531010
# std    21035.770834             30.181423        412.591017      1.519459
# min        1.000000              4.000000          0.000000      1.000000
# 25%    20607.750000             14.000000          0.000000      2.000000
# 50%    39460.500000             14.000000          0.000000      2.000000
# 75%    55796.250000             14.000000          0.000000      3.000000
# max    72355.000000            165.000000      33011.650000    143.000000
#
#        ...    c_repaid_r  c_impaired1_r  c_pastdue90_r  c_pastdue180_r  \
# count  ...  5.969200e+04   5.969100e+04   59690.000000    59690.000000
# mean   ...           inf            inf       0.020103        0.010856
# std    ...           NaN            NaN       0.054436        0.035920
# min    ...  0.000000e+00   0.000000e+00       0.000000        0.000000
# 25%    ...  4.556052e-01   0.000000e+00       0.000000        0.000000
# 50%    ...  6.812315e-01   3.213958e-03       0.000738        0.000000
# 75%    ...  7.870435e-01   7.037102e-03       0.010881        0.004194
# max    ...           inf            inf       1.000000        0.823529
#
#        imp_edge_eff  imp_edge_flow  imp_d_node_flow  imp_c_node_eff  \
# count  5.982000e+04   59820.000000     59820.000000    5.982000e+04
# mean   5.291119e+05       0.014529         2.347308    1.238718e+09
# std    8.885848e+05       0.059556         6.260445    1.424855e+09
# min    0.000000e+00       0.000000         0.000000    0.000000e+00
# 25%    3.446470e+04       0.000000         0.000000    2.171897e+08
# 50%    1.835365e+05       0.000000         0.000000    3.894150e+08
# 75%    6.348421e+05       0.004442         1.074920    2.226492e+09
# max    6.307533e+06       1.000346        36.305373    5.313150e+09
#
#        imp_node_flow    imp_energy
# count   59820.000000  5.982000e+04
# mean       25.118850  8.159791e+09
# std        19.305044  2.003589e+10
# min         0.000000  0.000000e+00
# 25%         5.075884  2.287730e+07
# 50%        24.886577  3.284329e+08
# 75%        42.838886  4.057329e+09
# max        66.306407  9.161020e+10
#
# [8 rows x 73 columns]

# %%
df.head().transpose()
# Out:
# uid                                                    2744:79/231  \
# customer_id                                                2004008
# customer_name_1                                      Castillo GmbH
# debtor_id                                                       79
# debtor_name_1                                    Sana Hyannis Sarl
# invoice_number                                                2744
# invoice_date                                   2013-07-23 00:00:00
# due_date                                       2013-08-02 00:00:00
# invoice_amount                                               913.7
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                             913.7
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-09 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        231
# cancellation_date                                              NaT
# value_date                                     2013-08-02 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# ...                                                            ...
# d_impaired1_c                                                    0
# d_pastdue90_c                                                    0
# d_pastdue180_c                                                   0
# d_trend_a                                                        0
# d_we_payment_share                                             NaN
# d_pd_mismatch_mean                                             NaN
# d_pd_mismatch_std                                              NaN
# d_repaid_r                                                     NaN
# d_impaired1_r                                                  NaN
# d_pastdue90_r                                                  NaN
# d_pastdue180_r                                                 NaN
# c_lent_c                                                         0
# c_repaid_c                                                       0
# c_impaired1_c                                                    0
# c_pastdue90_c                                                    0
# c_pastdue180_c                                                   0
# c_trend_a                                                        0
# c_we_payment_share                                             NaN
# c_pd_mismatch_mean                                             NaN
# c_pd_mismatch_std                                              NaN
# c_repaid_r                                                     NaN
# c_impaired1_r                                                  NaN
# c_pastdue90_r                                                  NaN
# c_pastdue180_r                                                 NaN
# imp_edge_eff                                                     0
# imp_edge_flow                                                    0
# imp_d_node_flow                                                  0
# imp_c_node_eff                                               636.3
# imp_node_flow                                               1.7703
# imp_energy                                                 15888.3
#
# uid                                                    2861:79/232  \
# customer_id                                                2004008
# customer_name_1                                      Castillo GmbH
# debtor_id                                                       79
# debtor_name_1                                    Sana Hyannis Sarl
# invoice_number                                                2861
# invoice_date                                   2013-07-30 00:00:00
# due_date                                       2013-08-09 00:00:00
# invoice_amount                                             2233.45
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                           2233.45
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-23 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        232
# cancellation_date                                              NaT
# value_date                                     2013-08-09 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# ...                                                            ...
# d_impaired1_c                                                    0
# d_pastdue90_c                                                    0
# d_pastdue180_c                                                   0
# d_trend_a                                                        0
# d_we_payment_share                                             NaN
# d_pd_mismatch_mean                                             NaN
# d_pd_mismatch_std                                              NaN
# d_repaid_r                                                       0
# d_impaired1_r                                                    0
# d_pastdue90_r                                                    0
# d_pastdue180_r                                                   0
# c_lent_c                                                         1
# c_repaid_c                                                       0
# c_impaired1_c                                                    0
# c_pastdue90_c                                                    0
# c_pastdue180_c                                                   0
# c_trend_a                                                        0
# c_we_payment_share                                             NaN
# c_pd_mismatch_mean                                             NaN
# c_pd_mismatch_std                                              NaN
# c_repaid_r                                                       0
# c_impaired1_r                                                    0
# c_pastdue90_r                                                    0
# c_pastdue180_r                                                   0
# imp_edge_eff                                                     0
# imp_edge_flow                                                    0
# imp_d_node_flow                                                  0
# imp_c_node_eff                                               636.3
# imp_node_flow                                               1.7703
# imp_energy                                                 15888.3
#
# uid                                                           2932:79/233  \
# customer_id                                                       2004008
# customer_name_1                                             Castillo GmbH
# debtor_id                                                              79
# debtor_name_1                                           Sana Hyannis Sarl
# invoice_number                                                       2932
# invoice_date                                          2013-08-06 00:00:00
# due_date                                              2013-08-16 00:00:00
# invoice_amount                                                     1370.5
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date                   [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       8
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-09-23 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               233
# cancellation_date                                                     NaT
# value_date                                            2013-08-16 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# ...                                                                   ...
# d_impaired1_c                                                           0
# d_pastdue90_c                                                           0
# d_pastdue180_c                                                          0
# d_trend_a                                                          7.1852
# d_we_payment_share                                                    NaN
# d_pd_mismatch_mean                                                    NaN
# d_pd_mismatch_std                                                     NaN
# d_repaid_r                                                              0
# d_impaired1_r                                                           0
# d_pastdue90_r                                                           0
# d_pastdue180_r                                                          0
# c_lent_c                                                                2
# c_repaid_c                                                              0
# c_impaired1_c                                                           0
# c_pastdue90_c                                                           0
# c_pastdue180_c                                                          0
# c_trend_a                                                          7.1852
# c_we_payment_share                                                    NaN
# c_pd_mismatch_mean                                                    NaN
# c_pd_mismatch_std                                                     NaN
# c_repaid_r                                                              0
# c_impaired1_r                                                           0
# c_pastdue90_r                                                           0
# c_pastdue180_r                                                          0
# imp_edge_eff                                                            0
# imp_edge_flow                                                           0
# imp_d_node_flow                                                         0
# imp_c_node_eff                                                      636.3
# imp_node_flow                                                      1.7703
# imp_energy                                                        15888.3
#
# uid                                                   1472:489/688  \
# customer_id                                                2004009
# customer_name_1                       Orpheus Wyandotte Supply LLC
# debtor_id                                                      489
# debtor_name_1                                           Isfahan SA
# invoice_number                                                1472
# invoice_date                                   2013-08-13 00:00:00
# due_date                                       2013-08-23 00:00:00
# invoice_amount                                              9195.1
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            9195.1
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-10-21 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        688
# cancellation_date                                              NaT
# value_date                                     2013-08-23 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# ...                                                            ...
# d_impaired1_c                                                    0
# d_pastdue90_c                                                    0
# d_pastdue180_c                                                   0
# d_trend_a                                                        0
# d_we_payment_share                                             NaN
# d_pd_mismatch_mean                                             NaN
# d_pd_mismatch_std                                              NaN
# d_repaid_r                                                     NaN
# d_impaired1_r                                                  NaN
# d_pastdue90_r                                                  NaN
# d_pastdue180_r                                                 NaN
# c_lent_c                                                         0
# c_repaid_c                                                       0
# c_impaired1_c                                                    0
# c_pastdue90_c                                                    0
# c_pastdue180_c                                                   0
# c_trend_a                                                        0
# c_we_payment_share                                             NaN
# c_pd_mismatch_mean                                             NaN
# c_pd_mismatch_std                                              NaN
# c_repaid_r                                                     NaN
# c_impaired1_r                                                  NaN
# c_pastdue90_r                                                  NaN
# c_pastdue180_r                                                 NaN
# imp_edge_eff                                                     0
# imp_edge_flow                                                    0
# imp_d_node_flow                                                  0
# imp_c_node_eff                                              105832
# imp_node_flow                                              2.32854
# imp_energy                                                 8015.48
#
# uid                                                          2042:512/645
# customer_id                                                       2004009
# customer_name_1                              Orpheus Wyandotte Supply LLC
# debtor_id                                                             512
# debtor_name_1                                          Aldrich Chloe GmbH
# invoice_number                                                       2042
# invoice_date                                          2013-08-13 00:00:00
# due_date                                              2013-08-23 00:00:00
# invoice_amount                                                     4594.6
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                      Kunde
# discharge_amount                                                  4430.25
# discharge_date                                        2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               645
# cancellation_date                                                     NaT
# value_date                                            2013-08-23 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# ...                                                                   ...
# d_impaired1_c                                                           0
# d_pastdue90_c                                                           0
# d_pastdue180_c                                                          0
# d_trend_a                                                               0
# d_we_payment_share                                                    NaN
# d_pd_mismatch_mean                                                    NaN
# d_pd_mismatch_std                                                     NaN
# d_repaid_r                                                            NaN
# d_impaired1_r                                                         NaN
# d_pastdue90_r                                                         NaN
# d_pastdue180_r                                                        NaN
# c_lent_c                                                                1
# c_repaid_c                                                              0
# c_impaired1_c                                                           0
# c_pastdue90_c                                                           0
# c_pastdue180_c                                                          0
# c_trend_a                                                               0
# c_we_payment_share                                                    NaN
# c_pd_mismatch_mean                                                    NaN
# c_pd_mismatch_std                                                     NaN
# c_repaid_r                                                              0
# c_impaired1_r                                                           0
# c_pastdue90_r                                                           0
# c_pastdue180_r                                                          0
# imp_edge_eff                                                            0
# imp_edge_flow                                                  0.00880136
# imp_d_node_flow                                                 0.0528082
# imp_c_node_eff                                                     105832
# imp_node_flow                                                     2.32854
# imp_energy                                                        8015.48
#
# [116 rows x 5 columns]

# %% [markdown]
# ### 3. Isolating graph components

# %%
a = nx.connected_components(g)
components = [c for c in sorted(a, key=len, reverse=True)]

# %% [markdown]
# ### 4. Directed graph

# %%
directed_graphs = create_directed_graphs(components, df, 10**6)

# %%
#dictionary of independent components
comp_dict = dict(zip(range(len(components)), directed_graphs)) #each component corresponds to a number

# %%
capacity_list = []
weight_list = []

for line in nx.generate_edgelist(comp_dict[0]):
    #print(line)
    capacity_list.append(int(line.split(':')[1].split(',')[0].strip()))
    weight_list.append(int(line.split(':')[2].split('}')[0].strip()))

# %%
sns.distplot(capacity_list, bins=50)

# %%
sns.distplot(weight_list, bins=50)

# %% [markdown]
# ### 5. hybrids and their connections

# %%
#the nodes that are both buyers and sellers
customers = df.customer_name_1.unique()
debtors = df.debtor_name_1.unique()
hybrids = [v for v in customers if v in debtors]
hybrids
# Out:
# ['Cooperative Inventors Corporation',
#  'Remington Muskegon Corporation',
#  'McKesson Gumptia Inc.',
#  'Telex Inc.',
#  'Johansen Wilhelmina Sarl',
#  'Alva Apprentices and Pigeonberries SA',
#  'Universal Societies Ltd',
#  'DARPA Elijah Co.',
#  'Katharine Corporation',
#  'Tananarive Flintlocks Inc.',
#  'Irma SA',
#  'Sioux Oslo SA',
#  'Rankine Assyria GmbH',
#  'Blvd SA',
#  'Inman Workbenches and Coquinas Co.']

# %% [markdown]
# Hybrids and debtors nodes connected to them are particularly important because they work as capacitors, and as such contribute to the diffusion of a certain credit event in the system creating a chain.
# The debtors directly connected to them can be seen as a starting point of the flow, which will be passed through the capacitors (hybrid nodes) to reach other nodes.
# The receiver nodes will be other hybrids or customers (not debtors).
# Nodes wich have the seller role alone are considered as flow sinks (the energy leaves the system through them) or accumulators (without dissipation capability).

# %%
# finding the debtor nodes connected to hybrids
connected_to_hyb = [d for d in debtors if len(node_neighborhood(g, d, 1, hybrids))>1]

# %%
len(connected_to_hyb)
# Out:
# 547

# %% [markdown]
# ### 6. Flow modelling

# %%
#all debtors connected with hybrids with sources of flow >0
df_flow_chain = df[df.debtor_name_1.isin(connected_to_hyb) & df.imp_energy>0]

# %%
conn_to_hyb_sources = df_flow_chain.debtor_name_1.unique() #nodes having flow>0 and connected to hybrids

# %%
len(conn_to_hyb_sources)
# Out:
# 528

# %%
# for each debtor node connected to hybrids, we find the maximum 'chain degree' (the last node reached by the flow of that particular source)
max_degrees = [including_degree(g, nn, hybrids, comp_dict) for nn in conn_to_hyb_sources]

# %%
#exlcuding the debtors from the last reached nodes, since only customers can accumulate/dissipate or transmit (if they are hybrids) the flow
max_degrees = pd.Series(max_degrees).apply(lambda x:(x[0], x[1], list(x[2].intersection(set(df.customer_name_1))), x[3]))

# %%
#this dictionary will have as keys the starting buyers nodes, as values tuples of (farest flow degree, last hybrid contained in the path, last nodes reached 1 degree after the last hybrids)
dict_start_end = dict(zip(conn_to_hyb_sources, max_degrees))

# %% [markdown]
# At this point each "flow path" is detected and the total flow will be computed as a "graph overlapping": for each path a new grah is created, with "sub-flow values" assigned to the respective edges.
# In order to obtain the graph containing the total flow, the sum of the subflows is used.

# %%
#create flow graphs
graphs = create_flow_graphs(dict_start_end, comp_dict)
# Out:
# 2368 graphs successfully created

# %%
#identifying graphs with flow>0 and total flow computed
pos_graphs = positive_graphs(graphs)
# Out:
# Total calculated shock flow is 1745835 over 220 graphs with positive flow value

# %%
#creating a dictionaries of flow overlaps + check
#it will contain the terminal nodes between edges having positive flow with relative flow value
sum_dict=flow_dict(graphs, pos_graphs)

# %%
#for each graph component, the flow is added at each edge as capacity
#all edges flow (addition to the sum_dict of the starting static flows as final overlap)
sum_dict=sum_of_flows(sum_dict, comp_dict)

# %%
#assigning the flow value to instruments as a new feature
for edge in sum_dict.keys():
    df.loc[(df.customer_name_1==edge[1]) & (df.debtor_name_1==edge[0]), 'flow_shock_imp1'] = sum_dict[edge]

# %%
df.head().transpose()
# Out:
# uid                                                    2744:79/231  \
# customer_id                                                2004008
# customer_name_1                                      Castillo GmbH
# debtor_id                                                       79
# debtor_name_1                                    Sana Hyannis Sarl
# invoice_number                                                2744
# invoice_date                                   2013-07-23 00:00:00
# due_date                                       2013-08-02 00:00:00
# invoice_amount                                               913.7
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                             913.7
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-09 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        231
# cancellation_date                                              NaT
# value_date                                     2013-08-02 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# ...                                                            ...
# d_pastdue90_c                                                    0
# d_pastdue180_c                                                   0
# d_trend_a                                                        0
# d_we_payment_share                                             NaN
# d_pd_mismatch_mean                                             NaN
# d_pd_mismatch_std                                              NaN
# d_repaid_r                                                     NaN
# d_impaired1_r                                                  NaN
# d_pastdue90_r                                                  NaN
# d_pastdue180_r                                                 NaN
# c_lent_c                                                         0
# c_repaid_c                                                       0
# c_impaired1_c                                                    0
# c_pastdue90_c                                                    0
# c_pastdue180_c                                                   0
# c_trend_a                                                        0
# c_we_payment_share                                             NaN
# c_pd_mismatch_mean                                             NaN
# c_pd_mismatch_std                                              NaN
# c_repaid_r                                                     NaN
# c_impaired1_r                                                  NaN
# c_pastdue90_r                                                  NaN
# c_pastdue180_r                                                 NaN
# imp_edge_eff                                                     0
# imp_edge_flow                                                    0
# imp_d_node_flow                                                  0
# imp_c_node_eff                                               636.3
# imp_node_flow                                               1.7703
# imp_energy                                                 15888.3
# flow_shock_imp1                                                  1
#
# uid                                                    2861:79/232  \
# customer_id                                                2004008
# customer_name_1                                      Castillo GmbH
# debtor_id                                                       79
# debtor_name_1                                    Sana Hyannis Sarl
# invoice_number                                                2861
# invoice_date                                   2013-07-30 00:00:00
# due_date                                       2013-08-09 00:00:00
# invoice_amount                                             2233.45
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                           2233.45
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-23 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        232
# cancellation_date                                              NaT
# value_date                                     2013-08-09 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# ...                                                            ...
# d_pastdue90_c                                                    0
# d_pastdue180_c                                                   0
# d_trend_a                                                        0
# d_we_payment_share                                             NaN
# d_pd_mismatch_mean                                             NaN
# d_pd_mismatch_std                                              NaN
# d_repaid_r                                                       0
# d_impaired1_r                                                    0
# d_pastdue90_r                                                    0
# d_pastdue180_r                                                   0
# c_lent_c                                                         1
# c_repaid_c                                                       0
# c_impaired1_c                                                    0
# c_pastdue90_c                                                    0
# c_pastdue180_c                                                   0
# c_trend_a                                                        0
# c_we_payment_share                                             NaN
# c_pd_mismatch_mean                                             NaN
# c_pd_mismatch_std                                              NaN
# c_repaid_r                                                       0
# c_impaired1_r                                                    0
# c_pastdue90_r                                                    0
# c_pastdue180_r                                                   0
# imp_edge_eff                                                     0
# imp_edge_flow                                                    0
# imp_d_node_flow                                                  0
# imp_c_node_eff                                               636.3
# imp_node_flow                                               1.7703
# imp_energy                                                 15888.3
# flow_shock_imp1                                                  1
#
# uid                                                           2932:79/233  \
# customer_id                                                       2004008
# customer_name_1                                             Castillo GmbH
# debtor_id                                                              79
# debtor_name_1                                           Sana Hyannis Sarl
# invoice_number                                                       2932
# invoice_date                                          2013-08-06 00:00:00
# due_date                                              2013-08-16 00:00:00
# invoice_amount                                                     1370.5
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date                   [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       8
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-09-23 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               233
# cancellation_date                                                     NaT
# value_date                                            2013-08-16 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# ...                                                                   ...
# d_pastdue90_c                                                           0
# d_pastdue180_c                                                          0
# d_trend_a                                                          7.1852
# d_we_payment_share                                                    NaN
# d_pd_mismatch_mean                                                    NaN
# d_pd_mismatch_std                                                     NaN
# d_repaid_r                                                              0
# d_impaired1_r                                                           0
# d_pastdue90_r                                                           0
# d_pastdue180_r                                                          0
# c_lent_c                                                                2
# c_repaid_c                                                              0
# c_impaired1_c                                                           0
# c_pastdue90_c                                                           0
# c_pastdue180_c                                                          0
# c_trend_a                                                          7.1852
# c_we_payment_share                                                    NaN
# c_pd_mismatch_mean                                                    NaN
# c_pd_mismatch_std                                                     NaN
# c_repaid_r                                                              0
# c_impaired1_r                                                           0
# c_pastdue90_r                                                           0
# c_pastdue180_r                                                          0
# imp_edge_eff                                                            0
# imp_edge_flow                                                           0
# imp_d_node_flow                                                         0
# imp_c_node_eff                                                      636.3
# imp_node_flow                                                      1.7703
# imp_energy                                                        15888.3
# flow_shock_imp1                                                         1
#
# uid                                                   1472:489/688  \
# customer_id                                                2004009
# customer_name_1                       Orpheus Wyandotte Supply LLC
# debtor_id                                                      489
# debtor_name_1                                           Isfahan SA
# invoice_number                                                1472
# invoice_date                                   2013-08-13 00:00:00
# due_date                                       2013-08-23 00:00:00
# invoice_amount                                              9195.1
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            9195.1
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-10-21 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        688
# cancellation_date                                              NaT
# value_date                                     2013-08-23 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# ...                                                            ...
# d_pastdue90_c                                                    0
# d_pastdue180_c                                                   0
# d_trend_a                                                        0
# d_we_payment_share                                             NaN
# d_pd_mismatch_mean                                             NaN
# d_pd_mismatch_std                                              NaN
# d_repaid_r                                                     NaN
# d_impaired1_r                                                  NaN
# d_pastdue90_r                                                  NaN
# d_pastdue180_r                                                 NaN
# c_lent_c                                                         0
# c_repaid_c                                                       0
# c_impaired1_c                                                    0
# c_pastdue90_c                                                    0
# c_pastdue180_c                                                   0
# c_trend_a                                                        0
# c_we_payment_share                                             NaN
# c_pd_mismatch_mean                                             NaN
# c_pd_mismatch_std                                              NaN
# c_repaid_r                                                     NaN
# c_impaired1_r                                                  NaN
# c_pastdue90_r                                                  NaN
# c_pastdue180_r                                                 NaN
# imp_edge_eff                                                     0
# imp_edge_flow                                                    0
# imp_d_node_flow                                                  0
# imp_c_node_eff                                              105832
# imp_node_flow                                              2.32854
# imp_energy                                                 8015.48
# flow_shock_imp1                                                  1
#
# uid                                                          2042:512/645
# customer_id                                                       2004009
# customer_name_1                              Orpheus Wyandotte Supply LLC
# debtor_id                                                             512
# debtor_name_1                                          Aldrich Chloe GmbH
# invoice_number                                                       2042
# invoice_date                                          2013-08-13 00:00:00
# due_date                                              2013-08-23 00:00:00
# invoice_amount                                                     4594.6
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                      Kunde
# discharge_amount                                                  4430.25
# discharge_date                                        2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               645
# cancellation_date                                                     NaT
# value_date                                            2013-08-23 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# ...                                                                   ...
# d_pastdue90_c                                                           0
# d_pastdue180_c                                                          0
# d_trend_a                                                               0
# d_we_payment_share                                                    NaN
# d_pd_mismatch_mean                                                    NaN
# d_pd_mismatch_std                                                     NaN
# d_repaid_r                                                            NaN
# d_impaired1_r                                                         NaN
# d_pastdue90_r                                                         NaN
# d_pastdue180_r                                                        NaN
# c_lent_c                                                                1
# c_repaid_c                                                              0
# c_impaired1_c                                                           0
# c_pastdue90_c                                                           0
# c_pastdue180_c                                                          0
# c_trend_a                                                               0
# c_we_payment_share                                                    NaN
# c_pd_mismatch_mean                                                    NaN
# c_pd_mismatch_std                                                     NaN
# c_repaid_r                                                              0
# c_impaired1_r                                                           0
# c_pastdue90_r                                                           0
# c_pastdue180_r                                                          0
# imp_edge_eff                                                            0
# imp_edge_flow                                                  0.00880136
# imp_d_node_flow                                                 0.0528082
# imp_c_node_eff                                                     105832
# imp_node_flow                                                     2.32854
# imp_energy                                                        8015.48
# flow_shock_imp1                                                         1
#
# [117 rows x 5 columns]

# %% [markdown]
# ## Flow graph modelling for pastdue90 (repeating the above process for pastdue_90)

# %%
edge_effort_2 = df.groupby(['customer_name_1', 'debtor_name_1']).apply(lambda x:np.nansum(x.payment_date_mismatch))

# %%
df['p90_edge_eff'] = [edge_effort_2[(df.loc[i, 'customer_name_1'], df.loc[i, 'debtor_name_1'])] for i in df.index]
df['p90_edge_eff'] = df['p90_edge_eff'].replace([np.inf, -np.inf, np.nan], 0)
df['p90_edge_flow'] = df.cd_pastdue90_r.replace([np.inf, -np.inf, np.nan], 0)

# %%
df = build_bgtfeat(df, g, edge_flow='p90_edge_flow', edge_eff='p90_edge_eff', node_flow='p90_node_flow', energy='p90_energy',
                      c_node_eff='p90_c_node_eff', d_node_flow='p90_d_node_flow')

# %%
df.p90_energy.describe()
# Out:
# count    5.982000e+04
# mean     1.706477e+07
# std      7.644637e+07
# min     -1.154616e+06
# 25%      0.000000e+00
# 50%      3.975117e+03
# 75%      3.664372e+05
# max      3.717419e+08
# Name: p90_energy, dtype: float64

# %%
directed_graphs_p90 = create_directed_graphs(components, df, 10**4, 'p90_energy')

#dictionary of independent components
comp_dict_p90 = dict(zip(range(len(components)), directed_graphs_p90)) #each component corresponds to a number

#all debtors connected with hybrids with sources of flow >0
df_flow_chain2 = df[df.debtor_name_1.isin(connected_to_hyb) & df.p90_energy>0] 
conn_to_hyb_sources_p90 = df_flow_chain2.debtor_name_1.unique() #nodes having flow>0 and connected to hybrids

# for each debtor node connected to hybrids, we find the maximum 'chain degree' (the last node reached by the flow of that particular source)
max_degrees_p90 = [including_degree(g, nn, hybrids, comp_dict_p90) for nn in conn_to_hyb_sources]

#exlcuding the debtors from the last reached nodes, since only customers can accumulate/dissipate or transmit (if they are hybrids) the flow
max_degrees_p90 = pd.Series(max_degrees_p90).apply(lambda x:(x[0], x[1], list(x[2].intersection(set(df.customer_name_1))), x[3]))

#this dictionary will have as keys the starting buyers nodes, as values tuples of (farest flow degree, last hybrid contained in the path, last nodes reached 1 degree after the last hybrids)
dict_start_end_p90 = dict(zip(conn_to_hyb_sources_p90, max_degrees_p90))

#flow graphs
graphs_p90 = create_flow_graphs(dict_start_end_p90, comp_dict_p90)

#graphs with positive flows
pos_graphs_p90 = positive_graphs(graphs_p90)

#dictionary of sums of sub-flows
sum_dict_p90=flow_dict(graphs_p90, pos_graphs_p90)

#dictionary of total flow at each edge
sum_dict_p90=sum_of_flows(sum_dict_p90, comp_dict_p90)
# Out:
# ERROR 1 : there were problems with path McKesson Gumptia Inc.  -  National Binds Corporation of length 2 in component 24
# ERROR 2 : there were problems with path Mesozoic Paleozoic GmbH  -  National Binds Corporation of length 2 in component 24
# ERROR 3 : there were problems with path Marty Ltd  -  National Binds Corporation of length 2 in component 24
# ERROR 4 : there were problems with path Boucher Siegfried LLC  -  National Binds Corporation of length 2 in component 24
# ERROR 5 : there were problems with path Leslie Inc.  -  National Binds Corporation of length 2 in component 24
# ERROR 6 : there were problems with path Jewett Lares Sarl  -  Remington Muskegon Corporation of length 1 in component 24
# ERROR 7 : there were problems with path Jewett Lares Sarl  -  National Binds Corporation of length 1 in component 24
# 1745 graphs successfully created
# 1745 graphs successfully created
# Total calculated shock flow is 224041 over 147 graphs with positive flow value

# %%
#assigning the flow value for pastdue_90 to instruments as a new feature
for edge in sum_dict_p90.keys():
    df.loc[(df.customer_name_1==edge[1]) & (df.debtor_name_1==edge[0]), 'flow_shock_p90'] = sum_dict_p90[edge]

# %%
df.head()
# Out:
#              customer_id               customer_name_1 debtor_id  \
# uid
# 2744:79/231      2004008                 Castillo GmbH        79
# 2861:79/232      2004008                 Castillo GmbH        79
# 2932:79/233      2004008                 Castillo GmbH        79
# 1472:489/688     2004009  Orpheus Wyandotte Supply LLC       489
# 2042:512/645     2004009  Orpheus Wyandotte Supply LLC       512
#
#                    debtor_name_1 invoice_number invoice_date   due_date  \
# uid
# 2744:79/231    Sana Hyannis Sarl           2744   2013-07-23 2013-08-02
# 2861:79/232    Sana Hyannis Sarl           2861   2013-07-30 2013-08-09
# 2932:79/233    Sana Hyannis Sarl           2932   2013-08-06 2013-08-16
# 1472:489/688          Isfahan SA           1472   2013-08-13 2013-08-23
# 2042:512/645  Aldrich Chloe GmbH           2042   2013-08-13 2013-08-23
#
#               invoice_amount  purchase_amount  purchase_amount_open  ...  \
# uid                                                                  ...
# 2744:79/231           913.70              0.0                   0.0  ...
# 2861:79/232          2233.45              0.0                   0.0  ...
# 2932:79/233          1370.50              0.0                   0.0  ...
# 1472:489/688         9195.10              0.0                   0.0  ...
# 2042:512/645         4594.60              0.0                   0.0  ...
#
#              imp_node_flow    imp_energy flow_shock_imp1 p90_edge_eff  \
# uid
# 2744:79/231       1.770299  15888.322025             1.0        897.0
# 2861:79/232       1.770299  15888.322025             1.0        897.0
# 2932:79/233       1.770299  15888.322025             1.0        897.0
# 1472:489/688      2.328539   8015.477380             1.0          0.0
# 2042:512/645      2.328539   8015.477380             1.0       1752.0
#
#              p90_edge_flow  p90_d_node_flow p90_c_node_eff p90_node_flow  \
# uid
# 2744:79/231            0.0              0.0       239912.0      0.000000
# 2861:79/232            0.0              0.0       239912.0      0.000000
# 2932:79/233            0.0              0.0       239912.0      0.000000
# 1472:489/688           0.0              0.0       234247.0      1.665866
# 2042:512/645           0.0              0.0       234247.0      1.665866
#
#                  p90_energy flow_shock_p90
# uid
# 2744:79/231        0.000000            1.0
# 2861:79/232        0.000000            1.0
# 2932:79/233        0.000000            1.0
# 1472:489/688  366437.206374           36.0
# 2042:512/645  366437.206374           36.0
#
# [5 rows x 124 columns]

# %% [markdown]
# ## Flow graph modelling for pastdue180

# %%
#in this case the effort will be the same as pastdue_90, so that will be used
df['p180_edge_flow'] = df.cd_pastdue180_r.replace([np.inf, -np.inf, np.nan], 0)

# %%
df = build_bgtfeat(df, g, edge_flow='p180_edge_flow', edge_eff='p90_edge_eff', node_flow='p180_node_flow', energy='p180_energy',
                      c_node_eff='p180_c_node_eff', d_node_flow='p180_d_node_flow')

directed_graphs_p180 = create_directed_graphs(components, df, 10**5, 'p180_energy')

#dictionary of independent components
comp_dict_p180 = dict(zip(range(len(components)), directed_graphs_p180)) #each component corresponds to a number

#all debtors connected with hybrids with sources of flow >0
df_flow_chain3 = df[df.debtor_name_1.isin(connected_to_hyb) & df.p180_energy>0] 
conn_to_hyb_sources_p180 = df_flow_chain3.debtor_name_1.unique() #nodes having flow>0 and connected to hybrids

# for each debtor node connected to hybrids, we find the maximum 'chain degree' (the last node reached by the flow of that particular source)
max_degrees_p180 = [including_degree(g, nn, hybrids, comp_dict_p180) for nn in conn_to_hyb_sources]

#exlcuding the debtors from the last reached nodes, since only customers can accumulate/dissipate or transmit (if they are hybrids) the flow
max_degrees_p180 = pd.Series(max_degrees_p180).apply(lambda x:(x[0], x[1], list(x[2].intersection(set(df.customer_name_1))), x[3]))

#this dictionary will have as keys the starting buyers nodes, as values tuples of (farest flow degree, last hybrid contained in the path, last nodes reached 1 degree after the last hybrids)
dict_start_end_p180 = dict(zip(conn_to_hyb_sources_p180, max_degrees_p180))

#flow graphs
graphs_p180 = create_flow_graphs(dict_start_end_p180, comp_dict_p180)

#graphs with positive flows
pos_graphs_p180 = positive_graphs(graphs_p180)

#dictionary of sums of sub-flows
sum_dict_p180=flow_dict(graphs_p180, pos_graphs_p180)

#dictionary of total flow at each edge
sum_dict_p180=sum_of_flows(sum_dict_p180, comp_dict_p180)
# Out:
# ERROR 1 : there were problems with path Boucher Siegfried LLC  -  National Binds Corporation of length 2 in component 24
# ERROR 2 : there were problems with path Amalgamated Evils Co.  -  National Binds Corporation of length 2 in component 24
# ERROR 3 : there were problems with path Leslie Inc.  -  National Binds Corporation of length 2 in component 24
# ERROR 4 : there were problems with path Minsk Kieffer Sarl  -  National Binds Corporation of length 2 in component 24
# ERROR 5 : there were problems with path Beloit Ltd  -  National Binds Corporation of length 2 in component 24
# ERROR 6 : there were problems with path Federated Worrisomes Corporation  -  Remington Muskegon Corporation of length 1 in component 24
# ERROR 7 : there were problems with path Federated Worrisomes Corporation  -  National Binds Corporation of length 1 in component 24
# 1276 graphs successfully created
# 1276 graphs successfully created
# Total calculated shock flow is 1322 over 116 graphs with positive flow value

# %%
#assigning the flow value to instruments as a new feature
for edge in sum_dict_p180.keys():
    df.loc[(df.customer_name_1==edge[1]) & (df.debtor_name_1==edge[0]), 'flow_shock_p180'] = sum_dict[edge]

# %%
df.head().transpose()
# Out:
# uid                                                    2744:79/231  \
# customer_id                                                2004008
# customer_name_1                                      Castillo GmbH
# debtor_id                                                       79
# debtor_name_1                                    Sana Hyannis Sarl
# invoice_number                                                2744
# invoice_date                                   2013-07-23 00:00:00
# due_date                                       2013-08-02 00:00:00
# invoice_amount                                               913.7
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                             913.7
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-09 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        231
# cancellation_date                                              NaT
# value_date                                     2013-08-02 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# ...                                                            ...
# c_pastdue90_c                                                    0
# c_pastdue180_c                                                   0
# c_trend_a                                                        0
# c_we_payment_share                                             NaN
# c_pd_mismatch_mean                                             NaN
# c_pd_mismatch_std                                              NaN
# c_repaid_r                                                     NaN
# c_impaired1_r                                                  NaN
# c_pastdue90_r                                                  NaN
# c_pastdue180_r                                                 NaN
# imp_edge_eff                                                     0
# imp_edge_flow                                                    0
# imp_d_node_flow                                                  0
# imp_c_node_eff                                               636.3
# imp_node_flow                                               1.7703
# imp_energy                                                 15888.3
# flow_shock_imp1                                                  1
# p90_edge_eff                                                   897
# p90_edge_flow                                                    0
# p90_d_node_flow                                                  0
# p90_c_node_eff                                              239912
# p90_node_flow                                                    0
# p90_energy                                                       0
# flow_shock_p90                                                   1
# p180_edge_flow                                                   0
# p180_d_node_flow                                                 0
# p180_c_node_eff                                             239912
# p180_node_flow                                                   0
# p180_energy                                                      0
# flow_shock_p180                                                  1
#
# uid                                                    2861:79/232  \
# customer_id                                                2004008
# customer_name_1                                      Castillo GmbH
# debtor_id                                                       79
# debtor_name_1                                    Sana Hyannis Sarl
# invoice_number                                                2861
# invoice_date                                   2013-07-30 00:00:00
# due_date                                       2013-08-09 00:00:00
# invoice_amount                                             2233.45
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                           2233.45
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-23 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        232
# cancellation_date                                              NaT
# value_date                                     2013-08-09 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# ...                                                            ...
# c_pastdue90_c                                                    0
# c_pastdue180_c                                                   0
# c_trend_a                                                        0
# c_we_payment_share                                             NaN
# c_pd_mismatch_mean                                             NaN
# c_pd_mismatch_std                                              NaN
# c_repaid_r                                                       0
# c_impaired1_r                                                    0
# c_pastdue90_r                                                    0
# c_pastdue180_r                                                   0
# imp_edge_eff                                                     0
# imp_edge_flow                                                    0
# imp_d_node_flow                                                  0
# imp_c_node_eff                                               636.3
# imp_node_flow                                               1.7703
# imp_energy                                                 15888.3
# flow_shock_imp1                                                  1
# p90_edge_eff                                                   897
# p90_edge_flow                                                    0
# p90_d_node_flow                                                  0
# p90_c_node_eff                                              239912
# p90_node_flow                                                    0
# p90_energy                                                       0
# flow_shock_p90                                                   1
# p180_edge_flow                                                   0
# p180_d_node_flow                                                 0
# p180_c_node_eff                                             239912
# p180_node_flow                                                   0
# p180_energy                                                      0
# flow_shock_p180                                                  1
#
# uid                                                           2932:79/233  \
# customer_id                                                       2004008
# customer_name_1                                             Castillo GmbH
# debtor_id                                                              79
# debtor_name_1                                           Sana Hyannis Sarl
# invoice_number                                                       2932
# invoice_date                                          2013-08-06 00:00:00
# due_date                                              2013-08-16 00:00:00
# invoice_amount                                                     1370.5
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date                   [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       8
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-09-23 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               233
# cancellation_date                                                     NaT
# value_date                                            2013-08-16 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# ...                                                                   ...
# c_pastdue90_c                                                           0
# c_pastdue180_c                                                          0
# c_trend_a                                                          7.1852
# c_we_payment_share                                                    NaN
# c_pd_mismatch_mean                                                    NaN
# c_pd_mismatch_std                                                     NaN
# c_repaid_r                                                              0
# c_impaired1_r                                                           0
# c_pastdue90_r                                                           0
# c_pastdue180_r                                                          0
# imp_edge_eff                                                            0
# imp_edge_flow                                                           0
# imp_d_node_flow                                                         0
# imp_c_node_eff                                                      636.3
# imp_node_flow                                                      1.7703
# imp_energy                                                        15888.3
# flow_shock_imp1                                                         1
# p90_edge_eff                                                          897
# p90_edge_flow                                                           0
# p90_d_node_flow                                                         0
# p90_c_node_eff                                                     239912
# p90_node_flow                                                           0
# p90_energy                                                              0
# flow_shock_p90                                                          1
# p180_edge_flow                                                          0
# p180_d_node_flow                                                        0
# p180_c_node_eff                                                    239912
# p180_node_flow                                                          0
# p180_energy                                                             0
# flow_shock_p180                                                         1
#
# uid                                                   1472:489/688  \
# customer_id                                                2004009
# customer_name_1                       Orpheus Wyandotte Supply LLC
# debtor_id                                                      489
# debtor_name_1                                           Isfahan SA
# invoice_number                                                1472
# invoice_date                                   2013-08-13 00:00:00
# due_date                                       2013-08-23 00:00:00
# invoice_amount                                              9195.1
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            9195.1
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-10-21 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        688
# cancellation_date                                              NaT
# value_date                                     2013-08-23 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# ...                                                            ...
# c_pastdue90_c                                                    0
# c_pastdue180_c                                                   0
# c_trend_a                                                        0
# c_we_payment_share                                             NaN
# c_pd_mismatch_mean                                             NaN
# c_pd_mismatch_std                                              NaN
# c_repaid_r                                                     NaN
# c_impaired1_r                                                  NaN
# c_pastdue90_r                                                  NaN
# c_pastdue180_r                                                 NaN
# imp_edge_eff                                                     0
# imp_edge_flow                                                    0
# imp_d_node_flow                                                  0
# imp_c_node_eff                                              105832
# imp_node_flow                                              2.32854
# imp_energy                                                 8015.48
# flow_shock_imp1                                                  1
# p90_edge_eff                                                     0
# p90_edge_flow                                                    0
# p90_d_node_flow                                                  0
# p90_c_node_eff                                              234247
# p90_node_flow                                              1.66587
# p90_energy                                                  366437
# flow_shock_p90                                                  36
# p180_edge_flow                                                   0
# p180_d_node_flow                                                 0
# p180_c_node_eff                                             234247
# p180_node_flow                                             0.54333
# p180_energy                                                 119515
# flow_shock_p180                                                  1
#
# uid                                                          2042:512/645
# customer_id                                                       2004009
# customer_name_1                              Orpheus Wyandotte Supply LLC
# debtor_id                                                             512
# debtor_name_1                                          Aldrich Chloe GmbH
# invoice_number                                                       2042
# invoice_date                                          2013-08-13 00:00:00
# due_date                                              2013-08-23 00:00:00
# invoice_amount                                                     4594.6
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                      Kunde
# discharge_amount                                                  4430.25
# discharge_date                                        2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               645
# cancellation_date                                                     NaT
# value_date                                            2013-08-23 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# ...                                                                   ...
# c_pastdue90_c                                                           0
# c_pastdue180_c                                                          0
# c_trend_a                                                               0
# c_we_payment_share                                                    NaN
# c_pd_mismatch_mean                                                    NaN
# c_pd_mismatch_std                                                     NaN
# c_repaid_r                                                              0
# c_impaired1_r                                                           0
# c_pastdue90_r                                                           0
# c_pastdue180_r                                                          0
# imp_edge_eff                                                            0
# imp_edge_flow                                                  0.00880136
# imp_d_node_flow                                                 0.0528082
# imp_c_node_eff                                                     105832
# imp_node_flow                                                     2.32854
# imp_energy                                                        8015.48
# flow_shock_imp1                                                         1
# p90_edge_eff                                                         1752
# p90_edge_flow                                                           0
# p90_d_node_flow                                                         0
# p90_c_node_eff                                                     234247
# p90_node_flow                                                     1.66587
# p90_energy                                                         366437
# flow_shock_p90                                                         36
# p180_edge_flow                                                          0
# p180_d_node_flow                                                        0
# p180_c_node_eff                                                    234247
# p180_node_flow                                                    0.54333
# p180_energy                                                        119515
# flow_shock_p180                                                         1
#
# [130 rows x 5 columns]

# %%
df.to_pickle(datafolder+'04_instrumentsdf_bondgraph.pkl')
