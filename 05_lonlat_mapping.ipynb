# %% [markdown]
# # Longitude and latitude mapping

# %% [markdown]
# This notebook starts from the file generated at step 4 ('04_geocoding.ipynb' - notebook) and its aim is to map the longitude and latitude information retrieved to the provided portfolio of companies which are forming the supply chain network.

# %% [markdown]
# ### Data import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import os

# %%
#Instruments dataset
#import data
user = os.environ["USERNAME"]
filename = "190108_buyer.pkl"
filename2 = "company_info.pkl"
datafolder = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/".format(user)
ReportDate = datetime.datetime(2018, 9, 28) #reference date on which data are received - all due dates after report date are related to open instruments

buyer = pd.read_pickle(datafolder+filename)
cinfo = pd.read_pickle(datafolder+filename2)
buyer.head()
# Out:
#                               customer_id  customer_name_1  debtor_id  uid  \
# debtor_name_1
# 1A Swiss Dienstleistungen AG            1                1          1    5
# 3-Team                                  1                1          1    1
# 36GRAD GmbH                             3                3          2  127
# 3A Schreinerei                          1                1          1    1
# 3TECH SA                                1                1          1  367
#
#                               has_impairment1  has_impairment2  is_pastdue90  \
# debtor_name_1
# 1A Swiss Dienstleistungen AG              1.0              0.0           0.0
# 3-Team                                    0.0              0.0           0.0
# 36GRAD GmbH                               0.0              0.0           0.0
# 3A Schreinerei                            1.0              0.0           0.0
# 3TECH SA                                  0.0              0.0           0.0
#
#                               is_pastdue180  has_prosecution  is_open
# debtor_name_1
# 1A Swiss Dienstleistungen AG            0.0              0.0      0.0
# 3-Team                                  0.0              0.0      0.0
# 36GRAD GmbH                             0.0              0.0     23.0
# 3A Schreinerei                          0.0              0.0      0.0
# 3TECH SA                                0.0              0.0      0.0

# %%
buyer.index
# Out:
# Index(['1A Swiss Dienstleistungen AG', '3-Team', '36GRAD GmbH',
#        '3A Schreinerei', '3TECH SA', '4B Fenster AG',
#        '54 Sports Fröhlicher GmbH', 'A+R PROFILSTAHL ALLGEIER',
#        'A-Renovation SA', 'A-Team Bodenbeläge AG',
#        ...
#        'rore GmbH', 'steil & flach GmbH', 'swiss marketing academy',
#        'swisspro NW AG', 'südlich-t AG', 'tesa Werk Offenburg GmbH',
#        'triarc laboratories Ltd.', 'valantic Business Anlaytics Swiss AG',
#        'Österreichische Botschaft Bern',
#        'Österreichische Wirtschaftsdelegation'],
#       dtype='object', name='debtor_name_1', length=3234)

# %%
lat=[]
lon=[]
missing = []
for name in buyer.index:
    if name in list(cinfo["Debitorenname 1"]):
        lon.append(cinfo.loc[cinfo["Debitorenname 1"]==name, 'longitude'])
        lat.append(cinfo.loc[cinfo["Debitorenname 1"]==name, 'latitude'])
    else:
        print("{} is not in the geodata dataframe".format(name))
        missing.append(name)
# Out:
# 3-Team is not in the geodata dataframe
# 3A Schreinerei is not in the geodata dataframe
# A-Team Bodenbeläge AG is not in the geodata dataframe
# A. Geiser is not in the geodata dataframe
# A. Röllin Dächer & Fassaden AG is not in the geodata dataframe
# A. Schleiss AG is not in the geodata dataframe
# ABS Service GmbH is not in the geodata dataframe
# AF Hauswartung GmbH is not in the geodata dataframe
# AHMED SEDDIQI + SONS is not in the geodata dataframe
# AIO-Solar GmbH is not in the geodata dataframe
# APAG IMMO GmbH is not in the geodata dataframe
# APN Raum und Boden is not in the geodata dataframe
# ARGE BM Meret -Oppenheim is not in the geodata dataframe
# ARGE Brienzersee-Tunnels is not in the geodata dataframe
# ART Bodenbelag is not in the geodata dataframe
# AarElement AG is not in the geodata dataframe
# Aebischer Demenagement et Transport SARL is not in the geodata dataframe
# Agostino Ca,pana & Co is not in the geodata dataframe
# Air Five AG is not in the geodata dataframe
# Albert Fäh GmbH is not in the geodata dataframe
# Albin Borer AG is not in the geodata dataframe
# All-Inn Bodenbeläge GmbH is not in the geodata dataframe
# Alpsols Sàrl Duroni is not in the geodata dataframe
# Alrama AG is not in the geodata dataframe
# Altorfer AG is not in the geodata dataframe
# Amir Murati is not in the geodata dataframe
# Amir Sivic is not in the geodata dataframe
# Anderegg AG is not in the geodata dataframe
# Andreas Giger is not in the geodata dataframe
# Anker Jean-Pierre is not in the geodata dataframe
# Antalis AG is not in the geodata dataframe
# Antikhaus Historische Fenter is not in the geodata dataframe
# Anton Fercher Stahl-und Metallbau AG is not in the geodata dataframe
# Arco Gebäudeunterhalt Werner Aemisegger is not in the geodata dataframe
# Arnold Heizung  / Sanitär AG is not in the geodata dataframe
# Arnold Philipp Maler AG is not in the geodata dataframe
# Arondo AG is not in the geodata dataframe
# Arredamenti Poretti Roberto is not in the geodata dataframe
# ArteBoden AG is not in the geodata dataframe
# Arteflo SA is not in the geodata dataframe
# Atelier Brunart is not in the geodata dataframe
# Avatron Swiss AG is not in the geodata dataframe
# Avenso GmbH is not in the geodata dataframe
# Axom GmbH is not in the geodata dataframe
# Azzoun Adraina is not in the geodata dataframe
# B+L Bodensysteme Ag is not in the geodata dataframe
# B. Braun Medical AG is not in the geodata dataframe
# BEKA Schiffbau & Geländewagen GmbH is not in the geodata dataframe
# BHS Gebäudeschutz GmbH is not in the geodata dataframe
# BID - G. Millwater AG is not in the geodata dataframe
# Baby-Rose Werlen GmbH is not in the geodata dataframe
# Bacciarini Lorenzo is not in the geodata dataframe
# Bacher Peter is not in the geodata dataframe
# Badrutt's Palace Hotel AG is not in the geodata dataframe
# Baeflor Raumkonzept mit Design is not in the geodata dataframe
# Bardelli AG is not in the geodata dataframe
# Basile Giuseppe & Co. Malergeschäft is not in the geodata dataframe
# Basler Leben AG is not in the geodata dataframe
# Bativer SA is not in the geodata dataframe
# Baukonzept Zwahlen AG is not in the geodata dataframe
# Baumgartner Schreinerei AG Holz-/Innenausbau is not in the geodata dataframe
# Bauschreinerei Brüschweiler GmbH is not in the geodata dataframe
# Bautherm Fassaden AG is not in the geodata dataframe
# Beat Betschart GmbH is not in the geodata dataframe
# Belevo AG is not in the geodata dataframe
# Ben-Teppiche AG is not in the geodata dataframe
# Beni Senn is not in the geodata dataframe
# Benteler Rothrist AG is not in the geodata dataframe
# Benz Hauswirth AG is not in the geodata dataframe
# Berger Innendekorationen is not in the geodata dataframe
# Bernasconi is not in the geodata dataframe
# Bernet O. AG is not in the geodata dataframe
# Bernhard Boden AG is not in the geodata dataframe
# Bernhard Rohrer is not in the geodata dataframe
# Bertschmann  AG is not in the geodata dataframe
# Betten-Züri AG is not in the geodata dataframe
# Bieler Böden & Vorhänge is not in the geodata dataframe
# Bigla Offfice AG is not in the geodata dataframe
# Bildungsgemeinschaft Metallbau GmbH is not in the geodata dataframe
# Binna Holzbau AG is not in the geodata dataframe
# Birchmeier AG is not in the geodata dataframe
# Birchmeier Bau AG is not in the geodata dataframe
# Bisang Holzbau AG is not in the geodata dataframe
# Blechtech AG is not in the geodata dataframe
# Blendi Sàrl is not in the geodata dataframe
# Boder Remo is not in the geodata dataframe
# Bohrfix AG is not in the geodata dataframe
# Boller Giuseppe is not in the geodata dataframe
# Bopp AG is not in the geodata dataframe
# Borella & Fils Décoration is not in the geodata dataframe
# Brigger AG is not in the geodata dataframe
# Brodbeck AG is not in the geodata dataframe
# Brunner Fachmarkt AG is not in the geodata dataframe
# Brönnimann AG is not in the geodata dataframe
# Brügger HTB GmbH is not in the geodata dataframe
# Burri Möbel is not in the geodata dataframe
# Busch SA Morrens is not in the geodata dataframe
# Buser Lukas is not in the geodata dataframe
# Bären Elektro AG is not in the geodata dataframe
# Bärenzaun AG is not in the geodata dataframe
# Bürkli Boden AG is not in the geodata dataframe
# CASA Wiederkehr GmbH is not in the geodata dataframe
# CEPV Centre d' enseigmement is not in the geodata dataframe
# CSA Pavimenti Sagl is not in the geodata dataframe
# California Stores is not in the geodata dataframe
# Carelli e Ricci Sagl is not in the geodata dataframe
# Carlo Carigiet is not in the geodata dataframe
# Casa Tessuti is not in the geodata dataframe
# Casatex Zürich is not in the geodata dataframe
# Caviezel AG is not in the geodata dataframe
# Centrale des Achats et Prestations Sàrl is not in the geodata dataframe
# Chabon Sellerie is not in the geodata dataframe
# Challet Philippe is not in the geodata dataframe
# Charles-Emile Moinat & Fils SA is not in the geodata dataframe
# Chevalley Pierre is not in the geodata dataframe
# Chez Rüfi  AG is not in the geodata dataframe
# Christian Müller is not in the geodata dataframe
# Clair Net is not in the geodata dataframe
# Clientis Bank is not in the geodata dataframe
# Coiffina AG is not in the geodata dataframe
# Comme à la Maison is not in the geodata dataframe
# Comte Ameublement is not in the geodata dataframe
# Consortium TC Diablerets-Mazots is not in the geodata dataframe
# Corali SA is not in the geodata dataframe
# Cortat Jean-Claude is not in the geodata dataframe
# Cortinas Reichlin Partners AG is not in the geodata dataframe
# Cotting Daniel is not in the geodata dataframe
# Coupy Pierre-André et Marie -Madeleine is not in the geodata dataframe
# Curic Bassi Sagl is not in the geodata dataframe
# Curtainfay GmbH is not in the geodata dataframe
# DC Revêtements de sols is not in the geodata dataframe
# DD Haustechnik GmbH is not in the geodata dataframe
# DEVEN SA is not in the geodata dataframe
# DZZ Druckzentrum Bern AG is not in the geodata dataframe
# Dachdecker-Meister Schweiz AG is not in the geodata dataframe
# Dado Plinio is not in the geodata dataframe
# Dagani Bruno is not in the geodata dataframe
# Daniel Stern is not in the geodata dataframe
# De Luca Isolationen AG is not in the geodata dataframe
# Decolab GmbH is not in the geodata dataframe
# Decorint Biel Sàrl is not in the geodata dataframe
# Decorint Biel Särl is not in the geodata dataframe
# Decors 200 is not in the geodata dataframe
# Delaloye Isabelle is not in the geodata dataframe
# Dell'Oca Baukeramik GmbH is not in the geodata dataframe
# Demiri Gartenbau GmbH is not in the geodata dataframe
# Demuth AG is not in the geodata dataframe
# Dini Parket AG is not in the geodata dataframe
# Districlean SA is not in the geodata dataframe
# Donato Russo SAGL is not in the geodata dataframe
# Duroni Alpsols Sàrl is not in the geodata dataframe
# Dätwyler Lignoplast AG is not in the geodata dataframe
# Découverte SA is not in the geodata dataframe
# E. + A. Keramik GmbH is not in the geodata dataframe
# E. In-Albon AG is not in the geodata dataframe
# E. Jörg AG is not in the geodata dataframe
# E. Nüesch-Kuster + Co. is not in the geodata dataframe
# E3 HLK AG is not in the geodata dataframe
# EE Bau AG is not in the geodata dataframe
# EGLI Strassen- und Tiefbau is not in the geodata dataframe
# EKH-Thun is not in the geodata dataframe
# ELCA Informatik AG is not in the geodata dataframe
# ETHEMI Haustechnik GmbH is not in the geodata dataframe
# ETS Installationen AG is not in the geodata dataframe
# Eberhard Bühnen AG is not in the geodata dataframe
# Eduard Meier Plattenbeläge AG is not in the geodata dataframe
# Egli Pius is not in the geodata dataframe
# Egli Wohnen AG is not in the geodata dataframe
# Egloff Handwerk is not in the geodata dataframe
# Egora GmbH is not in the geodata dataframe
# Einkaufspartner AG is not in the geodata dataframe
# Elektro Neidhart AG is not in the geodata dataframe
# Elektro Stirnimann AG is not in the geodata dataframe
# Elektro Support Team GmbH is not in the geodata dataframe
# Elektro-Bau AG Rothrist is not in the geodata dataframe
# Eniwa AG is not in the geodata dataframe
# Ergostyle SA is not in the geodata dataframe
# Eric Woestelandt Deco is not in the geodata dataframe
# Espace Concept Sàrl is not in the geodata dataframe
# Euromaster Schlieren is not in the geodata dataframe
# Eyer Beat is not in the geodata dataframe
# F. Duttweiler AG is not in the geodata dataframe
# Farine Décpration Sàrl is not in the geodata dataframe
# Felder AG is not in the geodata dataframe
# Felix Barandun is not in the geodata dataframe
# Fischer + Hostettler AG is not in the geodata dataframe
# Fissatex AG is not in the geodata dataframe
# Foffa Conrad Holzbau AG is not in the geodata dataframe
# Folino Ponte Giovanni Malergeschäft is not in the geodata dataframe
# Fortuna Personalberatung GmbH is not in the geodata dataframe
# Fp consulting is not in the geodata dataframe
# Franz Hasenböhler AG is not in the geodata dataframe
# Frau Diana Stroe is not in the geodata dataframe
# Friche Gérald + Fabienne is not in the geodata dataframe
# Fritz Kaufmann is not in the geodata dataframe
# Frutiger Holzbau AG is not in the geodata dataframe
# Fröhlich Sortiertechnik GmbH is not in the geodata dataframe
# G.L.W SA is not in the geodata dataframe
# GENERAL PEINTURE SA is not in the geodata dataframe
# GIELLE Srl is not in the geodata dataframe
# GLM Gipserei Lüthi + Moser GmBH is not in the geodata dataframe
# GRILL PRIZRENI SA is not in the geodata dataframe
# Gasser + Bertschy Elektro AG is not in the geodata dataframe
# Gebrüder Beugger GmbH is not in the geodata dataframe
# Gebrüder Maissen AG is not in the geodata dataframe
# Gebrüder Rolf und Kurt Saxer is not in the geodata dataframe
# Gebrüder Wenger AG is not in the geodata dataframe
# Generalbau SLJ GmbH is not in the geodata dataframe
# Georges Fracheboud Sa is not in the geodata dataframe
# Gepart AG is not in the geodata dataframe
# Gibag Renovations GmbH is not in the geodata dataframe
# Gipser Ortiz GmbH is not in the geodata dataframe
# Gipser- und Malergenossenschaft Bern is not in the geodata dataframe
# Gipsergeschäft Reimann Anton AG is not in the geodata dataframe
# Gisi Com AG is not in the geodata dataframe
# Glaus + Söhne AG is not in the geodata dataframe
# Google Switzerland GmbH is not in the geodata dataframe
# Grand Hotel Engadiner Kulm AG is not in the geodata dataframe
# Grand Hotel LES TROIS ROIS is not in the geodata dataframe
# Greub AG is not in the geodata dataframe
# Grisoni-Zaugg SA is not in the geodata dataframe
# Groupe Deco -Bat SA is not in the geodata dataframe
# Gruenenwald Fritz is not in the geodata dataframe
# Gruyéria SA is not in the geodata dataframe
# Grütter Innenausbau is not in the geodata dataframe
# Gschwind & Co. is not in the geodata dataframe
# Guy Fracheboud SA is not in the geodata dataframe
# Guédat Denis is not in the geodata dataframe
# Gysel Hansueli is not in the geodata dataframe
# Gärtner Bodenbeläge is not in the geodata dataframe
# Gübeli Sanitär AG is not in the geodata dataframe
# H. Müller Elekro AG is not in the geodata dataframe
# H.Rosenberger GmbH is not in the geodata dataframe
# HAUSENBAUR Holzbau AG is not in the geodata dataframe
# HBF Inotech is not in the geodata dataframe
# HKM SA is not in the geodata dataframe
# HLK Heizung Lüftung Klima AG is not in the geodata dataframe
# HT Haustechnik AG is not in the geodata dataframe
# Haas Daniel is not in the geodata dataframe
# Hakama AG is not in the geodata dataframe
# Halter + Colledani AG is not in the geodata dataframe
# Handte AG is not in the geodata dataframe
# Hans Hassler AG is not in the geodata dataframe
# Hans Müller Elektro AG is not in the geodata dataframe
# Hauri - Hunziker Esther is not in the geodata dataframe
# Heinz Freitag AG is not in the geodata dataframe
# Helvesko AG is not in the geodata dataframe
# Herzog Haustechnik  AG Luzern is not in the geodata dataframe
# Hilber + Giger ElektroCon GmbH is not in the geodata dataframe
# Hilti Möbel Raumgestaltungs-AG is not in the geodata dataframe
# Hobi Wohnschreinerei AG is not in the geodata dataframe
# Holzbauwerk AG Mühleberg is not in the geodata dataframe
# Holzlabor is not in the geodata dataframe
# Huber AG is not in the geodata dataframe
# Häcki Oswald is not in the geodata dataframe
# Hälg + Co. AG is not in the geodata dataframe
# Häni Komplettumbauten is not in the geodata dataframe
# Hänngi AG Basel is not in the geodata dataframe
# Hüfi's Renovationen is not in the geodata dataframe
# IBS Systemhaus AG is not in the geodata dataframe
# IMK Institut für Medizin und Kommunikation AG is not in the geodata dataframe
# IPElements Sàrl is not in the geodata dataframe
# Ilag Bau AG is not in the geodata dataframe
# Inbau Handwerker AG is not in the geodata dataframe
# Industisol Suisse Sàrl is not in the geodata dataframe
# Inside Inneneinrichtungen  AG is not in the geodata dataframe
# Instafair Jöhl Elektro GmbH is not in the geodata dataframe
# Interdecorationen Deyhle is not in the geodata dataframe
# Interieur Giacometti is not in the geodata dataframe
# Intertapis AG is not in the geodata dataframe
# Intérieur Création is not in the geodata dataframe
# InwOdek Bodenbeläge is not in the geodata dataframe
# Ioan Varga is not in the geodata dataframe
# Isidori Pavimenti is not in the geodata dataframe
# Isoteam Dämmtechnik GmbH is not in the geodata dataframe
# Ital'Parquet Sàrl is not in the geodata dataframe
# JB-Teppich-Handels GmbH is not in the geodata dataframe
# Jacquement Paul is not in the geodata dataframe
# Jacques Dubuis is not in the geodata dataframe
# Jaeger & Bosshard SA is not in the geodata dataframe
# Jakob Fritz is not in the geodata dataframe
# Janam SA is not in the geodata dataframe
# Jauss Lorena is not in the geodata dataframe
# Jemoli AG is not in the geodata dataframe
# Johnny Zerbini is not in the geodata dataframe
# Josef Vogt AG is not in the geodata dataframe
# Jucker AG is not in the geodata dataframe
# Julius Glatz GmbH is not in the geodata dataframe
# Jörimann Schreinerei AG is not in the geodata dataframe
# K. Studer AG is not in the geodata dataframe
# KIGIPS AG is not in the geodata dataframe
# KITA- und Kinderkrippeneinrichtungen is not in the geodata dataframe
# KV Zürich is not in the geodata dataframe
# Kammermann Bodenbeläge is not in the geodata dataframe
# Karo-Line SA is not in the geodata dataframe
# Keller & Marquart AG is not in the geodata dataframe
# Keravita AG is not in the geodata dataframe
# Kistler Innovativ Bau GmbH is not in the geodata dataframe
# Klauser Wetter Metallbau AG is not in the geodata dataframe
# Kleinstein Otto is not in the geodata dataframe
# Kloster Einsiedeln is not in the geodata dataframe
# Knutti AG is not in the geodata dataframe
# Kobal Gebäudetechnik AG is not in the geodata dataframe
# Kocer Parkett & Reinigungen GmbH is not in the geodata dataframe
# Komaco is not in the geodata dataframe
# Kompatech GmbH is not in the geodata dataframe
# Konzeptbau is not in the geodata dataframe
# Kramer GmbH is not in the geodata dataframe
# Krasotec Invest AG is not in the geodata dataframe
# Krüsi Küchen AG is not in the geodata dataframe
# Kueng Siegfried is not in the geodata dataframe
# Kurt Haupt Inh. André Ramelet is not in the geodata dataframe
# Kurz - Technik GmbH is not in the geodata dataframe
# Küffer Schnreiner AG is not in the geodata dataframe
# L Traub Bau GmbH is not in the geodata dataframe
# L'Artisan Schaffter SA is not in the geodata dataframe
# LES ATELIERS LOUIS MOINE is not in the geodata dataframe
# LESI AG is not in the geodata dataframe
# Lake and Mountain View is not in the geodata dataframe
# Lauber SA is not in the geodata dataframe
# Lauclair AG is not in the geodata dataframe
# Le Républicain Lorrain is not in the geodata dataframe
# Learning Culture AG is not in the geodata dataframe
# Leutenegger AG is not in the geodata dataframe
# Lieberherr F. is not in the geodata dataframe
# Linus Beer Plattenbeläge is not in the geodata dataframe
# Lotti Partner AG is not in the geodata dataframe
# Ludovik Bibaj GmbH is not in the geodata dataframe
# Luedi Heinrich is not in the geodata dataframe
# M. Crettenand-Filliez is not in the geodata dataframe
# M.Müller Parkett und Bodenbeläge is not in the geodata dataframe
# MC Décoration is not in the geodata dataframe
# MC Schweiz AG is not in the geodata dataframe
# MDT Moderer Druck & Technik Ag is not in the geodata dataframe
# MIB Protection GmbH is not in the geodata dataframe
# MIRO Gipsergeschäft AG is not in the geodata dataframe
# Maars Schweiz AG is not in the geodata dataframe
# Madörin der Erste AG is not in the geodata dataframe
# Maendly Jean-Daniel is not in the geodata dataframe
# Magnin Décoration is not in the geodata dataframe
# Maio Malergeschäft AG is not in the geodata dataframe
# Maler A. Laurito GmbH is not in the geodata dataframe
# Maler Gipser Steiner is not in the geodata dataframe
# Maler- + Gipsergenossenschaft Biel is not in the geodata dataframe
# Malerei-Gipserei Mäder AG is not in the geodata dataframe
# Malergeschäft Ferati GmbH is not in the geodata dataframe
# Marit AG Bauholding is not in the geodata dataframe
# Marius Bächler AG is not in the geodata dataframe
# Marquesdécosols is not in the geodata dataframe
# Marthaler Heinrich is not in the geodata dataframe
# Martin Bold is not in the geodata dataframe
# Maréchaux Elektro AG Sursee is not in the geodata dataframe
# Masserey Intérieur SA is not in the geodata dataframe
# Mathez Intèrieur is not in the geodata dataframe
# Maurer AG Buchs is not in the geodata dataframe
# Max Hauri AG is not in the geodata dataframe
# Mayer IMBAU is not in the geodata dataframe
# Meag AG is not in the geodata dataframe
# Meichtry Bodenbeläge GmbH is not in the geodata dataframe
# Meierhofer Inox AG is not in the geodata dataframe
# Melly André is not in the geodata dataframe
# Menuiserie Art du Bois is not in the geodata dataframe
# Menuiserie Cortat & Fils Sàrl is not in the geodata dataframe
# Menétrey-Lausanne SA is not in the geodata dataframe
# Merz AG Gipserunternehmung is not in the geodata dataframe
# Metorol AG is not in the geodata dataframe
# Metzgerei Safiental is not in the geodata dataframe
# Meubles Kolly is not in the geodata dataframe
# Michel Scarangella is not in the geodata dataframe
# Michel Taramarcaz Sàrl is not in the geodata dataframe
# Michel+ Jenni AG is not in the geodata dataframe
# Mo.ser & Gaffuri Pavimenti Sagl is not in the geodata dataframe
# Mondialmoquette SA is not in the geodata dataframe
# Moquette- Boson Jacky is not in the geodata dataframe
# Moret Décoration Sàrl is not in the geodata dataframe
# Morisod SA Constructions is not in the geodata dataframe
# Moser Gartengestaltung AG is not in the geodata dataframe
# Muster Bedachungen AG is not in the geodata dataframe
# Muster René is not in the geodata dataframe
# Mutti Wohnideen is not in the geodata dataframe
# Möbel Bürgy Ag is not in the geodata dataframe
# Möbel Pfister AG is not in the geodata dataframe
# Möbel Schwaller is not in the geodata dataframe
# Möbel Schwyter AG is not in the geodata dataframe
# Möbelhalle Bern is not in the geodata dataframe
# Möri Metallbau AG is not in the geodata dataframe
# Mösching Forst GmbH is not in the geodata dataframe
# Müller Martin is not in the geodata dataframe
# N. Schirmer AG is not in the geodata dataframe
# NU-BAU AG is not in the geodata dataframe
# Nardi S. Tino is not in the geodata dataframe
# Neeser Schreinerei  AG is not in the geodata dataframe
# Netto Einkaufsgruppe AG is not in the geodata dataframe
# Neuenschwander - Neutair AG is not in the geodata dataframe
# Neukomm AG is not in the geodata dataframe
# Neuweiler AG is not in the geodata dataframe
# Nobs GmbH is not in the geodata dataframe
# Norm + Mass AG is not in the geodata dataframe
# Number 1 Complex GmbH is not in the geodata dataframe
# Näpflin Jo is not in the geodata dataframe
# Näpflin Mario is not in the geodata dataframe
# O. Tschanz AG is not in the geodata dataframe
# Obersee Metallbau GmbH is not in the geodata dataframe
# Odermatt-Akkord GmbH is not in the geodata dataframe
# Odgers Berndtson AG is not in the geodata dataframe
# Oppikofer Stahl- und Metallbau AG is not in the geodata dataframe
# Ossig Phillip is not in the geodata dataframe
# PS Schweiz AG is not in the geodata dataframe
# Padula Bodenbeläge is not in the geodata dataframe
# Parkett Liniger GmbH is not in the geodata dataframe
# Parkett Nadig is not in the geodata dataframe
# Parkett Umrbicht GmbH is not in the geodata dataframe
# Parquets Gardelle Sàrl is not in the geodata dataframe
# Paul Brunner Bodenbeläge GmbH is not in the geodata dataframe
# Paul Schmid is not in the geodata dataframe
# Paul Suter Kundenmalerei is not in the geodata dataframe
# Pereal Küchenstudio AG is not in the geodata dataframe
# Persy Gerüstbau GmbH is not in the geodata dataframe
# Peter Ivan is not in the geodata dataframe
# Peter Odermatt Holzbau GmbH is not in the geodata dataframe
# Peter Spring AG is not in the geodata dataframe
# Pfammater Maler und Gipser AG is not in the geodata dataframe
# Pfister Ladenbau AG is not in the geodata dataframe
# Pintus Pavimenti Sagl is not in the geodata dataframe
# Plaslica Sàrl M. Linder is not in the geodata dataframe
# Pluvina AG is not in the geodata dataframe
# Poenina Holding AG is not in the geodata dataframe
# Polartherm AG is not in the geodata dataframe
# QualiFenster GmbH is not in the geodata dataframe
# Quasim Palushi is not in the geodata dataframe
# Quickline AG is not in the geodata dataframe
# R. Guldimann GmbH is not in the geodata dataframe
# Ramani Gazmend is not in the geodata dataframe
# Ramseier Fassadenbau- und Holzbau AG is not in the geodata dataframe
# Rapid Autoglas Wallisellen is not in the geodata dataframe
# Reale Immoinvest GmbH is not in the geodata dataframe
# Rebotech GmbH is not in the geodata dataframe
# Reformierte Kirchgemeinde Fluntern is not in the geodata dataframe
# Reliable Fire Sprinkler GmbH is not in the geodata dataframe
# Reutebuch Rita is not in the geodata dataframe
# Rhomberg Bahntechnik GmbH Zweigniederlassung ZH is not in the geodata dataframe
# Rhyner Haushalt Multimedia AG is not in the geodata dataframe
# Riget AG is not in the geodata dataframe
# Rodari Pavimenti is not in the geodata dataframe
# Rodriguesols Sàrö is not in the geodata dataframe
# Rolladen AG is not in the geodata dataframe
# Rossier Paul is not in the geodata dataframe
# Roth AG Malters is not in the geodata dataframe
# Russo + Partner GmbH is not in the geodata dataframe
# Rénovation + Intérieurs is not in the geodata dataframe
# Rösch Steinger Kronenberg Elektro AG is not in the geodata dataframe
# SAN Anlagenbau GmbH is not in the geodata dataframe
# SB-RED Sàrl is not in the geodata dataframe
# SCHWAB-SYSTEM -John Schwab SA is not in the geodata dataframe
# SOS Jantes KC Sàrl is not in the geodata dataframe
# SR Décoration is not in the geodata dataframe
# SVALE-BAU GmbH is not in the geodata dataframe
# SWISS CONFECTION is not in the geodata dataframe
# Saluz Vorhangsysteme is not in the geodata dataframe
# Sandra Schuler is not in the geodata dataframe
# Savisol Sàrl is not in the geodata dataframe
# Schaad + Partner is not in the geodata dataframe
# Schachenmann AG is not in the geodata dataframe
# Schluchter is not in the geodata dataframe
# Schlumpf is not in the geodata dataframe
# Schmid & Co is not in the geodata dataframe
# Schmid Janutin AG is not in the geodata dataframe
# Schmid Paul is not in the geodata dataframe
# Schmidlin  AG is not in the geodata dataframe
# Schneider Dämmertechnik AG is not in the geodata dataframe
# Schnellmann Albert is not in the geodata dataframe
# Schreinerei Geiser AG is not in the geodata dataframe
# Schreinerei Glaserei Pfister GmbH is not in the geodata dataframe
# Schreinerei Lerch GmbH is not in the geodata dataframe
# Schreinerei Uffer AG is not in the geodata dataframe
# Schreinerei Zangger GmbH is not in the geodata dataframe
# Schriber Elektro AG is not in the geodata dataframe
# Schuermann AG is not in the geodata dataframe
# Schuler Steiger Partner is not in the geodata dataframe
# Schumacher Werner GmbH is not in the geodata dataframe
# Schumibaut is not in the geodata dataframe
# Schwarz Parkett- Bodenbeläge GmbH is not in the geodata dataframe
# Schweizerische Bundesbahnen SBB is not in the geodata dataframe
# Schäppi & Meier AG is not in the geodata dataframe
# Schärer Blitzgerüst AG is not in the geodata dataframe
# Schärer Jacques AG is not in the geodata dataframe
# See+Gaster Elektro AG is not in the geodata dataframe
# Seifriz AG is not in the geodata dataframe
# Sekisui Slveo AG is not in the geodata dataframe
# Shefki Tahiri is not in the geodata dataframe
# Siltex AG is not in the geodata dataframe
# Simon Germann is not in the geodata dataframe
# Simond Claude is not in the geodata dataframe
# Sipaec S.A. is not in the geodata dataframe
# Sirivatana Interprint Public Campany Ltd. is not in the geodata dataframe
# Soba Inter is not in the geodata dataframe
# Société des Mines de Paparko (SOMITA) is not in the geodata dataframe
# Somazzi Dario Materiali da Costruzione SA is not in the geodata dataframe
# Sonnentuch AG is not in the geodata dataframe
# Sottas SA is not in the geodata dataframe
# Spiller AG is not in the geodata dataframe
# Spirit Market GmbH is not in the geodata dataframe
# Staedler Ag is not in the geodata dataframe
# Stahl & Traumfabrik AG is not in the geodata dataframe
# Stefano Ponti is not in the geodata dataframe
# Steiert AG is not in the geodata dataframe
# Steiger Gartenbau GmbH is not in the geodata dataframe
# Stiftung Klimaschutz und is not in the geodata dataframe
# Stocker Gartenbau GmbH is not in the geodata dataframe
# Stohr Wohneinrichtung AG is not in the geodata dataframe
# Stoppani AG is not in the geodata dataframe
# Strasky Agnes is not in the geodata dataframe
# Strasser AG Thun is not in the geodata dataframe
# StreetNet GmbH is not in the geodata dataframe
# Stucco and more GmbH is not in the geodata dataframe
# Stucortec  AG is not in the geodata dataframe
# Sutter Kurt is not in the geodata dataframe
# SweDeltaco AB is not in the geodata dataframe
# Swiss Immo Capital AG is not in the geodata dataframe
# Swiss Optima AG is not in the geodata dataframe
# TCS Sektion Zürich is not in the geodata dataframe
# TEBS OFFICE AG is not in the geodata dataframe
# TEO BAU GmbH is not in the geodata dataframe
# TRAVECO Transporte AG is not in the geodata dataframe
# Tally Weijl Switzerland AG is not in the geodata dataframe
# Tanne is not in the geodata dataframe
# Tapis Jordan SA is not in the geodata dataframe
# Telkomatik Schweiz GmbH is not in the geodata dataframe
# Teppich Amacher AG is not in the geodata dataframe
# Teppich Center 51 AG is not in the geodata dataframe
# Teppich Metzger GmbH is not in the geodata dataframe
# Teppich Quelle AG is not in the geodata dataframe
# Teppich Schneider+ Co. Möbel-Vorhänge-Parkett is not in the geodata dataframe
# Teppich- Express is not in the geodata dataframe
# Teppich-Galerie Center is not in the geodata dataframe
# Teppiche Meichtry is not in the geodata dataframe
# Teppichhaus Milchbuck GmbH is not in the geodata dataframe
# Tepppich-Galerie Paul Cartier AG is not in the geodata dataframe
# The Beautiful Design Sarl is not in the geodata dataframe
# Theo Hotz Partner AG is not in the geodata dataframe
# Therm-Isol AG is not in the geodata dataframe
# Thiébaud + Perritaz SA is not in the geodata dataframe
# Thomas Furrer AG is not in the geodata dataframe
# Thomas Sabo GmbH is not in the geodata dataframe
# Thomet Gerard is not in the geodata dataframe
# Trendlein AG is not in the geodata dataframe
# Trenovag AG is not in the geodata dataframe
# Tuwag Immobilien AG is not in the geodata dataframe
# Ulrich Pulver AG is not in the geodata dataframe
# Urs Walther AG is not in the geodata dataframe
# VZ revêtements Sàrl is not in the geodata dataframe
# Vallelian Georges is not in the geodata dataframe
# Vassalli Marco is not in the geodata dataframe
# Verein Institution Barbara Keller is not in the geodata dataframe
# Vicari Alessandro is not in the geodata dataframe
# Villat Meubles SA is not in the geodata dataframe
# Vischer, Merkt & Partner AG is not in the geodata dataframe
# Vitor Freitas Goncalves is not in the geodata dataframe
# Vock Interieur is not in the geodata dataframe
# Vögeli AG is not in the geodata dataframe
# W. Grieder AG is not in the geodata dataframe
# Walter Ott AG is not in the geodata dataframe
# Walti Haustechnik GmbH is not in the geodata dataframe
# Wan-Jet AG is not in the geodata dataframe
# Wanger Malergeschäft is not in the geodata dataframe
# Wanner Bau AG is not in the geodata dataframe
# Wanzenried Bau AG is not in the geodata dataframe
# Wasta AG is not in the geodata dataframe
# Weingartner + Meier Holzbau AG is not in the geodata dataframe
# Werlen GmbH Baby-Rose is not in the geodata dataframe
# Werner Krebs AG is not in the geodata dataframe
# Wider SA Montreux is not in the geodata dataframe
# Winet AG is not in the geodata dataframe
# Winkelmann Peter is not in the geodata dataframe
# Winkler Bodenleger AG is not in the geodata dataframe
# Wissmann Maler AG is not in the geodata dataframe
# Wohn Collection Stofer GmbH is not in the geodata dataframe
# Wohnatelier René Christen is not in the geodata dataframe
# Wohnhandwerk is not in the geodata dataframe
# Wohnteam Collection is not in the geodata dataframe
# Wood Living AG is not in the geodata dataframe
# Wyser Tägerwilen GmbH is not in the geodata dataframe
# Wyttenbach Ulrich is not in the geodata dataframe
# Xyloforme SA is not in the geodata dataframe
# Yerly Pierre-Alain is not in the geodata dataframe
# ZARGES GmbH, Weilheim is not in the geodata dataframe
# ZR Zurich Relocation AG is not in the geodata dataframe
# Zanolari AG is not in the geodata dataframe
# Zbinden Hans is not in the geodata dataframe
# Zbinden Marcel  Fils Sàrl is not in the geodata dataframe
# Zervudachi Antiquités SA is not in the geodata dataframe
# Ziegler Isolierungen is not in the geodata dataframe
# Ziehli AG is not in the geodata dataframe
# Zimmerei-Abbund AG is not in the geodata dataframe
# Zurbuchen Spenglerei + Bedachungen AG is not in the geodata dataframe
# anplaq ag is not in the geodata dataframe
# atelier bpunkt GmbH is not in the geodata dataframe
# boden-dirket .ch ind GmbH is not in the geodata dataframe
# brinergarten gmbh is not in the geodata dataframe
# dachschaden.ch GmbH is not in the geodata dataframe
# fiba Liegenschaften GmbH is not in the geodata dataframe

# %%
len(lon)
# Out:
# 2633

# %%
len(lat)
# Out:
# 2633

# %%
len(missing)
# Out:
# 601
