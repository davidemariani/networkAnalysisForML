# %% [markdown]
# # Benchmark model - Impairment - Timewise Exploration, calibration, test

# %% [markdown]
# This notebook uses as inputs the outputs from the pipeline ('05_preproc_pipeline_1.ipynb' notebook) and performs model calibration and general exploration for the transaction credit events prediction.

# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.model_selection import cross_val_predict, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import precision_recall_curve, roc_curve, roc_auc_score, confusion_matrix, make_scorer, accuracy_score
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from scripts_viz.visualization_utils import *
from scripts_ml.models_utils import *

from bokeh.io import show, output_notebook
output_notebook()

import datetime as dt
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### TRAIN Data import

# %%
#importing data
prefix = 'time_2018-04-30_p90_bg_'
trainfile = '_traindata'
testfile = '_testdata'
postfix = '_190812_1316'
preproc_folder = "enriched_time"
datafolder = "../data/preproc_traintest/"+preproc_folder+'/'

[X_train, y_train, feature_labels] = pd.read_pickle(datafolder+prefix+trainfile+postfix+'.pkl') 
[X_test, y_test, feature_labels] = pd.read_pickle(datafolder+prefix+testfile+postfix+'.pkl')

# %%
y_train.shape
# Out:
# (46101,)

# %%
X_train_df = pd.DataFrame(X_train, columns=feature_labels)
X_train_df.head()
# Out:
#    currency_Schweizer Franken  currency_Euro  currency_US-Dollar  \
# 0                    0.325154      -0.312102           -0.071579
# 1                    0.325154      -0.312102           -0.071579
# 2                    0.325154      -0.312102           -0.071579
# 3                    0.325154      -0.312102           -0.071579
# 4                    0.325154      -0.312102           -0.071579
#
#    currency_Britisches Pfund  has_purchase  dd_value_date  cd_lent_c  \
# 0                  -0.041954     -2.159195       0.581487  -0.604370
# 1                  -0.041954     -2.159195       0.581487  -0.596487
# 2                  -0.041954     -2.159195       0.581487  -0.588605
# 3                  -0.041954     -2.159195       0.581487  -0.604370
# 4                  -0.041954     -2.159195       0.581487  -0.604370
#
#    cd_repaid_c  cd_impaired1_c  cd_pastdue90_c  ...  flow_shock_p90  \
# 0    -0.511071          -0.193       -0.189484  ...       -0.202693
# 1    -0.511071          -0.193       -0.189484  ...       -0.202693
# 2    -0.511071          -0.193       -0.189484  ...       -0.202693
# 3    -0.511071          -0.193       -0.189484  ...       -0.196984
# 4    -0.511071          -0.193       -0.189484  ...       -0.196984
#
#    p90_c_node_eff  p90_energy  p90_d_node_flow  flow_shock_p180  \
# 0       -0.522908   -0.203621        -0.314066         -0.39019
# 1       -0.522908   -0.203621        -0.314066         -0.39019
# 2       -0.522908   -0.203621        -0.314066         -0.39019
# 3       -0.523175   -0.196832        -0.314066         -0.39019
# 4       -0.523175   -0.196832        -0.314066         -0.39019
#
#    p180_d_node_flow  p180_energy  invoice_amount  purchase_amount  \
# 0         -0.297678    -0.201604       -0.845852        -2.113662
# 1         -0.297678    -0.201604       -0.161609        -2.113662
# 2         -0.297678    -0.201604       -0.535479        -2.113662
# 3         -0.297678    -0.193546        0.921729        -2.113662
# 4         -0.297678    -0.193546        0.390604        -2.113662
#
#    invoice_date
# 0     -4.071457
# 1     -4.071457
# 2     -4.071457
# 3     -4.071457
# 4     -4.071457
#
# [5 rows x 35 columns]

# %%
X_train_df.columns
# Out:
# Index(['currency_Schweizer Franken', 'currency_Euro', 'currency_US-Dollar',
#        'currency_Britisches Pfund', 'has_purchase', 'dd_value_date',
#        'cd_lent_c', 'cd_repaid_c', 'cd_impaired1_c', 'cd_pastdue90_c',
#        'cd_trend_a', 'c_lent_c', 'c_repaid_c', 'c_impaired1_c',
#        'c_pastdue90_c', 'c_trend_a', 'd_repaid_c', 'd_impaired1_c',
#        'd_pastdue90_c', 'd_trend_a', 'd_we_payment_share', 'flow_shock_imp1',
#        'imp_c_node_eff', 'imp_energy', 'imp_d_node_flow', 'flow_shock_p90',
#        'p90_c_node_eff', 'p90_energy', 'p90_d_node_flow', 'flow_shock_p180',
#        'p180_d_node_flow', 'p180_energy', 'invoice_amount', 'purchase_amount',
#        'invoice_date'],
#       dtype='object')

# %%
X_train_df.describe().transpose()
# Out:
#                               count          mean       std       min  \
# currency_Schweizer Franken  46101.0  7.281693e-09  1.000011 -3.075465
# currency_Euro               46101.0 -4.170425e-08  1.000011 -0.312102
# currency_US-Dollar          46101.0 -3.971833e-09  1.000011 -0.071579
# currency_Britisches Pfund   46101.0 -9.267610e-09  1.000011 -0.041954
# has_purchase                46101.0  5.560566e-08  1.000011 -2.159195
# dd_value_date               46101.0  1.853522e-08  1.000011 -0.170477
# cd_lent_c                   46101.0  0.000000e+00  1.000011 -0.604370
# cd_repaid_c                 46101.0  0.000000e+00  1.000011 -0.511071
# cd_impaired1_c              46101.0 -2.647889e-08  1.000011 -0.193000
# cd_pastdue90_c              46101.0  2.118311e-08  1.000011 -0.189484
# cd_trend_a                  46101.0  1.125353e-08  1.000011 -3.777575
# c_lent_c                    46101.0  1.059155e-08  1.000011 -1.029539
# c_repaid_c                  46101.0 -1.059155e-08  1.000011 -0.875688
# c_impaired1_c               46101.0 -1.059155e-08  1.000011 -0.642260
# c_pastdue90_c               46101.0 -3.177466e-08  1.000011 -0.433954
# c_trend_a                   46101.0  1.323944e-08  1.000011 -4.005668
# d_repaid_c                  46101.0 -1.588733e-08  1.000011 -0.553805
# d_impaired1_c               46101.0 -2.647889e-08  1.000011 -0.211706
# d_pastdue90_c               46101.0 -4.236622e-08  1.000011 -0.191233
# d_trend_a                   46101.0 -1.787325e-08  1.000011 -3.779020
# d_we_payment_share          46101.0 -2.647889e-08  1.000011 -0.213661
# flow_shock_imp1             46101.0 -1.588733e-08  1.000011 -0.390190
# imp_c_node_eff              46101.0  1.059155e-08  1.000011 -0.900958
# imp_energy                  46101.0 -5.295777e-09  1.000011 -0.432100
# imp_d_node_flow             46101.0  1.522536e-08  1.000011 -0.403961
# flow_shock_p90              46101.0 -1.853522e-08  1.000011 -0.202693
# p90_c_node_eff              46101.0  1.059155e-08  1.000011 -0.948581
# p90_energy                  46101.0 -5.295777e-09  1.000011 -0.225010
# p90_d_node_flow             46101.0 -1.059155e-08  1.000011 -0.314066
# flow_shock_p180             46101.0 -1.588733e-08  1.000011 -0.390190
# p180_d_node_flow            46101.0 -5.295777e-09  1.000011 -0.297678
# p180_energy                 46101.0 -5.295777e-09  1.000011 -0.249383
# invoice_amount              46101.0  1.985917e-09  1.000011 -4.005940
# purchase_amount             46101.0 -1.952818e-08  1.000011 -2.113662
# invoice_date                46101.0 -2.118311e-08  1.000011 -4.071457
#
#                                  25%       50%       75%        max
# currency_Schweizer Franken  0.325154  0.325154  0.325154   0.325154
# currency_Euro              -0.312102 -0.312102 -0.312102   3.204080
# currency_US-Dollar         -0.071579 -0.071579 -0.071579  13.970486
# currency_Britisches Pfund  -0.041954 -0.041954 -0.041954  23.835859
# has_purchase                0.463136  0.463136  0.463136   0.463136
# dd_value_date              -0.170477 -0.170477 -0.170477  79.964493
# cd_lent_c                  -0.557074 -0.446717  0.026240   4.140315
# cd_repaid_c                -0.511071 -0.435532 -0.079420   4.248518
# cd_impaired1_c             -0.193000 -0.193000 -0.193000   7.905553
# cd_pastdue90_c             -0.189484 -0.189484 -0.189484   8.024996
# cd_trend_a                 -0.693179 -0.025400  0.734599   3.731169
# c_lent_c                   -0.796781 -0.352049  0.528065   3.092552
# c_repaid_c                 -0.798560 -0.356937  0.452913   3.499491
# c_impaired1_c              -0.642260 -0.393988  0.226692   4.719173
# c_pastdue90_c              -0.433954 -0.433954 -0.209457   4.568787
# c_trend_a                  -0.662543  0.086838  0.748480   4.005528
# d_repaid_c                 -0.553805 -0.440525 -0.018299   4.190884
# d_impaired1_c              -0.211706 -0.211706 -0.211706   7.624601
# d_pastdue90_c              -0.191233 -0.191233 -0.191233   8.179377
# d_trend_a                  -0.704095 -0.009886  0.727287   3.763662
# d_we_payment_share         -0.213661 -0.213661  0.114410  10.227529
# flow_shock_imp1            -0.388737 -0.338600 -0.200136   5.285230
# imp_c_node_eff             -0.745505 -0.593675  0.692642   2.901902
# imp_energy                 -0.430201 -0.368365 -0.197521   4.347161
# imp_d_node_flow            -0.403961 -0.403961 -0.193142   4.256800
# flow_shock_p90             -0.202693 -0.202693 -0.197637   5.181361
# p90_c_node_eff             -0.495688 -0.446006 -0.358298   3.547769
# p90_energy                 -0.203621 -0.203547 -0.197552   5.176191
# p90_d_node_flow            -0.314066 -0.314066 -0.314066   4.870568
# flow_shock_p180            -0.388737 -0.338600 -0.200136   5.285230
# p180_d_node_flow           -0.297678 -0.297678 -0.297678   5.608221
# p180_energy                -0.201604 -0.201604 -0.197712   5.174272
# invoice_amount             -0.419396 -0.155158  0.604420   4.006089
# purchase_amount             0.174603  0.405798  0.511452   1.576640
# invoice_date               -0.490265  0.277222  0.694767   1.327049

# %%
sns.heatmap(X_train_df.corr())

# %% [markdown]
# ### SGD Classifier

# %%
#Linear model Stochastic Gradient Descent
sgd_clf = SGDClassifier(random_state=42, max_iter=250, loss='log', tol=0.0001) 
sgd_clf.fit(X_train, y_train)
sgd_clf_diag = model_diag_seq(sgd_clf, X_train, y_train, train_window=12000, test_window=3000)
# Out:
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.7884314732716167
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.7966665106044291
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.7924590584597984
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.8100512481401883
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.858714206856883
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.6215258281864121
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.8746297774230736
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.8394722558557055
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.8776363832209705
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.871000117411174
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.7880638465443964
# Validation AUC 0.793

# %%
y_score_sgd = sgd_clf.predict(X_test)
cm = confusion_matrix(y_test, y_score_sgd)
print(cm)
sgd_test_diag = model_oostest(sgd_clf,X_test, y_test)
sgd_test_auc = plot_rocs([sgd_clf_diag, sgd_test_diag], p_width=600, p_height=600, model_appendix=['SGD - seq_valid','SGD - test'])
show(sgd_test_auc)
# Out:
# [[10399   897]
#  [  131    91]]
# Confusion matrix:
# [[0.92059 0.07941]
#  [0.0116  0.00806]]
# AUC 0.744
#   <div class="bk-root" id="1156bc46-3be1-480b-93a6-fa0d258ba0ee" data-root-id="1005"></div>

# %%
#save_sk_model(sgd_clf, "../data/models/", 'sgd', 'benchmark')

# %%
scoring = {"AUC": "roc_auc", "Accuracy": make_scorer(accuracy_score)}

# max Number of iterations
max_iter = [100, 180, 200, 250, 300, 320, 350] 
# learning rate
learning_rate = ['constant', 'optimal', 'adaptive']
#eta
eta0 = [0.00001, 0.0001, 0.001, 0.01]
#loss
loss = ['log', 'hinge', 'perceptron']

param_grid = {'max_iter': max_iter,
               'learning_rate': learning_rate,
                  'eta0': eta0,
                  'loss':loss}

sgd = SGDClassifier(tol=0.0001)

sgd_gsearch = GridSearchCV(estimator = sgd, param_grid = param_grid, #param_distributions = sgd_random_grid, 
                           cv = rolling_window(X_train.shape[0],ntrain = 12000, ntest = 3000, gen_for_grid_search=True),   
                                 verbose=2, n_jobs =7, scoring=scoring, refit='AUC')
# Fit the random search model
sgd_gsearch.fit(X_train, y_train)
# Out:
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fitting 11 folds for each of 252 candidates, totalling 2772 fits
# [Parallel(n_jobs=7)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  27 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=7)]: Done 148 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=7)]: Done 574 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=7)]: Done 1176 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=7)]: Done 1860 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=7)]: Done 2772 out of 2772 | elapsed:  1.6min finished
# GridSearchCV(cv=<generator object rolling_window at 0x000001C1F6C76258>,
#              error_score='raise-deprecating',
#              estimator=SGDClassifier(alpha=0.0001, average=False,
#                                      class_weight=None, early_stopping=False,
#                                      epsilon=0.1, eta0=0.0, fit_intercept=True,
#                                      l1_ratio=0.15, learning_rate='optimal',
#                                      loss='hinge', max_iter=1000,
#                                      n_iter_no_change=5, n_jobs=None,
#                                      penalty='l2', power_t=0.5...
#                                      verbose=0, warm_start=False),
#              iid='warn', n_jobs=7,
#              param_grid={'eta0': [1e-05, 0.0001, 0.001, 0.01],
#                          'learning_rate': ['constant', 'optimal', 'adaptive'],
#                          'loss': ['log', 'hinge', 'perceptron'],
#                          'max_iter': [100, 180, 200, 250, 300, 320, 350]},
#              pre_dispatch='2*n_jobs', refit='AUC', return_train_score=False,
#              scoring={'AUC': 'roc_auc',
#                       'Accuracy': make_scorer(accuracy_score)},
#              verbose=2)

# %%
sgd_gsearch.best_params_
# Out:
# {'eta0': 0.001, 'learning_rate': 'constant', 'loss': 'log', 'max_iter': 320}

# %%
#Linear model Stochastic Gradient Descent
sgd_gs = SGDClassifier(random_state=42, max_iter=320, loss='log', learning_rate='constant', eta0=0.001, tol=0.0001) 
sgd_gs.fit(X_train, y_train)
sgd_gs_diag = model_diag_seq(sgd_gs, X_train, y_train,train_window=12000, test_window=3000)
# Out:
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.7961960770081185
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.8081523727989253
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.8157652489875945
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.8144717301699983
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.879486174441852
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.6939556428972488
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.893116963731489
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.8664289591248799
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.8892404458005615
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.8670961958779645
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.7769551075620875
# Validation AUC 0.803

# %%
y_score_sgd_gs = sgd_gs.predict(X_test)
cm = confusion_matrix(y_test, y_score_sgd_gs)
print(cm)
sgd_test_diag_gs = model_oostest(sgd_gs,X_test, y_test)
sgd_test_auc_gs = plot_rocs([sgd_gs_diag, sgd_test_diag_gs], p_width=600, p_height=600, model_appendix=['SGD - seq_valid','SGD - test'])
show(sgd_test_auc_gs)
# Out:
# [[11052   244]
#  [  147    75]]
# Confusion matrix:
# [[0.9784  0.0216 ]
#  [0.01301 0.00664]]
# AUC 0.770
#   <div class="bk-root" id="d95a32eb-ba7d-4de8-b9e2-c8c1e3826303" data-root-id="1196"></div>

# %% [markdown]
# ### Random Forest Classifier

# %%
#random forest - benchmark
n_estimators = 200
max_leaf_nodes = 40
rf_clf = RandomForestClassifier(random_state=42,
                               n_estimators=n_estimators,
                               max_leaf_nodes=max_leaf_nodes,
                               class_weight="balanced",
                               n_jobs=7)

rf_clf.fit(X_train, y_train)
rf_clf_diag = model_diag_seq(rf_clf, X_train, y_train,train_window=12000, test_window=3000)
# Out:
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.8126563389875934
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.8593180143914863
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.9267412066154204
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.9146639975216404
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.9458701914379416
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.9497936552498596
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.9584966450888239
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9504254519644274
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9494211055620375
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.9197765575043804
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.8828218206347695
# Validation AUC 0.915

# %%
y_score_rf = rf_clf.predict(X_test)
cm = confusion_matrix(y_test, y_score_rf)
print(cm)
rf_test_diag = model_oostest(rf_clf,X_test, y_test)
rf_test_auc = plot_rocs([rf_clf_diag, rf_test_diag], p_width=600, p_height=600, model_appendix=['RF - seq_valid','RF - test'])
show(rf_test_auc)
# Out:
# [[9769 1527]
#  [  89  133]]
# Confusion matrix:
# [[0.86482 0.13518]
#  [0.00788 0.01177]]
# AUC 0.826
#   <div class="bk-root" id="5599457f-f842-4b80-9392-26da144f970f" data-root-id="1403"></div>

# %% [markdown]
# ### Randomized Grid Search

# %%
# Number of trees in random forest
n_estimators = [150, 180, 200, 250, 280, 300, 350] 
# Number of features to consider at every split
max_features = ['auto', 'sqrt', 10, 20]
# Maximum number of levels in tree
max_depth = [100,200, None]
#Max leaf nodes
max_leaf_nodes = [10,20,40,60]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
              'max_leaf_nodes':max_leaf_nodes}

# %%
rf = RandomForestClassifier() #base model
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 80, 
                               cv = rolling_window(X_train.shape[0],ntrain = 12000, ntest = 3000, gen_for_grid_search=True), 
                               verbose=2, random_state=42, n_jobs =7, refit='AUC')
# Fit the random search model
rf_random.fit(X_train, y_train)
# Out:
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fitting 11 folds for each of 80 candidates, totalling 880 fits
# [Parallel(n_jobs=7)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  27 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=7)]: Done 148 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=7)]: Done 351 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=7)]: Done 634 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=7)]: Done 880 out of 880 | elapsed: 12.2min finished
# RandomizedSearchCV(cv=<generator object rolling_window at 0x000001C1F83958E0>,
#                    error_score='raise-deprecating',
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fracti...
#                    iid='warn', n_iter=80, n_jobs=7,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [100, 200, None],
#                                         'max_features': ['auto', 'sqrt', 10,
#                                                          20],
#                                         'max_leaf_nodes': [10, 20, 40, 60],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [150, 180, 200, 250,
#                                                          280, 300, 350]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit='AUC',
#                    return_train_score=False, scoring=None, verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 250,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_leaf_nodes': 60,
#  'max_features': 'sqrt',
#  'max_depth': None,
#  'bootstrap': True}

# %%
# Number of trees in random forest
n_estimators = [225, 250, 275] 
# Number of features to consider at every split
max_features = ['sqrt', 10]
# Maximum number of levels in tree
max_depth = [200, None]
#Max leaf nodes
max_leaf_nodes = [60,80]
# Minimum number of samples required to split a node
min_samples_split = [5]
# Minimum number of samples required at each leaf node
min_samples_leaf = [2,4]
# Method of selecting samples for training each tree
bootstrap = [True]
# Create the random grid
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
              'max_leaf_nodes':max_leaf_nodes}

# %%
rf = RandomForestClassifier() #base model
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_grid = GridSearchCV(estimator = rf, param_grid = param_grid, #param_distributions = sgd_random_grid, 
                           cv = rolling_window(X_train.shape[0],ntrain = 12000, ntest = 3000, gen_for_grid_search=True),   
                                 verbose=2, n_jobs =7, scoring=scoring, refit='AUC')
# Fit the random search model
rf_grid.fit(X_train, y_train)
# Out:
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fitting 11 folds for each of 48 candidates, totalling 528 fits
# [Parallel(n_jobs=7)]: Using backend LokyBackend with 7 concurrent workers.
# [Parallel(n_jobs=7)]: Done  27 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=7)]: Done 148 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=7)]: Done 351 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=7)]: Done 528 out of 528 | elapsed:  5.8min finished
# GridSearchCV(cv=<generator object rolling_window at 0x000001C1F8395830>,
#              error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_lea...
#                                               warm_start=False),
#              iid='warn', n_jobs=7,
#              param_grid={'bootstrap': [True], 'max_depth': [200, None],
#                          'max_features': ['sqrt', 10],
#                          'max_leaf_nodes': [60, 80], 'min_samples_leaf': [2, 4],
#                          'min_samples_split': [5],
#                          'n_estimators': [225, 250, 275]},
#              pre_dispatch='2*n_jobs', refit='AUC', return_train_score=False,
#              scoring={'AUC': 'roc_auc',
#                       'Accuracy': make_scorer(accuracy_score)},
#              verbose=2)

# %%
rf_grid.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 200,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': 80,
#  'min_samples_leaf': 2,
#  'min_samples_split': 5,
#  'n_estimators': 275}

# %%
#optimized params 
rf_opt = {'n_estimators': 275,
 'min_samples_split': 5,
 'min_samples_leaf': 2,
 'max_leaf_nodes': 80,
 'max_features': 'sqrt',
 'max_depth': 200,
 'bootstrap': True}

# %%
#random_forest from rand
n_estimators=rf_opt['n_estimators']
min_samples_split=rf_opt['min_samples_split']
min_samples_leaf=rf_opt['min_samples_leaf']
max_leaf_nodes=rf_opt['max_leaf_nodes']
max_features=rf_opt['max_features']
max_depth=rf_opt['max_depth']
bootstrap=rf_opt['bootstrap']




rf_opt_clf = RandomForestClassifier(random_state=42,
                               n_estimators=n_estimators,
                                max_features=max_features,
                                min_samples_split=min_samples_split,
                               min_samples_leaf=min_samples_leaf,
                               class_weight="balanced", bootstrap=bootstrap,
                               n_jobs=7)
rf_opt_clf.fit(X_train, y_train)
rf_opt_diag = model_diag_seq(rf_opt_clf, X_train, y_train, train_window=12000, test_window=3000)
# Out:
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.8029127209684084
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.8728476549100842
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.9319424358270085
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.9388550923758493
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.9588346963294199
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.9621069623806849
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.9721456652182909
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9461976535426495
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9588970352108351
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.929710784667907
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.9033762170366291
# Validation AUC 0.920

# %%
y_score_rf_opt = rf_opt_clf.predict(X_test)
cm = confusion_matrix(y_test, y_score_rf_opt)
print(cm)
rf_opt_test_diag = model_oostest(rf_opt_clf,X_test, y_test)
rf_opt_test_auc = plot_rocs([rf_opt_diag, rf_opt_test_diag], p_width=600, p_height=600, model_appendix=['RF - val_seq','RF - test'])
show(rf_opt_test_auc)
# Out:
# [[10944   352]
#  [  145    77]]
# Confusion matrix:
# [[0.96884 0.03116]
#  [0.01284 0.00682]]
# AUC 0.819
#   <div class="bk-root" id="26924a69-fd8c-44f0-97c1-807031fe7368" data-root-id="1626"></div>
