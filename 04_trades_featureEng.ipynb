# %% [markdown]
# # Trades feature engineering - Degree 1 buyers-sellers data

# %% [markdown]
# This notebook starts from the file generated at step 01 (notebook '01_instrumentsFeatures.ipynb') and performs feature engineering adding useful node/edge stats retrieved with the notebook '02_buyers_sellers_df.ipynb'.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import itertools

from scripts_preproc.features_utils import *

# %% [markdown]
# ## Data import

# %%
filename = "02_instrumentsdf_2.pkl"
datafolder = "../data/"

inst = pd.read_pickle(datafolder+filename)
inst.head()
# Out:
#              customer_id               customer_name_1 debtor_id  \
# uid
# 2744:79/231      2004008                 Castillo GmbH        79
# 2861:79/232      2004008                 Castillo GmbH        79
# 2932:79/233      2004008                 Castillo GmbH        79
# 1472:489/688     2004009  Orpheus Wyandotte Supply LLC       489
# 2042:512/645     2004009  Orpheus Wyandotte Supply LLC       512
#
#                    debtor_name_1 invoice_number invoice_date   due_date  \
# uid
# 2744:79/231    Sana Hyannis Sarl           2744   2013-07-23 2013-08-02
# 2861:79/232    Sana Hyannis Sarl           2861   2013-07-30 2013-08-09
# 2932:79/233    Sana Hyannis Sarl           2932   2013-08-06 2013-08-16
# 1472:489/688          Isfahan SA           1472   2013-08-13 2013-08-23
# 2042:512/645  Aldrich Chloe GmbH           2042   2013-08-13 2013-08-23
#
#               invoice_amount  purchase_amount  purchase_amount_open  ...  \
# uid                                                                  ...
# 2744:79/231           913.70              0.0                   0.0  ...
# 2861:79/232          2233.45              0.0                   0.0  ...
# 2932:79/233          1370.50              0.0                   0.0  ...
# 1472:489/688         9195.10              0.0                   0.0  ...
# 2042:512/645         4594.60              0.0                   0.0  ...
#
#              total_repayment  total_impairment is_open we_payment_share  \
# uid
# 2744:79/231             0.00              0.00   False              NaN
# 2861:79/232             0.00              0.00   False              NaN
# 2932:79/233          1370.50              0.00   False              1.0
# 1472:489/688            0.00              0.00   False              NaN
# 2042:512/645          164.35            164.35   False              1.0
#
#              has_purchase  has_deduction is_due has_discharge cash_check  \
# uid
# 2744:79/231         False          False   True          True     913.70
# 2861:79/232         False          False   True          True    2233.45
# 2932:79/233         False          False   True         False       0.00
# 1472:489/688        False          False   True          True    9195.10
# 2042:512/645        False          False   True          True    4265.90
#
#              unexpl
# uid
# 2744:79/231    True
# 2861:79/232    True
# 2932:79/233   False
# 1472:489/688   True
# 2042:512/645   True
#
# [5 rows x 57 columns]

# %%
print("{:} instruments".format(inst.shape[0]))
# Out:
# 59820 instruments

# %%
print("{:} open, {:} with no payments".format(sum(inst.document_status=="offen") ,sum(inst.last_payment_date.isnull())))
# Out:
# 8213 open, 12181 with no payments

# %% [markdown]
# ### 1. Retrieving first and last posting date and payment date mismatch

# %%
inst["first_posting_date"] = inst.posting_date.apply(lambda x: min(x))
inst["last_posting_date"] = inst.posting_date.apply(lambda x: max(x))
inst["payment_date_mismatch"] = (inst.last_payment_date - inst.due_date).dt.days

# %% [markdown]
# ### 2. Isolating date columns and calculating offsets from invoice_date

# %%
datecol = [  'due_date', 
           #"invoice_date", #almost always the earliest
       'discharge_date',  'input_date', 'creation_date', 
       'debt_collection_date', 'last_payment_date', 'reminder_date',
       'cancellation_date', 'value_date',
       'first_posting_date', 'last_posting_date']

for c in datecol:
    inst["dd_"+c] = (inst[c] - inst.invoice_date).apply(lambda x: x.days)

# %%
inst[['dd_'+i for i in datecol]].head().transpose()
# Out:
# uid                      2744:79/231  2861:79/232  2932:79/233  1472:489/688  \
# dd_due_date                     10.0         10.0         10.0          10.0
# dd_discharge_date              973.0        966.0          NaN         952.0
# dd_input_date                  921.0        914.0        907.0         900.0
# dd_creation_date               921.0        914.0        907.0         900.0
# dd_debt_collection_date          NaN          NaN          NaN           NaN
# dd_last_payment_date             NaN          NaN        907.0           NaN
# dd_reminder_date                48.0         55.0         48.0          69.0
# dd_cancellation_date             NaN          NaN          NaN           NaN
# dd_value_date                   10.0         10.0         10.0          10.0
# dd_first_posting_date          921.0        914.0        907.0         900.0
# dd_last_posting_date           973.0        966.0        959.0         952.0
#
# uid                      2042:512/645
# dd_due_date                      10.0
# dd_discharge_date               952.0
# dd_input_date                   900.0
# dd_creation_date                900.0
# dd_debt_collection_date           NaN
# dd_last_payment_date            900.0
# dd_reminder_date                125.0
# dd_cancellation_date              NaN
# dd_value_date                    10.0
# dd_first_posting_date           900.0
# dd_last_posting_date            952.0

# %%
inst.columns
# Out:
# Index(['customer_id', 'customer_name_1', 'debtor_id', 'debtor_name_1',
#        'invoice_number', 'invoice_date', 'due_date', 'invoice_amount',
#        'purchase_amount', 'purchase_amount_open', 'discharge_type',
#        'discharge_amount', 'discharge_date', 'posting_date',
#        'transaction_type', 'document_stack_id', 'booking_text', 'input_date',
#        'creation_date', 'factoring_type', 'debt_collection_date',
#        'last_payment_date', 'reminder_date', 'test_feature_tested',
#        'test_characteristic_id', 'bill_id', 'cancellation_date', 'value_date',
#        'currency', 'purchase_examination', 'prosecution', 'deduction_amount',
#        'payment_amount', 'payment_date', 'document_status', 'uid', 'ttype',
#        'nrecords', 'ttypeset', 'discharge_loss', 'has_impairment1',
#        'has_prosecution', 'is_pastdue', 'is_pastdue30', 'is_pastdue90',
#        'is_pastdue180', 'last_payment_amount', 'total_repayment',
#        'total_impairment', 'is_open', 'we_payment_share', 'has_purchase',
#        'has_deduction', 'is_due', 'has_discharge', 'cash_check', 'unexpl',
#        'first_posting_date', 'last_posting_date', 'payment_date_mismatch',
#        'dd_due_date', 'dd_discharge_date', 'dd_input_date', 'dd_creation_date',
#        'dd_debt_collection_date', 'dd_last_payment_date', 'dd_reminder_date',
#        'dd_cancellation_date', 'dd_value_date', 'dd_first_posting_date',
#        'dd_last_posting_date'],
#       dtype='object')

# %% [markdown]
# ### 3. Marking up instruments with buyer/seller relationship details properties known at instrument inception

# %% [markdown]
# For each instrument, stats will be added and classified depending on their nature.
# The type of stats can be of 3 types, and it will be named accordingly:
# - edge stats, referred to a customer/debtor pair - it will have the prefix 'cd'
# - node stats referred to a customer - it will have the prefix 'c'
# - node stats referred to a debtor - it will have the prefix 'd'

# %% [markdown]
# ### 3.1 Adding buyer/seller pair attributes (cd)

# %%
#Adding buyer/seller pair attributes
print("Adding buyer/seller pair attributes...")
prefix = "cd_" #stands for customer/debtor
g_cb = inst.groupby(["customer_name_1", "debtor_name_1"])
for (customer, debtor), igroup in g_cb:
    #for each instrument in this group, already sorted by invoice_date
    for idx, (id, ii) in enumerate(igroup.iterrows()):
       add_node_stats(inst, igroup, idx, id, ii, prefix)

#Adding the ratio columns for the previously calculated stats
cl = [prefix+"repaid_", prefix+"impaired1_",
      prefix+"pastdue90_", prefix+"pastdue180_"]
for c in cl:
    inst[c+"r"] = inst[c+"c"] / inst[prefix+"lent_c"]
# Out:
# Adding buyer/seller pair attributes...

# %% [markdown]
# ### 3.2 Adding buyer attributes (d)

# %%
print("Adding buyer attributes...")
#buyer attributes
prefix = "d_"
g_b = inst.groupby(["debtor_name_1"])
for _, igroup in g_b:
    #for each instrument in this group, already sorted by invoice_date
    for idx, (id, ii) in enumerate(igroup.iterrows()):
        add_node_stats(inst, igroup, idx, id, ii, prefix)      
#add the ratio columns
cl = [prefix+"repaid_", prefix+"impaired1_",
      prefix+"pastdue90_", prefix+"pastdue180_"]
for c in cl:
    inst[c+"r"] = inst[c+"c"] / inst[prefix+"lent_c"]
# Out:
# Adding buyer attributes...

# %% [markdown]
# ### 3.3 Adding seller attributes (c)

# %%
#Adding seller attributes
print("Adding seller attributes...")
prefix = "c_"
g_b = inst.groupby(["customer_name_1"])
for _, igroup in g_b:
    #for each instrument in this group, already sorted by invoice_date
    for idx, (id, ii) in enumerate(igroup.iterrows()):
        add_node_stats(inst, igroup, idx, id, ii, prefix)      
#add the ratio columns
cl = [prefix+"repaid_", prefix+"impaired1_",  
      prefix+"pastdue90_", prefix+"pastdue180_"]
for c in cl:
    inst[c+"r"] = inst[c+"c"] / inst[prefix+"lent_c"]
# Out:
# Adding seller attributes...

# %%
outputfile = '03_instrumentsdf_deg1stats.pkl'
inst.to_pickle(datafolder+outputfile)

# %%
d = pd.read_pickle(datafolder+'03_instrumentsdf_deg1stats.pkl')

# %%
d.tail(5)[[c for c in d.columns if 'cd_' in c]].transpose()
# Out:
# uid                  2017-3634:29/47558  2017-3635:29/47567  \
# cd_lent_c                    431.000000          432.000000
# cd_repaid_c                  315.000000          315.000000
# cd_impaired1_c                 0.000000            0.000000
# cd_pastdue90_c                 3.000000            3.000000
# cd_pastdue180_c                3.000000            3.000000
# cd_trend_a                    -1.443147           -1.444563
# cd_we_payment_share            0.000000            0.000000
# cd_pd_mismatch_mean          -17.298413          -17.298413
# cd_pd_mismatch_std            30.917393           30.917393
# cd_repaid_r                    0.730858            0.729167
# cd_impaired1_r                 0.000000            0.000000
# cd_pastdue90_r                 0.006961            0.006944
# cd_pastdue180_r                0.006961            0.006944
#
# uid                  2017-3636:29/47559  2017-3637:29/47560  \
# cd_lent_c                    433.000000          434.000000
# cd_repaid_c                  315.000000          315.000000
# cd_impaired1_c                 0.000000            0.000000
# cd_pastdue90_c                 3.000000            3.000000
# cd_pastdue180_c                3.000000            3.000000
# cd_trend_a                    -1.442165           -1.439885
# cd_we_payment_share            0.000000            0.000000
# cd_pd_mismatch_mean          -17.298413          -17.298413
# cd_pd_mismatch_std            30.917393           30.917393
# cd_repaid_r                    0.727483            0.725806
# cd_impaired1_r                 0.000000            0.000000
# cd_pastdue90_r                 0.006928            0.006912
# cd_pastdue180_r                0.006928            0.006912
#
# uid                  2017-3622:69/47546
# cd_lent_c                    801.000000
# cd_repaid_c                  532.000000
# cd_impaired1_c                 0.000000
# cd_pastdue90_c                 1.000000
# cd_pastdue180_c                0.000000
# cd_trend_a                    -3.244175
# cd_we_payment_share            0.000000
# cd_pd_mismatch_mean           74.847744
# cd_pd_mismatch_std            38.671066
# cd_repaid_r                    0.664170
# cd_impaired1_r                 0.000000
# cd_pastdue90_r                 0.001248
# cd_pastdue180_r                0.000000

# %%
d.filter(regex=("^d_")).tail().transpose()
# Out:
# uid                 2017-3634:29/47558  2017-3635:29/47567  \
# d_lent_c                    431.000000          432.000000
# d_repaid_c                  315.000000          315.000000
# d_impaired1_c                 0.000000            0.000000
# d_pastdue90_c                 3.000000            3.000000
# d_pastdue180_c                3.000000            3.000000
# d_trend_a                    -1.443147           -1.444563
# d_we_payment_share            0.000000            0.000000
# d_pd_mismatch_mean          -17.298413          -17.298413
# d_pd_mismatch_std            30.917393           30.917393
# d_repaid_r                    0.730858            0.729167
# d_impaired1_r                 0.000000            0.000000
# d_pastdue90_r                 0.006961            0.006944
# d_pastdue180_r                0.006961            0.006944
#
# uid                 2017-3636:29/47559  2017-3637:29/47560  2017-3622:69/47546
# d_lent_c                    433.000000          434.000000          801.000000
# d_repaid_c                  315.000000          315.000000          532.000000
# d_impaired1_c                 0.000000            0.000000            0.000000
# d_pastdue90_c                 3.000000            3.000000            1.000000
# d_pastdue180_c                3.000000            3.000000            0.000000
# d_trend_a                    -1.442165           -1.439885           -3.244175
# d_we_payment_share            0.000000            0.000000            0.000000
# d_pd_mismatch_mean          -17.298413          -17.298413           74.847744
# d_pd_mismatch_std            30.917393           30.917393           38.671066
# d_repaid_r                    0.727483            0.725806            0.664170
# d_impaired1_r                 0.000000            0.000000            0.000000
# d_pastdue90_r                 0.006928            0.006912            0.001248
# d_pastdue180_r                0.006928            0.006912            0.000000

# %%
d.filter(regex=("^c_")).tail().transpose()
# Out:
# uid                 2017-3634:29/47558  2017-3635:29/47567  \
# c_lent_c                   3801.000000         3802.000000
# c_repaid_c                 2988.000000         2988.000000
# c_impaired1_c                62.000000           62.000000
# c_pastdue90_c               269.000000          269.000000
# c_pastdue180_c              202.000000          202.000000
# c_trend_a                    -1.471188           -1.473267
# c_we_payment_share            0.000000            0.000000
# c_pd_mismatch_mean           46.005020           46.005020
# c_pd_mismatch_std            97.133022           97.133022
# c_repaid_r                    0.786109            0.785902
# c_impaired1_r                 0.016311            0.016307
# c_pastdue90_r                 0.070771            0.070752
# c_pastdue180_r                0.053144            0.053130
#
# uid                 2017-3636:29/47559  2017-3637:29/47560  2017-3622:69/47546
# c_lent_c                   3803.000000         3804.000000         3805.000000
# c_repaid_c                 2988.000000         2988.000000         2988.000000
# c_impaired1_c                62.000000           62.000000           62.000000
# c_pastdue90_c               269.000000          269.000000          269.000000
# c_pastdue180_c              202.000000          202.000000          202.000000
# c_trend_a                    -1.474443           -1.475649           -1.472599
# c_we_payment_share            0.000000            0.000000            0.000000
# c_pd_mismatch_mean           46.005020           46.005020           46.005020
# c_pd_mismatch_std            97.133022           97.133022           97.133022
# c_repaid_r                    0.785696            0.785489            0.785283
# c_impaired1_r                 0.016303            0.016299            0.016294
# c_pastdue90_r                 0.070734            0.070715            0.070696
# c_pastdue180_r                0.053116            0.053102            0.053088
