# %% [markdown]
# # Models loop automation - Impairment tuned models

# %% [markdown]
# This notebook uses as inputs the outputs from the pipeline ('05_preproc_pipeline_1.ipynb' notebook) and performs model assessment of performances and general exploration for the transaction credit events prediction "has_impairement1".
# All the experiments produce useful data for visualizing results and can be tracked on MLflow.

# %%
import pandas as pd
import numpy as np
import pickle

from scripts_ml.models_utils import *
from scripts_viz.visualization_utils import *

from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from bokeh.io import show, output_notebook
output_notebook()
# Out:
# C:\ProgramData\Anaconda3\envs\thesis_mlflow\lib\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
#linear model Stochastic Gradient Descent with semi-optimized hyperparameters using random search
sgd_rs_1 = SGDClassifier(random_state=42, max_iter=350, loss='log', learning_rate='optimal', eta0=0.001, tol=0.0001) #from benchmark_imp_shuffle_tuning
sgd_rs_2 = SGDClassifier(random_state=42, max_iter=200, loss='log', learning_rate='constant', eta0=0.001, tol=0.0001) #from benchmark_imp_time_tuning
sgd_rs_3 = SGDClassifier(random_state=42, max_iter=180, loss='log', learning_rate='adaptive', eta0=0.01, tol=0.0001) #from benchmark_p90_shuffle_tuning
sgd_rs_4 = SGDClassifier(random_state=42, max_iter=320, loss='log', learning_rate='constant', eta0=0.01, tol=0.0001) #from benchmark_p90_time_tuning
sgd_rs_5 = SGDClassifier(random_state=42, max_iter=320, loss='log', learning_rate='adaptive', eta0=0.01, tol=0.0001) #from both benchmark_p180_shuffle_tuning and benchmark_p180_time_tuning

sgd_models = [sgd_rs_1, sgd_rs_2, sgd_rs_3, sgd_rs_4, sgd_rs_5]

# %%
#random forest models parameters from randomized grid search

#from benchmark_imp_shuffle_tuning
rf_opt_1 = {'n_estimators': 350,
 'min_samples_split': 10,
 'min_samples_leaf': 1,
 'max_leaf_nodes': 80,
 'max_features': 15,
 'max_depth': 80,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_imp_time_tuning
rf_opt_2 = {'n_estimators': 180,
 'min_samples_split': 10,
 'min_samples_leaf': 1,
 'max_leaf_nodes': 25,
 'max_features': 10,
 'max_depth': None,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_p90_shuffle_tuning
rf_opt_3 = {'n_estimators': 280,
 'min_samples_split': 10,
 'min_samples_leaf': 1,
 'max_leaf_nodes': 100,
 'max_features': 15,
 'max_depth': 280,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_p90_time_tuning
rf_opt_4 = {'n_estimators': 300,
 'min_samples_split': 5,
 'min_samples_leaf': 2,
 'max_leaf_nodes': 80,
 'max_features': 'sqrt',
 'max_depth': None,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_p180_shuffle_tuning
rf_opt_5 = {'n_estimators': 250,
 'min_samples_split': 15,
 'min_samples_leaf': 1,
 'max_leaf_nodes': 100,
 'max_features': 'auto',
 'max_depth': 180,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

#from benchmark_p180_time_tuning 
rf_opt_6 = {'n_estimators': 180,
 'min_samples_split': 5,
 'min_samples_leaf': 2,
 'max_leaf_nodes': 80,
 'max_features': 'sqrt',
 'max_depth': 80,
 'bootstrap': True,
 'random_state':42,
 'class_weight':"balanced",
  'n_jobs': 7}

rf_parameters = [rf_opt_1, rf_opt_2, rf_opt_3, rf_opt_4, rf_opt_5, rf_opt_6]

rf_models = [RandomForestClassifier(**params) for params in rf_parameters]

# %%
models = sgd_models+rf_models

# %%
prefixes_shuffle = ['shuffle_imp_']
postfixes_shuffle = ['_19072_750']
preproc_folder = "benchmarks_shuffle" #folder with the correct preprocessing data
expname = preproc_folder+"_opt_imp" #experiment name

# %%
datafolder = "../data/preproc_traintest/"+preproc_folder+'/'
output_path = "../data/models/"

# %% [markdown]
# ## Experiment in Shuffle Mode

# %%
experiment_shuffle = models_loop(models, datafolder, prefixes_shuffle, postfixes_shuffle, mlf_tracking=True, save_model=True,
                                experiment_name=expname, save_results_for_viz=False)
# Out:
# ----Loop 1 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.792
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99894 0.00106]
#  [0.01797 0.00212]]
# AUC 0.784
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__SGDClassifier_190817_92449.pkl
# - Creating the new experiment 'benchmarks_shuffle_opt_imp',  the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 2 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.791
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99885 0.00115]
#  [0.01788 0.00221]]
# AUC 0.782
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__SGDClassifier_190817_92455.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 3 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.797
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99903 0.00097]
#  [0.0178  0.0023 ]]
# AUC 0.783
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__SGDClassifier_190817_9254.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 4 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.795
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99867 0.00133]
#  [0.01762 0.00248]]
# AUC 0.769
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__SGDClassifier_190817_9258.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 5 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.797
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99903 0.00097]
#  [0.0178  0.0023 ]]
# AUC 0.783
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__SGDClassifier_190817_92516.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 6 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.928
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.93156 0.06844]
#  [0.00531 0.01479]]
# AUC 0.919
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__RandomForestClassifier_190817_92742.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 7 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.915
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.8741  0.1259 ]
#  [0.00469 0.01541]]
# AUC 0.904
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__RandomForestClassifier_190817_92827.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 8 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.929
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.94351 0.05649]
#  [0.00567 0.01443]]
# AUC 0.923
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__RandomForestClassifier_190817_93024.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 9 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.927
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.91244 0.08756]
#  [0.00514 0.01496]]
# AUC 0.918
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__RandomForestClassifier_190817_93116.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 10 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.929
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.92457 0.07543]
#  [0.00584 0.01425]]
# AUC 0.921
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__RandomForestClassifier_190817_9323.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 11 of 11 for credit event shuffle_imp_----
# Training, validation and testing of experiment with prefix shuffle_imp_ and postfix _19072_750 using RandomForestClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__traindata_19072_750.pkl
# testing files: ../data/preproc_traintest/benchmarks_shuffle/shuffle_imp__testdata_19072_750.pkl
# - Training/Validation...
# AUC 0.927
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.91155 0.08845]
#  [0.00558 0.01452]]
# AUC 0.918
# - Saving the model to ../data/models/benchmarks_shuffle_opt_imp/...
# - Saving model to ../data/models/benchmarks_shuffle_opt_imp/shuffle_imp__RandomForestClassifier_190817_93237.pkl
# - Activating existing experiment 'benchmarks_shuffle_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# Experiment done!

# %% [markdown]
# ## Experiment in Time mode

# %%
preproc_folder = "benchmarks_time" #folder with the correct preprocessing data
expname = preproc_folder+"_opt_imp" #experiment name
datafolder = "../data/preproc_traintest/"+preproc_folder+'/'
prefixes_time = ['time_2018-04-30_imp_']
postfixes_time = ['_190710_745']

# %%
experiment_time = models_loop(models, datafolder, prefixes_time, postfixes_time, 
                              timeSeqValid = True, train_window = 12000, test_window = 3000,
                              mlf_tracking=True, save_model=True,
                                experiment_name=expname, save_results_for_viz=False)
# Out:
# ----Loop 1 of 11 for credit event time_2018-04-30_imp_----
# Training, validation and testing of experiment with prefix time_2018-04-30_imp_ and postfix _190710_745 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_imp__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_imp__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.46796766309456667
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.6518784751987794
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.5517888563049853
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.637378613369467
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.7304788411858778
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.7358821990507157
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.7508238236427554
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9618008696956066
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9321875000000001
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.9235928132502773
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.7698612545913682
# Validation AUC 0.759
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99628 0.00372]
#  [0.03734 0.00662]]
# AUC 0.779
# - Saving the model to ../data/models/benchmarks_time_opt_imp/...
# - Saving model to ../data/models/benchmarks_time_opt_imp/time_2018-04-30_imp__SGDClassifier_190817_93242.pkl
# - Creating the new experiment 'benchmarks_time_opt_imp',  the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 2 of 11 for credit event time_2018-04-30_imp_----
# Training, validation and testing of experiment with prefix time_2018-04-30_imp_ and postfix _190710_745 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_imp__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_imp__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.5108554239518706
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.6227084332801158
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.5892452538972064
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.5761630532971996
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.6776356255381966
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.8191252133398115
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.8209137167619601
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9670677762783026
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9416131756756756
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.9242573863556589
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.7615967917814509
# Validation AUC 0.757
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.99565 0.00435]
#  [0.03725 0.00671]]
# AUC 0.797
# - Saving the model to ../data/models/benchmarks_time_opt_imp/...
# - Saving model to ../data/models/benchmarks_time_opt_imp/time_2018-04-30_imp__SGDClassifier_190817_93247.pkl
# - Activating existing experiment 'benchmarks_time_opt_imp', the following results will be saved in it...
# - Tracking the experiment on mlflow...
# - Experiment tracked.
#
# ----Loop 3 of 11 for credit event time_2018-04-30_imp_----
# Training, validation and testing of experiment with prefix time_2018-04-30_imp_ and postfix _190710_745 using SGDClassifier
# -Loading preprocessed data...
# training files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_imp__traindata_190710_745.pkl
# testing files: ../data/preproc_traintest/benchmarks_time/time_2018-04-30_imp__testdata_190710_745.pkl
# - Training/Validation...
# Preparing fold 0 with 13101 train observations and 3000 test observations, starti=4101...
# Fold 0: train  on 13101 from index 0 to 13100, test on 3000 from 13101 to 16100
# Fold 0 AUC: 0.4881970295168265
# Preparing fold 1 with 12000 train observations and 3000 test observations, starti=7101...
# Fold 1: train  on 12000 from index 4101 to 16100, test on 3000 from 16101 to 19100
# Fold 1 AUC: 0.6494089704367249
# Preparing fold 2 with 12000 train observations and 3000 test observations, starti=10101...
# Fold 2: train  on 12000 from index 7101 to 19100, test on 3000 from 19101 to 22100
# Fold 2 AUC: 0.5412316715542522
# Preparing fold 3 with 12000 train observations and 3000 test observations, starti=13101...
# Fold 3: train  on 12000 from index 10101 to 22100, test on 3000 from 22101 to 25100
# Fold 3 AUC: 0.6205185749774165
# Preparing fold 4 with 12000 train observations and 3000 test observations, starti=16101...
# Fold 4: train  on 12000 from index 13101 to 25100, test on 3000 from 25101 to 28100
# Fold 4 AUC: 0.7740343215647681
# Preparing fold 5 with 12000 train observations and 3000 test observations, starti=19101...
# Fold 5: train  on 12000 from index 16101 to 28100, test on 3000 from 28101 to 31100
# Fold 5 AUC: 0.7160742983144598
# Preparing fold 6 with 12000 train observations and 3000 test observations, starti=22101...
# Fold 6: train  on 12000 from index 19101 to 31100, test on 3000 from 31101 to 34100
# Fold 6 AUC: 0.7779805113605084
# Preparing fold 7 with 12000 train observations and 3000 test observations, starti=25101...
# Fold 7: train  on 12000 from index 22101 to 34100, test on 3000 from 34101 to 37100
# Fold 7 AUC: 0.9739185035237666
# Preparing fold 8 with 12000 train observations and 3000 test observations, starti=28101...
# Fold 8: train  on 12000 from index 25101 to 37100, test on 3000 from 37101 to 40100
# Fold 8 AUC: 0.9293918918918919
# Preparing fold 9 with 12000 train observations and 3000 test observations, starti=31101...
# Fold 9: train  on 12000 from index 28101 to 40100, test on 3000 from 40101 to 43100
# Fold 9 AUC: 0.9233260479896664
# Preparing fold 10 with 12000 train observations and 3000 test observations, starti=34101...
# Fold 10: train  on 12000 from index 31101 to 43100, test on 3000 from 43101 to 46100
# Fold 10 AUC: 0.765625
# Validation AUC 0.756
# - Training for test...
# - Testing...
# Confusion matrix:
# [[0.