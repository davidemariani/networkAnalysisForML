# %% [markdown]
# # Geocoding

# %% [markdown]
# This script retrieves longitude and latitude data for the company contained in the file 'Go_Factoring_Output_Perfect_Matches_20180912.XLSX' provided.

# %% [markdown]
# ### Data import

# %%
import pandas as pd
import numpy as np
import time

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

import os

# %%
user = os.environ['USERNAME']
datafolder = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/original_data/".format(user)
file = 'Go_Factoring_Output_Perfect_Matches_20180912.XLSX'
df = pd.read_excel(datafolder+file, header=1)
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
df.shape
# Out:
# (4460, 41)

# %%
df.head().transpose()
# Out:
#                                                    0  \
# id                                                 6
# kunden_id                                    2004052
# k-debitoren_id                                  6604
# debitorenname_1         1A Swiss Dienstleistungen AG
# anschrift               CH-5034 Suhr; Bachstrasse 33
# straße                                   Bachstrasse
# plz                                             5034
# ort                                             Suhr
# customer_id                                        6
# duns                                       480116741
# firma                   1A Swiss Dienstleistungen AG
# handelsname                                      NaN
# c/o_domiziladresse                               NaN
# domiziladresse                        Bachstrasse 33
# zusatz_domiziladresse                            NaN
# plz_domiziladresse                              5034
# ort_domiziladresse                              Suhr
# kanton_domiziladresse                             AG
# land_domiziladresse                               CH
# c/o_postadresse                                  NaN
# postadresse                           Bachstrasse 33
# zusatz_postadresse                               NaN
# plz_postadresse                                 5034
# ort_postadresse                                 Suhr
# kanton_postadresse                                AG
# land_postadresse                                  CH
# postfachadresse                                  NaN
# plz_postfachadresse                              NaN
# ort_postfachadresse                              NaN
# kanton_postfachadresse                           NaN
# land_postfachadresse                             NaN
# sprache                                      deutsch
# handelsregister-nummer                 CH40034407511
# uid                                  CHE-315.855.880
# regn_nbr_vat                                     NaN
# rechtsform                        Aktiengesellschaft
# duns_hauptsitz                                   NaN
# name_hauptsitz                                   NaN
# ort_hauptsitz                                    NaN
# land_hauptsitz                                   NaN
# aktivitätsstatus                               aktiv
#
#                                                             1  \
# id                                                          7
# kunden_id                                                 NaN
# k-debitoren_id                                           3499
# debitorenname_1                                 3.M.E.L. GmbH
# anschrift               CH-5734 Reinach AG; Pilatusstrasse 32
# straße                                      Pilatusstrasse 32
# plz                                                      5734
# ort                                                Reinach AG
# customer_id                                                 7
# duns                                                486977734
# firma                            3.M.E.L. GmbH in Liquidation
# handelsname                                               NaN
# c/o_domiziladresse                                        NaN
# domiziladresse                              Pilatusstrasse 32
# zusatz_domiziladresse                                     NaN
# plz_domiziladresse                                       5734
# ort_domiziladresse                                 Reinach AG
# kanton_domiziladresse                                      AG
# land_domiziladresse                                        CH
# c/o_postadresse                                           NaN
# postadresse                                 Pilatusstrasse 32
# zusatz_postadresse                                        NaN
# plz_postadresse                                          5734
# ort_postadresse                                    Reinach AG
# kanton_postadresse                                         AG
# land_postadresse                                           CH
# postfachadresse                                           NaN
# plz_postfachadresse                                       NaN
# ort_postfachadresse                                       NaN
# kanton_postfachadresse                                    NaN
# land_postfachadresse                                      NaN
# sprache                                               deutsch
# handelsregister-nummer                          CH40040369009
# uid                                           CHE-258.353.008
# regn_nbr_vat                                              NaN
# rechtsform              Gesellschaft mit beschränkter Haftung
# duns_hauptsitz                                            NaN
# name_hauptsitz                                            NaN
# ort_hauptsitz                                             NaN
# land_hauptsitz                                            NaN
# aktivitätsstatus                                     gelöscht
#
#                                                             2  \
# id                                                          8
# kunden_id                                             2004078
# k-debitoren_id                                           4139
# debitorenname_1                                   36GRAD GmbH
# anschrift                            CH-6039 Root D4; Platz 3
# straße                                                Platz 3
# plz                                                      6039
# ort                                                   Root D4
# customer_id                                                 8
# duns                                                480141611
# firma                                             36GRAD GmbH
# handelsname                                               NaN
# c/o_domiziladresse                                        NaN
# domiziladresse                                        Platz 3
# zusatz_domiziladresse                                     NaN
# plz_domiziladresse                                       6039
# ort_domiziladresse                            Root Längenbold
# kanton_domiziladresse                                      LU
# land_domiziladresse                                        CH
# c/o_postadresse                                           NaN
# postadresse                                           Platz 3
# zusatz_postadresse                                        NaN
# plz_postadresse                                          6039
# ort_postadresse                               Root Längenbold
# kanton_postadresse                                         LU
# land_postadresse                                           CH
# postfachadresse                                           NaN
# plz_postfachadresse                                       NaN
# ort_postfachadresse                                       NaN
# kanton_postfachadresse                                    NaN
# land_postfachadresse                                      NaN
# sprache                                               deutsch
# handelsregister-nummer                          CH10048022038
# uid                                           CHE-447.812.384
# regn_nbr_vat                                              NaN
# rechtsform              Gesellschaft mit beschränkter Haftung
# duns_hauptsitz                                            NaN
# name_hauptsitz                                            NaN
# ort_hauptsitz                                             NaN
# land_hauptsitz                                            NaN
# aktivitätsstatus                                        aktiv
#
#                                                               3  \
# id                                                            9
# kunden_id                                                   NaN
# k-debitoren_id                                            12066
# debitorenname_1                                  3A Schreinerei
# anschrift               CH-2558 Aegerten; Schwadernaustrasse 63
# straße                                    Schwadernaustrasse 63
# plz                                                        2558
# ort                                                    Aegerten
# customer_id                                                   9
# duns                                                  486942464
# firma                                         3A Schreinerei AG
# handelsname                                                 NaN
# c/o_domiziladresse                                          NaN
# domiziladresse                            Schwadernaustrasse 63
# zusatz_domiziladresse                                       NaN
# plz_domiziladresse                                         2558
# ort_domiziladresse                                     Aegerten
# kanton_domiziladresse                                        BE
# land_domiziladresse                                          CH
# c/o_postadresse                                             NaN
# postadresse                               Schwadernaustrasse 63
# zusatz_postadresse                                          NaN
# plz_postadresse                                            2558
# ort_postadresse                                        Aegerten
# kanton_postadresse                                           BE
# land_postadresse                                             CH
# postfachadresse                                             NaN
# plz_postfachadresse                                         NaN
# ort_postfachadresse                                         NaN
# kanton_postfachadresse                                      NaN
# land_postfachadresse                                        NaN
# sprache                                                 deutsch
# handelsregister-nummer                            CH03630570797
# uid                                             CHE-208.196.936
# regn_nbr_vat                                                NaN
# rechtsform                                   Aktiengesellschaft
# duns_hauptsitz                                              NaN
# name_hauptsitz                                              NaN
# ort_hauptsitz                                               NaN
# land_hauptsitz                                              NaN
# aktivitätsstatus                                          aktiv
#
#                                                                  4
# id                                                              11
# kunden_id                                                      NaN
# k-debitoren_id                                                5732
# debitorenname_1                                      3S Partner AG
# anschrift               CH-6020 Emmenbrücke; Gerliswilstrasse 19 b
# straße                                            Gerliswilstrasse
# plz                                                           6020
# ort                                                    Emmenbrücke
# customer_id                                                     11
# duns                                                     481936891
# firma                                                3S Partner AG
# handelsname                                                    NaN
# c/o_domiziladresse                                             NaN
# domiziladresse                                Gerliswilstrasse 19b
# zusatz_domiziladresse                                          NaN
# plz_domiziladresse                                            6020
# ort_domiziladresse                                     Emmenbrücke
# kanton_domiziladresse                                           LU
# land_domiziladresse                                             CH
# c/o_postadresse                                                NaN
# postadresse                                   Gerliswilstrasse 19b
# zusatz_postadresse                                             NaN
# plz_postadresse                                               6020
# ort_postadresse                                        Emmenbrücke
# kanton_postadresse                                              LU
# land_postadresse                                                CH
# postfachadresse                                                NaN
# plz_postfachadresse                                            NaN
# ort_postfachadresse                                            NaN
# kanton_postfachadresse                                         NaN
# land_postfachadresse                                           NaN
# sprache                                                    deutsch
# handelsregister-nummer                               CH10040262069
# uid                                                CHE-109.644.693
# regn_nbr_vat                                  CHE-109.644.693 MWST
# rechtsform                                      Aktiengesellschaft
# duns_hauptsitz                                                 NaN
# name_hauptsitz                                                 NaN
# ort_hauptsitz                                                  NaN
# land_hauptsitz                                                 NaN
# aktivitätsstatus                                             aktiv

# %%
def do_geocode(address):
    geoloc = Nominatim(user_agent='lon-lat-retrieval', timeout=12)
    geocoder = RateLimiter(geoloc.geocode, min_delay_seconds=1, max_retries=2) #rate limiter to avoid being blocked
    try:
        location = geocoder(address)
        return location
    except GeocoderTimedOut:
        return do_geocode(address)

def geolocator_2(company, count, address, postcode, location, canton, country, req_limit=500):
    """
    This function, given the following strings representing the address, will return latitude and longitude, if available.
    NaN otherwise.
    - Postadresse
    - PLZ
    - Ort Postadresse
    - Kanton Postadresse
    - Land Postadresse
    """
    
    if count!=0 and count%req_limit==0:
        print("!!-- SCRIPT TEMPORARY SLEEPING TO AVOID TIMEOUT ERROR --!!")
        time.sleep(50)
    
    geoinfo = []
    
    if pd.isnull(address):
        print('no address available for company {}'.format(company))
        addresse=''
    else:
        geoinfo.append(str(address))
    
    if not pd.isnull(country) and not pd.isnull(postcode):
        geoinfo.append(str(country)+'-'+str(postcode))
    
    else:
        if pd.isnull(country):
            print('no country information available for company {}'.format(company))
            country=''
        else:
            geoinfo.append(str(country))

        if pd.isnull(postcode):
            print('no postcode available for company {}'.format(company))
            postcode=''
        else:
            geoinfo.append(str(postcode))
        
    #if pd.isnull(location):
    #    print('no location available for company {}'.format(company))
    #    location=''
    #else:
    #    geoinfo.append(str(location))
    
    #if pd.isnull(canton):
    #    print('no canton information available for company {}'.format(company))
    #    canton=''
    #else:
    #    geoinfo.append(str(canton))
    
    if len(geoinfo)>0:
        ad = ''
        for s in geoinfo:
            ad+=' '
            ad+=s
        location = do_geocode(ad)
        
        if location:
            lat = location.latitude
            lon = location.longitude
            return lon, lat
        else:
            print("--WARNING-- Geolocation data not available for company {} with input '{}'".format(company, ad))
            lat = np.nan
            lon = np.nan
            return lon, lat
    else:
        print('--WARNING-- Geolocation data not available for company: {}'.format(company))
        lat = np.nan
        lon = np.nan
        return lon, lat
    
 #   if len(address)<3:
 #       print('--WARNING-- Geolocation data not available for address: {}'.format(address))
 #       lat = np.nan
 #       lon = np.nan
 #       return lon, lat
 #       
 #   
 #   
 #   else:
 #       #make a second attempt using only the entire address
 #       print('Making a second attempt with the entire address {}'.format(address))
 #       location = geocoder(address)
 #       
 #       if location:
 #           lat = location.latitude
 #           lon = location.longitude
 #           return lon, lat
 #           
 #       else:
 #           print
 #           
 #           print('--WARNING-- Geolocation data not available for address: {}'.format(address))
  #          lat = np.nan
  ##          lon = np.nan
  #          return lon, lat

# %%
#try
try1=df.iloc[0]
geolocator_2(try1.debitorenname_1, 0, try1.postadresse, try1.plz, try1.ort, try1.kanton_postadresse, try1.land_postadresse)
# Out:
# (8.0792366, 47.382247)

# %%
lon = []
lat = []
for r in range(len(df)):
    row = df.iloc[r]
    lonlat = geolocator_2(row.debitorenname_1, r, row.postadresse, row.plz, row.ort, row.kanton_postadresse, row.land_postadresse)
    lon.append(lonlat[0])
    lat.append(lonlat[1])
# Out:
# --WARNING-- Geolocation data not available for company 4B Fenster AG with input ' Brandbachstrasse 6 CH-6280'
# --WARNING-- Geolocation data not available for company A. Kuster AG with input ' Zihlstrasse 11 CH-8575'
# --WARNING-- Geolocation data not available for company A1-Bau GmbH with input ' Haldenstrasse 27 CH-4313'
# --WARNING-- Geolocation data not available for company AC Mächler AG with input ' Schwendi 3 CH-8857'

# %% [markdown]
# ### Saving longitude and latitude data into dataframes

# %% [markdown]
# Geopy is used to retrieve latitude and longitude information for the companies of the given dataset. In order to avoid exceeding requests number, the dataset is split in 'sub-dataset'.

# %%
datafolder2 = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/".format(user)

# %%
#lonlat_0 = dfs[0].Anschrift.apply(geolocator)
#lonlat_0.to_pickle(datafolder2+'lonlat_0.pkl')
#done

# %%
#lonlat_1 = dfs[1].Anschrift.apply(geolocator)
#lonlat_1.to_pickle(datafolder2+'lonlat_1.pkl')
#done

# %%
#lonlat_2 = dfs[2].Anschrift.apply(geolocator)
#lonlat_2.to_pickle(datafolder2+'lonlat_2.pkl')
#done

# %%
#lonlat_3 = dfs[3].Anschrift.apply(geolocator)
#lonlat_3.to_pickle(datafolder2+'lonlat_3.pkl')
#done

# %%
#lonlat_4 = dfs[4].Anschrift.apply(geolocator)
#lonlat_4.to_pickle(datafolder2+'lonlat_4.pkl')
#done
# Out:
# Making a second attempt with the entire address GB-WD31JE Hertfordshire; Church street Rickmansworth
# --WARNING-- Geolocation data not available for address: GB-WD31JE Hertfordshire; Church street Rickmansworth
# Making a second attempt with the entire address GB-BA134JT Westbury; West wilts Trading Estation, Station Road
# --WARNING-- Geolocation data not available for address: GB-BA134JT Westbury; West wilts Trading Estation, Station Road
# Making a second attempt with the entire address GB-WD31JE Hertfordshire; Jubilee Trade Centre, Jubilee Rd, Letchworth
# --WARNING-- Geolocation data not available for address: GB-WD31JE Hertfordshire; Jubilee Trade Centre, Jubilee Rd, Letchworth
# Making a second attempt with the entire address GB-GU32DX GUILFORD; SURREY; HENLEY BUSINESS PARK; PIRBRIGHT ROAD; NORMANDY
# --WARNING-- Geolocation data not available for address: GB-GU32DX GUILFORD; SURREY; HENLEY BUSINESS PARK; PIRBRIGHT ROAD; NORMANDY

# %%
#lonlat_5 = dfs[5].Anschrift.apply(geolocator)
#lonlat_5.to_pickle(datafolder2+'lonlat_5.pkl')
#done
# Out:
# Making a second attempt with the entire address PT-4410083 VILA NOVA DE GAIA; RUA CAMINHO DO SENHOR 938
# --WARNING-- Geolocation data not available for address: PT-4410083 VILA NOVA DE GAIA; RUA CAMINHO DO SENHOR 938

# %%
#lonlat_6 = dfs[6].Anschrift.apply(geolocator)
#lonlat_6.to_pickle(datafolder2+'lonlat_6.pkl')
#done

# %%
#lonlat_7 = dfs[7].Anschrift.apply(geolocator)
#lonlat_7.to_pickle(datafolder2+'lonlat_7.pkl')
#done

# %%
#lonlat_8 = dfs[8].Anschrift.apply(geolocator)
#lonlat_8.to_pickle(datafolder2+'lonlat_8.pkl')
#done
# Out:
# Making a second attempt with the entire address - ;
# --WARNING-- Geolocation data not available for address: - ;

# %%
#lonlat_9 = dfs[9].Anschrift.apply(geolocator)
#lonlat_9.to_pickle(datafolder2+'lonlat_9.pkl')
#done
# Out:
# Making a second attempt with the entire address - ;
# --WARNING-- Geolocation data not available for address: - ;

# %% [markdown]
# ### Adding lon lat data to sub-dfs

# %%
for n in range(10):
    load = pd.read_pickle(datafolder2+'lonlat_'+str(n)+'.pkl')
    dfs[n]['longitude'] = load.apply(lambda x:x[0])
    dfs[n]['latitude'] = load.apply(lambda x:x[1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Merging dfs in a single df

# %%
df_output = pd.concat(dfs)
df_output.head()
# Out:
#     Kunden Id  K-Debitoren Id Debitoren Id Debitorenname 1  DUNS  UID  \
# 0     2004025               0   9999999999     CPD-Debitor   NaN  NaN
# 1  che2004009               0   9999999999     CPD-Debitor   NaN  NaN
# 2     2004056               0   9999999999     CPD-Debitor   NaN  NaN
# 3     2004071               0   9999999999     CPD-Debitor   NaN  NaN
# 4     2004037               0   9999999999     CPD-Debitor   NaN  NaN
#
#   Namenszusatz                            Anschrift            Währung  \
# 0          NaN    CH-1201 Genève; Quai du Seujet 12  Schweizer Franken
# 1          NaN      CH-8872 Weesen; Hauptstrasse 12  Schweizer Franken
# 2          NaN  CH-8001 Zürich; Weinbergstrasse  22  Schweizer Franken
# 3          NaN  CH-8001 Zürich; Weinbergstrasse  22  Schweizer Franken
# 4          NaN  CH-8001 Zürich; Weinbergstrasse  22  Schweizer Franken
#
#   Genehmigtes Limit Verfügbares Limit Mahnsperre Mahnsperre bis  \
# 0              0,00              0,00      keine            NaN
# 1              0,00              0,00      keine            NaN
# 2              0,00              0,00      keine            NaN
# 3              0,00              0,00      keine            NaN
# 4              0,00              0,00      keine            NaN
#
#    Sperre Debitor Eigene Factoringgebühren Zahlungsbedingung Limitgrundlage  \
# 0  nicht gesperrt                     Nein            30 net     kein Limit
# 1  nicht gesperrt                     Nein            90 Net     kein Limit
# 2  nicht gesperrt                     Nein            10 Net     kein Limit
# 3  nicht gesperrt                     Nein     30 Tage netto     kein Limit
# 4  nicht gesperrt                     Nein            10 Net     kein Limit
#
#    Telefon 1  longitude   latitude
# 0        NaN   6.145596  46.209789
# 1        NaN   9.111328  47.137560
# 2        NaN   8.541829  47.372767
# 3        NaN   8.541829  47.372767
# 4        NaN   8.541829  47.372767

# %%
df_output[df_output.longitude.isnull()]
# Out:
#        Kunden Id  K-Debitoren Id Debitoren Id  \
# 123   che2004001            1831      1010008
# 125   che2004001            1833      1010006
# 129   che2004001            1838      1010020
# 141   che2004001            1845      1180006
# 143   che2004001            1847      1180008
# 301   che2004012            1972        50118
# 317   che2004012            1988        50538
# 330   che2004012            1998         5502
# 370   che2004012            2030         6104
# 409   che2004012            2055        11307
# 425   che2004012            2068        50041
# 1328     2004011            2849      1200026
# 1331     2004011            2853      1200007
# 2502     2004021            3591         6014
# 2516     2004021            3603      1200022
# 2544     2004022            3619      1200024
# 2614  che2004007            3674       700002
# 2645  che2004012            3698         5859
# 2788  che2004015            3828       150007
# 3002  che2004015            4331       150015
# 3273  che2004017            4923       170012
# 5517     2004052            8733           42
# 6037     2004078           10059          243
#
#                                         Debitorenname 1         DUNS  UID  \
# 123                              ALTRAN Technologies SA          NaN  NaN
# 125                             Alstom Power Systems SA  482495202.0  NaN
# 129                          Akka Ingenerie Process SAS  487989840.0  NaN
# 141                    Siniat SA Pole Tech Agroparc Mft          NaN  NaN
# 143                      Spie Est SAS Geispolsheim Gare  486469567.0  NaN
# 301                 Derschlag Foliendruck GmbH & Co. KG  482342961.0  NaN
# 317           Valles Plastic Poligono Ind. El Carrascot  484521195.0  NaN
# 330                                           UNISLEEVE          NaN  NaN
# 370                         Stanley Press Equipment Ltd  487037533.0  NaN
# 409                                          DCM BP 406          NaN  NaN
# 425   Hydro Aluminium Rolled Products GmbH Accountin...  484620963.0  NaN
# 1328                      Unilever Asia Private Limited  481354806.0  NaN
# 1331                        ungeklärte Zahlungseingänge  483227252.0  NaN
# 2502                                     Benkert UK Ltd  482838778.0  NaN
# 2516                        Ungeklärte Zahlungseingänge  485979855.0  NaN
# 2544                        ungeklärte Zahlungseingänge  482695611.0  NaN
# 2614                                     Demour Limited  481482156.0  NaN
# 2645                          Welton Bibby & Baron Ltd.          NaN  NaN
# 2788                           Cutler & Woolf Steel Ltd          NaN  NaN
# 3002                     MERIDIAN METAL TRADING LIMITED  481414204.0  NaN
# 3273          SEMIMETAIS - SEMI-PRODUCTOS DE METAIS LDA          NaN  NaN
# 5517                              Studer Innenausbau AG          NaN  NaN
# 6037                        Elektrezitätswerk Uznach AG          NaN  NaN
#
#      Namenszusatz                                          Anschrift  \
# 123           NaN  FR-78457 Velizy-Villacoublay; 2, Rue Paul Daut...
# 125           NaN  FR-90041 Belfort Cedex; 3 Avenue des Trois Che...
# 129           NaN     FR-69258 LYON CEDEX 09; 21 RUE ANTONIN LABORDE
# 141           NaN  FR-84915 Avignon Cedex 9; 500 Rue Marcel Demon...
# 143           NaN  FR-67411 Illkirch Cedex; 2 Route de Lingolshei...
# 301           NaN     D-85813 Lüdenscheid; Werdohler Landstrasse 352
# 317           NaN  ES-46850 L'Olleria - Valencia; Fase A Carrer B...
# 330           NaN           FR-91421 Morangis Cedex; 15 avenue Arago
# 370           NaN      GB-SK117JL Cheshire; Gunco Lane, Macclesfield
# 409           NaN  FR-92004 Nanterre Cedex; 45 Avenue des Guiller...
# 425           NaN            D-41487 Grevenbroich; Aluminiumstraße 1
# 1328          NaN  SG-117439 Singapore; 20 Pasir Panjang Road, 06...
# 1331          NaN                                                - ;
# 2502          NaN                  GB-FK125DW Alva; Clackmannanshire
# 2516          NaN                                                - ;
# 2544          NaN                                                - ;
# 2614          NaN  GB-WD31JE Hertfordshire; Church street Rickman...
# 2645          NaN  GB-BA134JT Westbury; West wilts Trading Estati...
# 2788          NaN  GB-WD31JE Hertfordshire; Jubilee Trade Centre,...
# 3002          NaN  GB-GU32DX GUILFORD; SURREY; HENLEY BUSINESS PA...
# 3273          NaN  PT-4410083 VILA NOVA DE GAIA; RUA CAMINHO DO S...
# 5517          NaN                                                - ;
# 6037          NaN                                                - ;
#
#                 Währung Genehmigtes Limit Verfügbares Limit Mahnsperre  \
# 123   Schweizer Franken              0,00              0,00      keine
# 125   Schweizer Franken              0,00              0,00      keine
# 129   Schweizer Franken              0,00              0,00      keine
# 141   Schweizer Franken              0,00              0,00      keine
# 143   Schweizer Franken              0,00              0,00      keine
# 301   Schweizer Franken              0,00              0,00      keine
# 317   Schweizer Franken              0,00              0,00      keine
# 330   Schweizer Franken              0,00              0,00      keine
# 370   Schweizer Franken              0,00              0,00      keine
# 409   Schweizer Franken              0,00              0,00      keine
# 425   Schweizer Franken              0,00              0,00      keine
# 1328  Schweizer Franken              0,00              0,00      keine
# 1331  Schweizer Franken              0,00              0,00      keine
# 2502  Schweizer Franken              0,00              0,00      keine
# 2516  Schweizer Franken              0,00              0,00      keine
# 2544  Schweizer Franken              0,00              0,00      keine
# 2614               Euro         50'000,00         50'000,00      keine
# 2645               Euro              0,00              0,00      keine
# 2788   Britisches Pfund        150'000,00        150'000,00      keine
# 3002   Britisches Pfund      1'000'000,00      1'000'000,00      keine
# 3273               Euro              0,00              0,00      keine
# 5517  Schweizer Franken              0,00              0,00      keine
# 6037  Schweizer Franken              0,00              0,00      keine
#
#      Mahnsperre bis  Sperre Debitor Eigene Factoringgebühren  \
# 123             NaN  nicht gesperrt                     Nein
# 125             NaN  nicht gesperrt                     Nein
# 129             NaN  nicht gesperrt                     Nein
# 141             NaN  nicht gesperrt                     Nein
# 143             NaN  nicht gesperrt                     Nein
# 301             NaN  nicht gesperrt                     Nein
# 317             NaN  nicht gesperrt                     Nein
# 330             NaN  nicht gesperrt                     Nein
# 370             NaN  nicht gesperrt                     Nein
# 409             NaN  nicht gesperrt                     Nein
# 425             NaN  nicht gesperrt                     Nein
# 1328            NaN  nicht gesperrt                     Nein
# 1331            NaN  nicht gesperrt                     Nein
# 2502            NaN  nicht gesperrt                     Nein
# 2516            NaN  nicht gesperrt                     Nein
# 2544            NaN  nicht gesperrt                     Nein
# 2614            NaN  nicht gesperrt                     Nein
# 2645            NaN  nicht gesperrt                     Nein
# 2788            NaN  nicht gesperrt                     Nein
# 3002            NaN  nicht gesperrt                     Nein
# 3273            NaN  nicht gesperrt                     Nein
# 5517            NaN  nicht gesperrt                     Nein
# 6037            NaN  nicht gesperrt                     Nein
#
#      Zahlungsbedingung Limitgrundlage  Telefon 1  longitude  latitude
# 123             45 Net     kein Limit        NaN        NaN       NaN
# 125             45 Net     kein Limit        NaN        NaN       NaN
# 129             45 Net     kein Limit        NaN        NaN       NaN
# 141             45 Net     kein Limit        NaN        NaN       NaN
# 143             45 Net     kein Limit        NaN        NaN       NaN
# 301             30 Net     kein Limit        NaN        NaN       NaN
# 317             30 Net     kein Limit        NaN        NaN       NaN
# 330             30 Net     kein Limit        NaN        NaN       NaN
# 370             30 Net     kein Limit        NaN        NaN       NaN
# 409             30 Net     kein Limit        NaN        NaN       NaN
# 425             30 Net     kein Limit        NaN        NaN       NaN
# 1328            30 Net       KV-Limit        NaN        NaN       NaN
# 1331            30 Net     kein Limit        NaN        NaN       NaN
# 2502            30 Net     kein Limit        NaN        NaN       NaN
# 2516            30 Net     kein Limit        NaN        NaN       NaN
# 2544            30 Net     kein Limit        NaN        NaN       NaN
# 2614            30 Net       KV-Limit        NaN        NaN       NaN
# 2645            30 Net     kein Limit        NaN        NaN       NaN
# 2788            60 Net       KV-Limit        NaN        NaN       NaN
# 3002            60 Net       KV-Limit        NaN        NaN       NaN
# 3273            90 Net     kein Limit        NaN        NaN       NaN
# 5517            10 Net       KV-Limit        NaN        NaN       NaN
# 6037     30 Tage netto       KV-Limit        NaN        NaN       NaN

# %%
df_output.to_pickle(datafolder2+'company_info.pkl')
