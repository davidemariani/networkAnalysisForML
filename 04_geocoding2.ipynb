# %% [markdown]
# # Geocoding

# %% [markdown]
# This script retrieves longitude and latitude data for the company contained in the file 'Go_Factoring_Output_Perfect_Matches_20180912.XLSX' provided.

# %% [markdown]
# ### Data import

# %%
import pandas as pd
import numpy as np
import time

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

import os

# %%
user = os.environ['USERNAME']
datafolder = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/original_data/".format(user)
file = 'Go_Factoring_Output_Perfect_Matches_20180912.XLSX'
df = pd.read_excel(datafolder+file, header=1)
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
df.shape
# Out:
# (4460, 41)

# %%
df.head().transpose()
# Out:
#                                                    0  \
# id                                                 6
# kunden_id                                    2004052
# k-debitoren_id                                  6604
# debitorenname_1         1A Swiss Dienstleistungen AG
# anschrift               CH-5034 Suhr; Bachstrasse 33
# straße                                   Bachstrasse
# plz                                             5034
# ort                                             Suhr
# customer_id                                        6
# duns                                       480116741
# firma                   1A Swiss Dienstleistungen AG
# handelsname                                      NaN
# c/o_domiziladresse                               NaN
# domiziladresse                        Bachstrasse 33
# zusatz_domiziladresse                            NaN
# plz_domiziladresse                              5034
# ort_domiziladresse                              Suhr
# kanton_domiziladresse                             AG
# land_domiziladresse                               CH
# c/o_postadresse                                  NaN
# postadresse                           Bachstrasse 33
# zusatz_postadresse                               NaN
# plz_postadresse                                 5034
# ort_postadresse                                 Suhr
# kanton_postadresse                                AG
# land_postadresse                                  CH
# postfachadresse                                  NaN
# plz_postfachadresse                              NaN
# ort_postfachadresse                              NaN
# kanton_postfachadresse                           NaN
# land_postfachadresse                             NaN
# sprache                                      deutsch
# handelsregister-nummer                 CH40034407511
# uid                                  CHE-315.855.880
# regn_nbr_vat                                     NaN
# rechtsform                        Aktiengesellschaft
# duns_hauptsitz                                   NaN
# name_hauptsitz                                   NaN
# ort_hauptsitz                                    NaN
# land_hauptsitz                                   NaN
# aktivitätsstatus                               aktiv
#
#                                                             1  \
# id                                                          7
# kunden_id                                                 NaN
# k-debitoren_id                                           3499
# debitorenname_1                                 3.M.E.L. GmbH
# anschrift               CH-5734 Reinach AG; Pilatusstrasse 32
# straße                                      Pilatusstrasse 32
# plz                                                      5734
# ort                                                Reinach AG
# customer_id                                                 7
# duns                                                486977734
# firma                            3.M.E.L. GmbH in Liquidation
# handelsname                                               NaN
# c/o_domiziladresse                                        NaN
# domiziladresse                              Pilatusstrasse 32
# zusatz_domiziladresse                                     NaN
# plz_domiziladresse                                       5734
# ort_domiziladresse                                 Reinach AG
# kanton_domiziladresse                                      AG
# land_domiziladresse                                        CH
# c/o_postadresse                                           NaN
# postadresse                                 Pilatusstrasse 32
# zusatz_postadresse                                        NaN
# plz_postadresse                                          5734
# ort_postadresse                                    Reinach AG
# kanton_postadresse                                         AG
# land_postadresse                                           CH
# postfachadresse                                           NaN
# plz_postfachadresse                                       NaN
# ort_postfachadresse                                       NaN
# kanton_postfachadresse                                    NaN
# land_postfachadresse                                      NaN
# sprache                                               deutsch
# handelsregister-nummer                          CH40040369009
# uid                                           CHE-258.353.008
# regn_nbr_vat                                              NaN
# rechtsform              Gesellschaft mit beschränkter Haftung
# duns_hauptsitz                                            NaN
# name_hauptsitz                                            NaN
# ort_hauptsitz                                             NaN
# land_hauptsitz                                            NaN
# aktivitätsstatus                                     gelöscht
#
#                                                             2  \
# id                                                          8
# kunden_id                                             2004078
# k-debitoren_id                                           4139
# debitorenname_1                                   36GRAD GmbH
# anschrift                            CH-6039 Root D4; Platz 3
# straße                                                Platz 3
# plz                                                      6039
# ort                                                   Root D4
# customer_id                                                 8
# duns                                                480141611
# firma                                             36GRAD GmbH
# handelsname                                               NaN
# c/o_domiziladresse                                        NaN
# domiziladresse                                        Platz 3
# zusatz_domiziladresse                                     NaN
# plz_domiziladresse                                       6039
# ort_domiziladresse                            Root Längenbold
# kanton_domiziladresse                                      LU
# land_domiziladresse                                        CH
# c/o_postadresse                                           NaN
# postadresse                                           Platz 3
# zusatz_postadresse                                        NaN
# plz_postadresse                                          6039
# ort_postadresse                               Root Längenbold
# kanton_postadresse                                         LU
# land_postadresse                                           CH
# postfachadresse                                           NaN
# plz_postfachadresse                                       NaN
# ort_postfachadresse                                       NaN
# kanton_postfachadresse                                    NaN
# land_postfachadresse                                      NaN
# sprache                                               deutsch
# handelsregister-nummer                          CH10048022038
# uid                                           CHE-447.812.384
# regn_nbr_vat                                              NaN
# rechtsform              Gesellschaft mit beschränkter Haftung
# duns_hauptsitz                                            NaN
# name_hauptsitz                                            NaN
# ort_hauptsitz                                             NaN
# land_hauptsitz                                            NaN
# aktivitätsstatus                                        aktiv
#
#                                                               3  \
# id                                                            9
# kunden_id                                                   NaN
# k-debitoren_id                                            12066
# debitorenname_1                                  3A Schreinerei
# anschrift               CH-2558 Aegerten; Schwadernaustrasse 63
# straße                                    Schwadernaustrasse 63
# plz                                                        2558
# ort                                                    Aegerten
# customer_id                                                   9
# duns                                                  486942464
# firma                                         3A Schreinerei AG
# handelsname                                                 NaN
# c/o_domiziladresse                                          NaN
# domiziladresse                            Schwadernaustrasse 63
# zusatz_domiziladresse                                       NaN
# plz_domiziladresse                                         2558
# ort_domiziladresse                                     Aegerten
# kanton_domiziladresse                                        BE
# land_domiziladresse                                          CH
# c/o_postadresse                                             NaN
# postadresse                               Schwadernaustrasse 63
# zusatz_postadresse                                          NaN
# plz_postadresse                                            2558
# ort_postadresse                                        Aegerten
# kanton_postadresse                                           BE
# land_postadresse                                             CH
# postfachadresse                                             NaN
# plz_postfachadresse                                         NaN
# ort_postfachadresse                                         NaN
# kanton_postfachadresse                                      NaN
# land_postfachadresse                                        NaN
# sprache                                                 deutsch
# handelsregister-nummer                            CH03630570797
# uid                                             CHE-208.196.936
# regn_nbr_vat                                                NaN
# rechtsform                                   Aktiengesellschaft
# duns_hauptsitz                                              NaN
# name_hauptsitz                                              NaN
# ort_hauptsitz                                               NaN
# land_hauptsitz                                              NaN
# aktivitätsstatus                                          aktiv
#
#                                                                  4
# id                                                              11
# kunden_id                                                      NaN
# k-debitoren_id                                                5732
# debitorenname_1                                      3S Partner AG
# anschrift               CH-6020 Emmenbrücke; Gerliswilstrasse 19 b
# straße                                            Gerliswilstrasse
# plz                                                           6020
# ort                                                    Emmenbrücke
# customer_id                                                     11
# duns                                                     481936891
# firma                                                3S Partner AG
# handelsname                                                    NaN
# c/o_domiziladresse                                             NaN
# domiziladresse                                Gerliswilstrasse 19b
# zusatz_domiziladresse                                          NaN
# plz_domiziladresse                                            6020
# ort_domiziladresse                                     Emmenbrücke
# kanton_domiziladresse                                           LU
# land_domiziladresse                                             CH
# c/o_postadresse                                                NaN
# postadresse                                   Gerliswilstrasse 19b
# zusatz_postadresse                                             NaN
# plz_postadresse                                               6020
# ort_postadresse                                        Emmenbrücke
# kanton_postadresse                                              LU
# land_postadresse                                                CH
# postfachadresse                                                NaN
# plz_postfachadresse                                            NaN
# ort_postfachadresse                                            NaN
# kanton_postfachadresse                                         NaN
# land_postfachadresse                                           NaN
# sprache                                                    deutsch
# handelsregister-nummer                               CH10040262069
# uid                                                CHE-109.644.693
# regn_nbr_vat                                  CHE-109.644.693 MWST
# rechtsform                                      Aktiengesellschaft
# duns_hauptsitz                                                 NaN
# name_hauptsitz                                                 NaN
# ort_hauptsitz                                                  NaN
# land_hauptsitz                                                 NaN
# aktivitätsstatus                                             aktiv

# %%
def do_geocode(address):
    geoloc = Nominatim(user_agent='lon-lat-retrieval', timeout=12)
    geocoder = RateLimiter(geoloc.geocode, min_delay_seconds=1, max_retries=50) #rate limiter to avoid being blocked
    try:
        location = geocoder(address)
        return location
    except GeocoderTimedOut:
        return do_geocode(address)
    
def create_add(geoinfo):
    
    if len(geoinfo)>0:
        ad = ''
        for s in range(len(geoinfo)):
            if s!=0:
                ad+=' '
                ad+=geoinfo[s]
            else:
                ad+=geoinfo[s]
        return ad
    else:
        return None

def geolocator_2(company, count, address, postcode, canton, country, req_limit=500, timesleep=100):     #location, 
    """
    This function, given the following strings representing the address, will return latitude and longitude, if available.
    NaN otherwise.
    - Postadresse
    - PLZ
    - Kanton Postadresse
    - Land Postadresse
    """
    
    if count!=0 and count%req_limit==0:
        print("!!-- SCRIPT TEMPORARY SLEEPING FOR {} SECS TO AVOID TIMEOUT ERROR --!!".format(timesleep))
        time.sleep(timesleep)
    
    geoinfo = []
    
    #ADDRESS
    if pd.isnull(address):
        print('no address available for company {}'.format(company))
        addresse=''
    else:
        geoinfo.append(str(address))
    
    #POSTCODE
    pcodedata = False
    if not pd.isnull(country) and not pd.isnull(postcode):
        pcodedata=True
        geoinfo.append(str(country)+'-'+str(postcode))
    else:
        if pd.isnull(country):
            print('no country information available for company {}'.format(company))
            country=''
        else:
            geoinfo.append(str(country))

        if pd.isnull(postcode):
            print('no postcode available for company {}'.format(company))
            postcode=''
        else:
            geoinfo.append(str(postcode))
        
    ad = create_add(geoinfo)
    
    if ad!=None:
        location = do_geocode(ad)
        if location:
            lat = location.latitude
            lon = location.longitude
            return lon, lat
        else:
            geoinfo = []
            print("Making a new attempt for company {} with postcode and canton area".format(company))
            if pcodedata:
                geoinfo.append(str(country)+'-'+str(postcode))
            if pd.isnull(canton):
                print('no canton information available for company {}'.format(company))
                canton=''    
            else:
                geoinfo.append(str(canton))
                
            ad = create_add(geoinfo)
            if ad!=None:
                location = do_geocode(ad)
                if location:
                    print("Successful attempt!")
                    lat = location.latitude
                    lon = location.longitude
                    return lon, lat
                else:
                    print("--WARNING-- Geolocation data not available for company {} with input '{}'".format(company, ad))
                    lat = np.nan
                    lon = np.nan
                    return lon, lat
            else:
                print("--WARNING-- Geolocation data not available for company {} with input '{}'".format(company, ad))
                lat = np.nan
                lon = np.nan
                return lon, lat       
    else:
        print('--WARNING-- Geolocation data not available for company: {}'.format(company))
        lat = np.nan
        lon = np.nan
        return lon, lat

# %%
#try
try1=df.iloc[0]
geolocator_2(try1.debitorenname_1, 0, try1.postadresse, try1.plz, try1.kanton_postadresse, try1.land_postadresse) # try1.ort,
# Out:
# (8.0792366, 47.382247)

# %%
lon = []
lat = []
count = 0
for r in range(len(df)):
    row = df.iloc[r]
    lonlat = geolocator_2(row.debitorenname_1, r, row.postadresse, row.plz, row.kanton_postadresse, row.land_postadresse)
    lon.append(lonlat[0])
    lat.append(lonlat[1])
    if r%500==0:
        count+=1
        dftemp = pd.DataFrame({'longitude':lon, 'latitude':lat})
        dftemp.to_pickle(datafolder+'lonlat_progress'+str(count))
    elif r==len(df):
        dftemp = pd.DataFrame({'longitude':lon, 'latitude':lat})
        dftemp.to_pickle(datafolder+'lonlat_final')
# Out:
# Making a new attempt for company 4B Fenster AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company A. Kuster AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company A1-Bau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company AC Mächler AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Adecco Human Resources AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company ADEFI SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Adnan Görgülü Industrieservice with postcode and canton area
# Successful attempt!
# Making a new attempt for company Adolf Barmettler Dachdeckerei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Adolf Müller GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Adriatic Group SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company AF Hauswartung GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Albert Storenbau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Allround Service Team GmbH with postcode and canton area
# Successful attempt!
# no address available for company Alpiq InTec Ost AG
# Making a new attempt for company Alpiq InTec Schweiz with postcode and canton area
# Successful attempt!
# no address available for company Alpiq InTec Schweiz AG
# no address available for company Alpiq InTec Schweiz AG
# no address available for company Alpiq InTec Schweiz AG
# no address available for company Alpiq InTec Schweiz AG
# Making a new attempt for company Alpiq InTec Schweiz AG with postcode and canton area
# Successful attempt!
# no address available for company Alpiq InTec Schweiz AG
# Making a new attempt for company Alpkäserei Urnerboden AG with postcode and canton area
# Successful attempt!
# no address available for company amotec AG für Montagetechnik
# Making a new attempt for company Ancon Akkord GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Anderegg Kran AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Anderhub Metallbearbeitungs GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Andreas Schenk-Heimann with postcode and canton area
# Successful attempt!
# Making a new attempt for company Anobia Holzbau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Architekturbüro A. Bösch GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company A-Renovation SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Aria-Lüftungstechnik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Arnosti Arkuba AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Arredamenti Poretti Roberto with postcode and canton area
# Successful attempt!
# Making a new attempt for company AS Aufzüge AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Asbestdemontagen plus GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company ASK Umbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company ASK Umbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Athleticum Sportsmarkets AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Athleticum Sportsmarkets AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company ATHLETICUM Sportsmarkets AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Attenhofer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Attenhofer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Auto Lanter AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Autohaus Gertsch AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Backes & Strauss with postcode and canton area
# Successful attempt!
# Making a new attempt for company Badrutt's Palace Hotel AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bärtsch Bodenbeläge GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Baud Marc SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Baufix Elemente GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Baumgartner AG, Bedachungen und Fassaden with postcode and canton area
# Successful attempt!
# Making a new attempt for company Baumgartner AG, Bedachungen und Fassaden with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bautech AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Beat Bähler, Metallbau with postcode and canton area
# Successful attempt!
# Making a new attempt for company BeFi Facility Services GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company BELFOR with postcode and canton area
# Successful attempt!
# no address available for company Bemu AG
# no country information available for company Bemu AG
# Making a new attempt for company Benjamin Etanchéitê Sàrl with postcode and canton area
# Successful attempt!
# !!-- SCRIPT TEMPORARY SLEEPING FOR 100 SECS TO AVOID TIMEOUT ERROR --!!
# Making a new attempt for company BEO Elecom GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Berisha Gerüstbau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Besmer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Besmer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Besmer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bieber Gartenbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bieber Gartenbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bilfinger Industrial Services Schweiz AG Postfach with postcode and canton area
# Successful attempt!
# Making a new attempt for company Binna Holzbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Birchmeier AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Birchmeier Bau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bischof Bauunternehmung AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company BK Bau & Gipsen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company BK Gips GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company BKW Energie AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company BLOM BANK (Switzerland) SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Blumbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bodan Gerüstbau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company boden & design gmbh with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bodenbeläge Truffer Philipp, Filiale with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bölsterli Andreas, Spenglerei / Bedachungen / Sani with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bomdia GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Borrello chauffage-sanitaire with postcode and canton area
# Successful attempt!
# Making a new attempt for company Britt Interior with postcode and canton area
# Successful attempt!
# Making a new attempt for company Broch Sandro with postcode and canton area
# Successful attempt!
# Making a new attempt for company Brünig Bau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bruno Camponovo with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bruno Stadelmann GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bruppacher Verwaltungs AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Brusa Bauunternehmung AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company BST Partners Group AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Bünter & Mathis AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Burri Möbel with postcode and canton area
# Successful attempt!
# Making a new attempt for company Büwe Tiefbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company BV Trans Cetinkaya with postcode and canton area
# Successful attempt!
# no address available for company Cafe de la Paix
# Making a new attempt for company Carlo Massaro AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Carlo Massaro AG with postcode and canton area
# Successful attempt!
# no address available for company Carrosserie du Rhône Sàrl
# Making a new attempt for company Cartapacking SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company CARTEC Carrosserie-Technik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Caruma Treuhand AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Cave du Tunnel with postcode and canton area
# Successful attempt!
# Making a new attempt for company CECIL PURNELL with postcode and canton area
# Successful attempt!
# Making a new attempt for company CFT Cleaning Team GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Challet Philippe with postcode and canton area
# Successful attempt!
# Making a new attempt for company Charles-Emile Moinat & Fils SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Chrigels Bereitschafts Service with postcode and canton area
# Successful attempt!
# Making a new attempt for company Clair Net with postcode and canton area
# Successful attempt!
# Making a new attempt for company Clean-Service AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Colak Spenglerei with postcode and canton area
# Successful attempt!
# Making a new attempt for company COLLEDANI AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company COLLEDANI AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Contact Stores Sàrl with postcode and canton area
# Successful attempt!
# Making a new attempt for company Contact Stores Sàrl with postcode and canton area
# Successful attempt!
# Making a new attempt for company Continental Compass SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Coop Genossenschaft with postcode and canton area
# Successful attempt!
# Making a new attempt for company Coop Genossenschaft with postcode and canton area
# Successful attempt!
# Making a new attempt for company Coop Genossenschaft with postcode and canton area
# Successful attempt!
# Making a new attempt for company Coop Genossenschaft with postcode and canton area
# Successful attempt!
# Making a new attempt for company Coop Genossenschaft with postcode and canton area
# Successful attempt!
# Making a new attempt for company Coop Genossenschaft with postcode and canton area
# Successful attempt!
# Making a new attempt for company Covertec AG Montagetechnik with postcode and canton area
# Successful attempt!
# Making a new attempt for company Covertec AG Montagetechnik with postcode and canton area
# Successful attempt!
# no address available for company Curic Bassi Sagl
# Making a new attempt for company D.E.S. Systèmes de sécurité SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Dachtechnik Donat Perren AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Daetmetall AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Dämmtechnik BZ Peng GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company DANI-A Sarl with postcode and canton area
# Successful attempt!
# Making a new attempt for company Daniel Fournier Agencement SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company das licht.gmbh with postcode and canton area
# Successful attempt!
# Making a new attempt for company Dean Gips AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Dell'Oca Baukeramik GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Diamond & Flair GmbH with postcode and canton area
# Successful attempt!
# !!-- SCRIPT TEMPORARY SLEEPING FOR 100 SECS TO AVOID TIMEOUT ERROR --!!
# Making a new attempt for company DIMITTO SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company DIOM AG Zargen und Türenmontagen with postcode and canton area
# Successful attempt!
# Making a new attempt for company Dolphins AG Bau Group with postcode and canton area
# no canton information available for company Dolphins AG Bau Group
# Successful attempt!
# Making a new attempt for company Donà und Studhalter GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company DST Combitrans AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Dunoyer Construction S.A. with postcode and canton area
# Successful attempt!
# Making a new attempt for company dwt Dach-Wand-Technik GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company E. Nüesch-Kuster + Co. with postcode and canton area
# Successful attempt!
# Making a new attempt for company E.P. 24 AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Eco Sanitaires, Bytyci with postcode and canton area
# Successful attempt!
# Making a new attempt for company Eddy Fritz with postcode and canton area
# Successful attempt!
# no address available for company Eerhard & Oliveira Da Silva Consulting AG
# no country information available for company Eerhard & Oliveira Da Silva Consulting AG
# Making a new attempt for company Elektro Aregger Willisau AG with postcode and canton area
# Successful attempt!
# no address available for company Elektro Bernina AG
# RateLimiter caught an error, retrying (0/50 tries). Called with (*('Bahnhofstrasse 24 CH-8240',), **{}).
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1318, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 964, in send
#     self.connect()
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1400, in connect
#     server_hostname=server_hostname)
#   File "C:\ProgramData\Anaconda3\lib\ssl.py", line 407, in wrap_socket
#     _context=self, _session=session)
#   File "C:\ProgramData\Anaconda3\lib\ssl.py", line 817, in __init__
#     self.do_handshake()
#   File "C:\ProgramData\Anaconda3\lib\ssl.py", line 1077, in do_handshake
#     self._sslobj.do_handshake()
#   File "C:\ProgramData\Anaconda3\lib\ssl.py", line 689, in do_handshake
#     self._sslobj.do_handshake()
# socket.timeout: _ssl.c:835: The handshake operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 344, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 526, in open
#     response = self._open(req, data)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 544, in _open
#     '_open', req)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 504, in _call_chain
#     result = func(*args)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1320, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error _ssl.c:835: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 309, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# Making a new attempt for company Elektro Buck GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Christoffel with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Christoffel with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Furrer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Hediger Elektroinstallationsgeschäft with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Illi AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Illi AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Jucker & Partner GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Schmid AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Schmid AG Elektroinstallationsgeschäft with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Supersaxo AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Supersaxo AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro Zemp GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Elektro-Wehrli AG Elektroanlagen with postcode and canton area
# Successful attempt!
# Making a new attempt for company eliv AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Emil Gloggner AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Emil Gloggner AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Emme Haustechnik GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Energie Systeme Vrella GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Engie Services AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company ENGIE Services AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Enzo Gispergeschäft GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Ergostyle SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Ernest Bau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company ERNI Consulting AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Ernst & Young AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Ewald Gattlen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company F. Huber Metallbau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company F. Huber Metallbau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company FA MENUISERIE EBENISTERIE SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company FC Aarau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fehr Albert with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fernsicht- Immobilien AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company FHB Bau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fischer Electric AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fit- & Wellness Concept GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fliri & Conrad Electro SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fliri & Conrad Electro SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Floc AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Foffa Conrad AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Frabetti Metallbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Frabetti Metallbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Franz Rehmann Gipsergeschäft Nachfolger Hanspeter with postcode and canton area
# Successful attempt!
# !!-- SCRIPT TEMPORARY SLEEPING FOR 100 SECS TO AVOID TIMEOUT ERROR --!!
# Making a new attempt for company Frey Paul Elektrogeschäft with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fritz Kaufmann with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fritz Nussbaum AG Bauunternehmung with postcode and canton area
# Successful attempt!
# Making a new attempt for company Frutiger AG Basel with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fuchs & Müller AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Fürer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Futra Dach und Bau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Futra GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company GAILLARD FRERES STORES with postcode and canton area
# Successful attempt!
# Making a new attempt for company Galli Holzbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Ganter Basel AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Garage du Signal SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Garage Ebneter AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company GARIN MARCEL with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gartenbau und Floristik Walter Frick with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gassmann AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gebrüder Maissen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gebrüder Maissen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gebrüder Rüger AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Geneux-Dancet SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gerag, Gerüstebau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company GIB Management AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gio Ceramica GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gipser Kamaj GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gislerbau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gnägi Aquatech AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Goldbeck Rhomberg AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Göldi AG, Garten- und Sportplatzbau with postcode and canton area
# Successful attempt!
# no address available for company Golfhotel les hauts de Gstaad
# Making a new attempt for company Granella AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Green Pact AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Green Terra AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company GREUBEL FORSEY SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gromann und Murer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gromann und Murer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Grüninger AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gübeli Sanitär AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gufler GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Guido Mächler Akkordunternehmung - Spezial with postcode and canton area
# Successful attempt!
# Making a new attempt for company Gwerder Tech GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company H. Kreiner AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company H. Mösch AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company H.J. Baumann with postcode and canton area
# Successful attempt!
# Making a new attempt for company Habersaat AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Häcki Oswald with postcode and canton area
# Successful attempt!
# Making a new attempt for company Häfliger Consulting AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company hajk Scout & Sport AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hälg & Co. AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hälg & Co. AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Haller Gerüstbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Haller Gerüstbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Häller Roger Schreinerei with postcode and canton area
# Successful attempt!
# Making a new attempt for company Ham Occasionen GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hampton & Meier SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hampton & Meier SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hans Frei Textil AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hans Rudolf Trachsel AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hansueli Brawand with postcode and canton area
# Successful attempt!
# Making a new attempt for company HASANI SERVICE & CO with postcode and canton area
# Successful attempt!
# Making a new attempt for company Haustechnik P. Baumann AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Haustechnik P. Baumann AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hediger Elektro with postcode and canton area
# Successful attempt!
# Making a new attempt for company Heggli u. Gubler AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Heim AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hertig Gebr. GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Herzog Architekten AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Herzog Architekten AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hess Fenster AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hilbe Bodenbeläge Anstalt with postcode and canton area
# no canton information available for company Hilbe Bodenbeläge Anstalt
# Successful attempt!
# Making a new attempt for company Hochreutener Elektro AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company hogla ag with postcode and canton area
# Successful attempt!
# Making a new attempt for company Holzbau Haag Arosa GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Holzbau und Bedachungen Maurer & von Bergen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hot Shape by Weithaler with postcode and canton area
# no canton information available for company Hot Shape by Weithaler
# Successful attempt!
# Making a new attempt for company Hot&Partner GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company HP Gretsch GmbH with postcode and canton area
# RateLimiter caught an error, retrying (0/50 tries). Called with (*('CH-8507 TG',), **{}).
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1318, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 964, in send
#     self.connect()
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1392, in connect
#     super().connect()
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 936, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\ProgramData\Anaconda3\lib\socket.py", line 724, in create_connection
#     raise err
#   File "C:\ProgramData\Anaconda3\lib\socket.py", line 713, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 344, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 526, in open
#     response = self._open(req, data)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 544, in _open
#     '_open', req)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 504, in _call_chain
#     result = func(*args)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1320, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 309, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# Successful attempt!
# !!-- SCRIPT TEMPORARY SLEEPING FOR 100 SECS TO AVOID TIMEOUT ERROR --!!
# Making a new attempt for company Huber Dach und Wand AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Hurni Engineering Sàrl with postcode and canton area
# Successful attempt!
# Making a new attempt for company Husner AG Holzbau with postcode and canton area
# Successful attempt!
# Making a new attempt for company HW Manufacture SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company ICM Swiss AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company IGKG Züri with postcode and canton area
# Successful attempt!
# Making a new attempt for company Illudec AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Imfeld Metall- und Stahlbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Immobilien Aktiengesellschaft Doso with postcode and canton area
# Successful attempt!
# Making a new attempt for company Impregest SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company ISS Facility Services AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company J. Zbinden Service  AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company J. Zbinden Service  AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company J. Zbinden Service  AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company J.D.S ECHAFAUDAGES SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jahaj Armierungen GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jakob Strasser with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jeff Communications GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company JMS RISI AG with postcode and canton area
# Successful attempt!
# no address available for company Johanneum
# Making a new attempt for company Jost AG Frutigen with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jost Immo AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jotterand Charpentier/Bâtisseur SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jung & Partner Bauspenglerei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jung & Partner Bauspenglerei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jung und Partner Bauspenglerei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jung und Partner Bauspenglerei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jung und Partner Bauspenglerei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Jung und Partner Bauspenglerei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company K. Reimann AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company K. Suter AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Kälin Elektro & Telematik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Kältetechnik Bosshard GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Kaminfeger Arthur Pousaz with postcode and canton area
# Successful attempt!
# Making a new attempt for company Karl Hersche-Weder with postcode and canton area
# Successful attempt!
# Making a new attempt for company Karl Rölli with postcode and canton area
# Successful attempt!
# Making a new attempt for company Karl Rölli Holzbau with postcode and canton area
# Successful attempt!
# Making a new attempt for company Karl Tschudin AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Karlen Maçonnerie Génie-civil SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Kies + Beton Münchwilen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Klima AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Knecht AG Bauhandwerk + Architekturbüro with postcode and canton area
# Successful attempt!
# Making a new attempt for company Knecht AG Bauhandwerk + Architekturbüro with postcode and canton area
# Successful attempt!
# Making a new attempt for company Knobel Haustechnik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Krähenbühl AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Krämer AG Bassersdorf with postcode and canton area
# Successful attempt!
# Making a new attempt for company Krapf GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company KRONOSTAHL SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Küchler + Wyrsch AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Kündig AG Holzbau with postcode and canton area
# Successful attempt!
# Making a new attempt for company Kurt Borer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Kurth Architekten AG with postcode and canton area
# RateLimiter caught an error, retrying (0/50 tries). Called with (*('CH-3008 BE',), **{}).
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1318, in do_open
#     encode_chunked=req.has_header('Transfer-encoding'))
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1239, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1285, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1234, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1026, in _send_output
#     self.send(msg)
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 964, in send
#     self.connect()
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 1392, in connect
#     super().connect()
#   File "C:\ProgramData\Anaconda3\lib\http\client.py", line 936, in connect
#     (self.host,self.port), self.timeout, self.source_address)
#   File "C:\ProgramData\Anaconda3\lib\socket.py", line 724, in create_connection
#     raise err
#   File "C:\ProgramData\Anaconda3\lib\socket.py", line 713, in create_connection
#     sock.connect(sa)
# socket.timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 344, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 526, in open
#     response = self._open(req, data)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 544, in _open
#     '_open', req)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 504, in _call_chain
#     result = func(*args)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1320, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 309, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# Successful attempt!
# Making a new attempt for company Laima Holding AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Landollina Haustechnik GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company L'AQ AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company L'AQ AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Lauber SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Lauclair AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company le Chalet d'Adrien Le Grenier with postcode and canton area
# Successful attempt!
# !!-- SCRIPT TEMPORARY SLEEPING FOR 100 SECS TO AVOID TIMEOUT ERROR --!!
# Making a new attempt for company Leutwyler Kühlanlagen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company LGT Financial Service AG with postcode and canton area
# no canton information available for company LGT Financial Service AG
# Successful attempt!
# Making a new attempt for company Lidubene GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Lieberherr AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Louis Genève SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Lüchinger + Schmid AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Ludwig Elkuch AG with postcode and canton area
# no canton information available for company Ludwig Elkuch AG
# Successful attempt!
# Making a new attempt for company Lunox Swiss AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Lütolf Teppich + Bodenbeläge GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Maler- & Gipsergenossenschaft Biel with postcode and canton area
# Successful attempt!
# Making a new attempt for company Maler Altmann Arosa with postcode and canton area
# Successful attempt!
# Making a new attempt for company Malergeschäft Bieri GmbH with postcode and canton area
# Successful attempt!
# no address available for company Malergeschäft Renato Summermatter
# Making a new attempt for company Mammut Sports Group AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Manufacture Cartier with postcode and canton area
# Successful attempt!
# Making a new attempt for company MARCOLIN ELEKTRO GMBH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Markus Maurer Elektroanlagen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Marquis AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Masserey Intérieur SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Mata Handels AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Mata Handels AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company MATAMOROS SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Maurus Cathomas AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Maximal Group AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Mayer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company MB-Sanitär-Heizung GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company MC Décoration with postcode and canton area
# Successful attempt!
# Making a new attempt for company MCS Multipla GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Meag AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Meier-Ehrensperger AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Meisser Immobilien GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Menétrey-Lausanne SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Merschnigg Teppich und Bodenbeläge with postcode and canton area
# Successful attempt!
# Making a new attempt for company Meta Tech AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Mettler Hans Storenbau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Metzgerei Safiental with postcode and canton area
# Successful attempt!
# Making a new attempt for company Michael Egli Gartenbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Montafort AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Morisod SA Constructions with postcode and canton area
# Successful attempt!
# Making a new attempt for company MPS Steuerungen AG with postcode and canton area
# Successful attempt!
# no address available for company MST Security Consulting GmbH
# no country information available for company MST Security Consulting GmbH
# Making a new attempt for company Muhmenthaler GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Multis Renova Suisse S.A. with postcode and canton area
# Successful attempt!
# no address available for company Murisier Michel
# Making a new attempt for company Mutti Wohnideen with postcode and canton area
# Successful attempt!
# Making a new attempt for company Neeser Schreinerei  AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company NeoVac ATA AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company New Dance Academy GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Niggli Villiger AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Nischelwitzer AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Nova - Pool SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company NTPK Umweltservice GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Nussbaumer Holzbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Nussbaumer Holzbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Nussbaumer Holzbau AG with postcode and canton area
# Successful attempt!
# ...
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 344, in _call_geocoder
#     page = requester(req, timeout=timeout, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 526, in open
#     response = self._open(req, data)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 544, in _open
#     '_open', req)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 504, in _call_chain
#     result = func(*args)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1361, in https_open
#     context=self._context, check_hostname=self._check_hostname)
#   File "C:\ProgramData\Anaconda3\lib\urllib\request.py", line 1320, in do_open
#     raise URLError(err)
# urllib.error.URLError: <urlopen error _ssl.c:835: The handshake operation timed out>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\extra\rate_limiter.py", line 126, in __call__
#     return self.func(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\osm.py", line 309, in geocode
#     self._call_geocoder(url, timeout=timeout), exactly_one
#   File "C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py", line 367, in _call_geocoder
#     raise GeocoderTimedOut('Service timed out')
# geopy.exc.GeocoderTimedOut: Service timed out
# Making a new attempt for company Profi Eisenleger AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company PRONAVAL SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Propac AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company PSP Trockenbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Publicitas AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company PX Group SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Qerreti Bauunternehmen with postcode and canton area
# Successful attempt!
# no address available for company Quadroni Linard
# Making a new attempt for company R & V GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company R. Betschart Holzbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company R. Rageth GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Raiffeisenbank Wittenbach with postcode and canton area
# Successful attempt!
# Making a new attempt for company Rawlinson & Hunter (Zürich) AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Rechsteiner AG Appenzell with postcode and canton area
# Successful attempt!
# Making a new attempt for company Reinigung Rueff AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Rene Huber with postcode and canton area
# Successful attempt!
# Making a new attempt for company Renovbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Reppucci Malerei + Gipserei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Resu AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Rethan AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company RIA Parkett AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company ricky-tec GmbH with postcode and canton area
# Successful attempt!
# no address available for company RIEDER & RITLER AG
# Making a new attempt for company RKS Invest AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Robin du Bois Dorthe SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Rodrigues da Silva BAU with postcode and canton area
# Successful attempt!
# Making a new attempt for company RODRIGUEZ et Fils SARL with postcode and canton area
# Successful attempt!
# Making a new attempt for company Rolf Wehrli Schreinerei/Sonnen- und Blendschutz with postcode and canton area
# Successful attempt!
# Making a new attempt for company Roman Hermann AG with postcode and canton area
# no canton information available for company Roman Hermann AG
# Successful attempt!
# Making a new attempt for company Rossi Binna AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Round Office SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company r-team Schreinerei AG with postcode and canton area
# Successful attempt!
# no address available for company RUAG Schweiz AG
# Making a new attempt for company Rustemi AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Rustemi AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company S.I. Berthoud Immob SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Sanitär Frei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Sanitär Wirth AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Saspago AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Saspago AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Saspago AG with postcode and canton area
# Successful attempt!
# !!-- SCRIPT TEMPORARY SLEEPING FOR 100 SECS TO AVOID TIMEOUT ERROR --!!
# Making a new attempt for company Sauter Wärmetechnik GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Saxer Holzbau Weiningen GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schaad + Schneider AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company SCHAAD psicologia sistemica with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schall Bohr GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schär H. Bedachungen with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schenker Storen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schibli-Holz AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schleich + Collenberg AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schoop + Co. AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schreinerei Luchsinger AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schreinerei Roland Suter GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schuler Gerüst GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schwarz Etienne SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Schweizer & Partner AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company SCS Swiss Cleaners Services AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Sealed Air GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Segrada & Co. with postcode and canton area
# Successful attempt!
# Making a new attempt for company Seraswiss AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company sesa akkord gmbh with postcode and canton area
# Successful attempt!
# Making a new attempt for company SH-Technik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company SH-Technik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company SH-Technik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company SH-Technik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Siegfried Bau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company SLJ Keramik GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company SMP - Sportmanagement Anstalt with postcode and canton area
# no canton information available for company SMP - Sportmanagement Anstalt
# Successful attempt!
# Making a new attempt for company Soba Inter with postcode and canton area
# Successful attempt!
# Making a new attempt for company Solventure AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Somazzi Dario Materiali da Costruzione SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Somedia Partner AG, Zeitungsdruck with postcode and canton area
# Successful attempt!
# Making a new attempt for company Speri & Bütler AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Speri & Bütler AG with postcode and canton area
# Successful attempt!
# no address available for company Spidergrafx GmbH
# no country information available for company Spidergrafx GmbH
# no address available for company Spidergrafx GmbH
# no country information available for company Spidergrafx GmbH
# Making a new attempt for company Sprenger Elektro AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Spross Muldenservice AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stahl & Traumfabrik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stalder Schreinerei GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Staubmann AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stecher AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Steimann R. AG Garage Carrosserie Spenglerei with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stein-Metall GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stein-Metall GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stocker Tiefbau AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stocker's Degusta GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Storen Gerber AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Strasser Jakob with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stratos Bau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stutz Fensterbau-Schreinerei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Stutz Fensterbau-Schreinerei AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Südostschweiz Partner AG B. Rothmund / U. Zieri with postcode and canton area
# Successful attempt!
# Making a new attempt for company SVALE-BAU GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company SWAROVSKI INTERNATIONAL DISTRIBUTION AG Travel Ret with postcode and canton area
# no canton information available for company SWAROVSKI INTERNATIONAL DISTRIBUTION AG Travel Ret
# Successful attempt!
# Making a new attempt for company Swisscom (Schweiz) AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Swisspro SR SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Swissproconnect AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company SWM Metallbautechnik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tamedia AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tanne with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tanner Elektro AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tapigroup SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tarcisi Maissen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tawo AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Technische Gemeindebetriebe with postcode and canton area
# Successful attempt!
# !!-- SCRIPT TEMPORARY SLEEPING FOR 100 SECS TO AVOID TIMEOUT ERROR --!!
# Making a new attempt for company Theo Graf AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Theo Hotz Partner AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Thomas Conrad, Keramische Wand- und Bodenbeläge, N with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tillotts Pharma AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tillotts Pharma AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company TN Technique du Nettoyage SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tobler Blechtech AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Toiture Willy Goncerut S.A. with postcode and canton area
# Successful attempt!
# Making a new attempt for company TORMAX Schweiz AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Torri Spenglerei und Bedachung with postcode and canton area
# Successful attempt!
# Making a new attempt for company TRAVECO Transporte AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tropf Stop GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Trüb Bau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Tunno Gipsergeschäft GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Uffer Holz AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Uffer Holz AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Villat Meubles SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Vitali Haustechnik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Vodanet Voice & Data Network AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Walo Bertschinger AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Waser Bauallrounder GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Wechler AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Weiss + Hagen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Wildmanndli-Sport with postcode and canton area
# Successful attempt!
# Making a new attempt for company Wilfried Klukas with postcode and canton area
# Successful attempt!
# Making a new attempt for company Winkelmann Peter with postcode and canton area
# Successful attempt!
# Making a new attempt for company winsun ag with postcode and canton area
# Successful attempt!
# Making a new attempt for company Wyss P. Metallbau GmbH with postcode and canton area
# Successful attempt!
# Making a new attempt for company Xyloforme SA with postcode and canton area
# Successful attempt!
# Making a new attempt for company Zbären Kreativküchen AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Zimmerberg Haustechnik AG with postcode and canton area
# Successful attempt!
# Making a new attempt for company Zogg AG Holzbau-Bedachungen with postcode and canton area
# Successful attempt!
# Making a new attempt for company Zürcher Holzbau AG, Finstersee with postcode and canton area
# Successful attempt!

# %%
len(lon)
# Out:
# 4460

# %%
len(df)
# Out:
# 4460

# %%
df['longitude']=lon
df['latitude']=lat

# %%
df.head()
# Out:
#    id kunden_id  k-debitoren_id               debitorenname_1  \
# 0   6   2004052            6604  1A Swiss Dienstleistungen AG
# 1   7       NaN            3499                 3.M.E.L. GmbH
# 2   8   2004078            4139                   36GRAD GmbH
# 3   9       NaN           12066                3A Schreinerei
# 4  11       NaN            5732                 3S Partner AG
#
#                                     anschrift                 straße   plz  \
# 0                CH-5034 Suhr; Bachstrasse 33            Bachstrasse  5034
# 1       CH-5734 Reinach AG; Pilatusstrasse 32      Pilatusstrasse 32  5734
# 2                    CH-6039 Root D4; Platz 3                Platz 3  6039
# 3     CH-2558 Aegerten; Schwadernaustrasse 63  Schwadernaustrasse 63  2558
# 4  CH-6020 Emmenbrücke; Gerliswilstrasse 19 b       Gerliswilstrasse  6020
#
#            ort  customer_id       duns    ...                  uid  \
# 0         Suhr            6  480116741    ...      CHE-315.855.880
# 1   Reinach AG            7  486977734    ...      CHE-258.353.008
# 2      Root D4            8  480141611    ...      CHE-447.812.384
# 3     Aegerten            9  486942464    ...      CHE-208.196.936
# 4  Emmenbrücke           11  481936891    ...      CHE-109.644.693
#
#            regn_nbr_vat                             rechtsform duns_hauptsitz  \
# 0                   NaN                     Aktiengesellschaft            NaN
# 1                   NaN  Gesellschaft mit beschränkter Haftung            NaN
# 2                   NaN  Gesellschaft mit beschränkter Haftung            NaN
# 3                   NaN                     Aktiengesellschaft            NaN
# 4  CHE-109.644.693 MWST                     Aktiengesellschaft            NaN
#
#   name_hauptsitz  ort_hauptsitz land_hauptsitz aktivitätsstatus   longitude  \
# 0            NaN            NaN            NaN            aktiv    8.079237
# 1            NaN            NaN            NaN         gelöscht    8.176528
# 2            NaN            NaN            NaN            aktiv  174.892322
# 3            NaN            NaN            NaN            aktiv    7.296306
# 4            NaN            NaN            NaN            aktiv    8.281529
#
#     latitude
# 0  47.382247
# 1  47.253798
# 2 -37.014441
# 3  47.124770
# 4  47.069267
#
# [5 rows x 43 columns]

# %%
datafolder2 = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/".format(user)

# %%
df.to_pickle(datafolder2+'companydata_2')
