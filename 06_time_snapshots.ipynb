# %% [markdown]
# # Time snapshots for network analysis

# %% [markdown]
# This notebook creates time snapshots of the given portfolio, in order to study how network structure could influence impairments/overdues diffusion.
# In the previous steps, impairments and overdues has been calculated using as report date the date in which the data was received.
# Using snapshots, it is possible to perform this analysis overtime observing diffusion.

# %% [markdown]
# ## Data import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import os

# %%
#Instruments dataset
#import data
user = os.environ["USERNAME"]

#from home
#filename = "instrumentsdf.pkl"
#datafolder = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/".format(user)

#from work
filename = "09272018_instruments.pkl"
datafolder = "C:/Users/{}/Tradeteq Dropbox/Tradeteq Team/Clients/#GoFactoring/data analysis/".format(user)

inst = pd.read_pickle(datafolder+filename)
inst.head().transpose()
# Out:
# uid                                                    2744:79/231  \
# customer_id                                                2004008
# customer_name_1                                   jobs united GmbH
# debtor_id                                                       79
# debtor_name_1                                      Quadroni Linard
# invoice_number                                                2744
# invoice_date                                   2013-07-23 00:00:00
# due_date                                       2013-08-02 00:00:00
# invoice_amount                                               913.7
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                             913.7
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-09 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        231
# cancellation_date                                              NaT
# value_date                                     2013-08-02 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                    2744:79/231
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
#
# uid                                                    2861:79/232  \
# customer_id                                                2004008
# customer_name_1                                   jobs united GmbH
# debtor_id                                                       79
# debtor_name_1                                      Quadroni Linard
# invoice_number                                                2861
# invoice_date                                   2013-07-30 00:00:00
# due_date                                       2013-08-09 00:00:00
# invoice_amount                                             2233.45
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                           2233.45
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-23 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        232
# cancellation_date                                              NaT
# value_date                                     2013-08-09 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                    2861:79/232
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
#
# uid                                                           2932:79/233  \
# customer_id                                                       2004008
# customer_name_1                                          jobs united GmbH
# debtor_id                                                              79
# debtor_name_1                                             Quadroni Linard
# invoice_number                                                       2932
# invoice_date                                          2013-08-06 00:00:00
# due_date                                              2013-08-16 00:00:00
# invoice_amount                                                     1370.5
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date                   [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       8
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-09-23 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               233
# cancellation_date                                                     NaT
# value_date                                            2013-08-16 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                          Nein
# deduction_amount                                                        0
# payment_amount                                           [1370.5, 1370.5]
# payment_date                   [2016-01-30 00:00:00, 2016-01-30 00:00:00]
# document_status                                                historisch
# uid                                                           2932:79/233
# ttype                                                              [0, 5]
# nrecords                                                                2
# ttypeset                                                           (0, 5)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                     False
# last_payment_amount                                                1370.5
# total_repayment                                                    1370.5
# total_impairment                                                        0
# is_open                                                             False
# we_payment_share                                                        1
# has_purchase                                                        False
# has_deduction                                                       False
# is_due                                                               True
#
# uid                                                   1472:489/688  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      489
# debtor_name_1                                      Style Interiors
# invoice_number                                                1472
# invoice_date                                   2013-08-13 00:00:00
# due_date                                       2013-08-23 00:00:00
# invoice_amount                                              9195.1
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            9195.1
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-10-21 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        688
# cancellation_date                                              NaT
# value_date                                     2013-08-23 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   1472:489/688
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
#
# uid                                                          2042:512/645
# customer_id                                                       2004009
# customer_name_1                                          PM Personal GmbH
# debtor_id                                                             512
# debtor_name_1                                           Elektropartner AG
# invoice_number                                                       2042
# invoice_date                                          2013-08-13 00:00:00
# due_date                                              2013-08-23 00:00:00
# invoice_amount                                                     4594.6
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                      Kunde
# discharge_amount                                                  4430.25
# discharge_date                                        2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               645
# cancellation_date                                                     NaT
# value_date                                            2013-08-23 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                           [164.35, 164.35, 164.35, 164.35]
# payment_date            [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# document_status                                                historisch
# uid                                                          2042:512/645
# ttype                                                        [0, 5, 5, 6]
# nrecords                                                                4
# ttypeset                                                        (0, 5, 6)
# discharge_loss                                                     164.35
# has_impairment1                                                     False
# has_impairment2                                                      True
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                164.35
# total_repayment                                                    164.35
# total_impairment                                                   164.35
# is_open                                                             False
# we_payment_share                                                        1
# has_purchase                                                        False
# has_deduction                                                       False
# is_due                                                               True

# %% [markdown]
# ## 1. Defining snapshot slices

# %% [markdown]
# In order to create snapshots of different time frames, the report date will be progressively changed and used to slice the dataframe.

# %%
ReportDate = datetime.datetime(2018, 9, 28) #date data was received

daterange = pd.date_range(start=inst.invoice_date.min(), end=ReportDate, freq='M')

# %%
len(daterange)
# Out:
# 62

# %%
daterange[2]
# Out:
# Timestamp('2013-09-30 00:00:00', freq='M')

# %%
inst[inst.invoice_date<daterange[5]]
# Out:
#              customer_id   customer_name_1 debtor_id       debtor_name_1  \
# uid
# 2744:79/231      2004008  jobs united GmbH        79     Quadroni Linard
# 2861:79/232      2004008  jobs united GmbH        79     Quadroni Linard
# 2932:79/233      2004008  jobs united GmbH        79     Quadroni Linard
# 1472:489/688     2004009  PM Personal GmbH       489     Style Interiors
# 2042:512/645     2004009  PM Personal GmbH       512   Elektropartner AG
# 2998:79/234      2004008  jobs united GmbH        79     Quadroni Linard
# 3043:506/229     2004008  jobs united GmbH       506    Elektro DOM GmbH
# 3098:79/235      2004008  jobs united GmbH        79     Quadroni Linard
# 1533:489/689     2004009  PM Personal GmbH       489     Style Interiors
# 1603:527/651     2004009  PM Personal GmbH       527  Ilanz Keramik GmbH
# 1604:527/652     2004009  PM Personal GmbH       527  Ilanz Keramik GmbH
# 1623:489/690     2004009  PM Personal GmbH       489     Style Interiors
# 2043:512/646     2004009  PM Personal GmbH       512   Elektropartner AG
# 3348:79/236      2004008  jobs united GmbH        79     Quadroni Linard
# 3378:506/230     2004008  jobs united GmbH       506    Elektro DOM GmbH
# 2044:512/647     2004009  PM Personal GmbH       512   Elektropartner AG
# 3399:79/237      2004008  jobs united GmbH        79     Quadroni Linard
# 1748:489/691     2004009  PM Personal GmbH       489     Style Interiors
# 2045:512/648     2004009  PM Personal GmbH       512   Elektropartner AG
# 3541:79/238      2004008  jobs united GmbH        79     Quadroni Linard
# 1764:489/692     2004009  PM Personal GmbH       489     Style Interiors
# 2046:512/649     2004009  PM Personal GmbH       512   Elektropartner AG
# 1793:489/693     2004009  PM Personal GmbH       489     Style Interiors
# 3627:79/239      2004008  jobs united GmbH        79     Quadroni Linard
# 1811:489/694     2004009  PM Personal GmbH       489     Style Interiors
# 2047:512/650     2004009  PM Personal GmbH       512   Elektropartner AG
# 3842:79/240      2004008  jobs united GmbH        79     Quadroni Linard
# 1894:489/695     2004009  PM Personal GmbH       489     Style Interiors
# 1915:489/696     2004009  PM Personal GmbH       489     Style Interiors
# 3938:79/241      2004008  jobs united GmbH        79     Quadroni Linard
# 1938:489/697     2004009  PM Personal GmbH       489     Style Interiors
# 4055:79/242      2004008  jobs united GmbH        79     Quadroni Linard
# 4166:79/243      2004008  jobs united GmbH        79     Quadroni Linard
# 2063:489/698     2004009  PM Personal GmbH       489     Style Interiors
# 4306:79/244      2004008  jobs united GmbH        79     Quadroni Linard
# 4306:79/244             False                0.00            0.00
# 4425:79/245             False                0.00            0.00
# 4538:79/246             False                0.00            0.00
# 4681:79/247             False                0.00            0.00
# 4835:79/248             False                0.00            0.00
#
#              total_impairment  is_open we_payment_share has_purchase  \
# uid
# 2744:79/231              0.00    False              NaN        False
# 2861:79/232              0.00    False              NaN        False
# 2932:79/233              0.00    False              1.0        False
# 1472:489/688             0.00    False              NaN        False
# 2042:512/645           164.35    False              1.0        False
# 2998:79/234              0.00    False              NaN        False
# 3043:506/229          1119.00    False              1.0        False
# 3098:79/235              0.00    False              NaN        False
# 1533:489/689             0.00    False              NaN        False
# 1603:527/651             0.00    False              NaN        False
# 1604:527/652             0.00    False              NaN        False
# 1623:489/690             0.00    False              NaN        False
# 2043:512/646             0.00    False              1.0        False
# 3348:79/236              0.00    False              NaN        False
# 3378:506/230             0.00    False              NaN        False
# 2044:512/647             0.00    False              NaN        False
# 3399:79/237              0.00    False              NaN        False
# 1748:489/691             0.00    False              NaN        False
# 2045:512/648             0.00    False              NaN        False
# 3541:79/238              0.00    False              NaN        False
# 1764:489/692             0.00    False              NaN        False
# 2046:512/649             0.00    False              NaN        False
# 1793:489/693             0.00    False              NaN        False
# 3627:79/239              0.00    False              NaN        False
# 1811:489/694             0.00    False              NaN        False
# 2047:512/650             0.00    False              NaN        False
# 3842:79/240              0.00    False              NaN        False
# 1894:489/695             0.00    False              NaN        False
# 1915:489/696             0.00    False              NaN        False
# 3938:79/241              0.00    False              NaN        False
# 1938:489/697             0.00    False              NaN        False
# 4055:79/242              0.00    False              NaN        False
# 4166:79/243              0.00    False              NaN        False
# 2063:489/698             0.00    False              NaN        False
# 4306:79/244              0.00    False              NaN        False
# 4425:79/245              0.00    False              NaN        False
# 4538:79/246              0.00    False              NaN        False
# 4681:79/247              0.00    False              NaN        False
# 4835:79/248              0.00    False              NaN        False
#
#              has_deduction is_due
# uid
# 2744:79/231          False   True
# 2861:79/232          False   True
# 2932:79/233          False   True
# 1472:489/688         False   True
# 2042:512/645         False   True
# 2998:79/234          False   True
# 3043:506/229         False   True
# 3098:79/235          False   True
# 1533:489/689         False   True
# 1603:527/651         False   True
# 1604:527/652         False   True
# 1623:489/690         False   True
# 2043:512/646         False   True
# 3348:79/236          False   True
# 3378:506/230         False   True
# 2044:512/647         False   True
# 3399:79/237          False   True
# 1748:489/691         False   True
# 2045:512/648         False   True
# 3541:79/238          False   True
# 1764:489/692         False   True
# 2046:512/649         False   True
# 1793:489/693         False   True
# 3627:79/239          False   True
# 1811:489/694         False   True
# 2047:512/650         False   True
# 3842:79/240          False   True
# 1894:489/695         False   True
# 1915:489/696         False   True
# 3938:79/241          False   True
# 1938:489/697         False   True
# 4055:79/242          False   True
# 4166:79/243          False   True
# 2063:489/698         False   True
# 4306:79/244          False   True
# 4425:79/245          False   True
# 4538:79/246          False   True
# 4681:79/247          False   True
# 4835:79/248          False   True
#
# [39 rows x 54 columns]
