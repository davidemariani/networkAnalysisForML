# %% [markdown]
# # Time snapshots for network analysis

# %% [markdown]
# This notebook creates time snapshots of the given portfolio, in order to study how network structure could influence impairments/overdues diffusion.
# In the previous steps, impairments and overdues has been calculated using as report date the date in which the data was received.
# Using snapshots, it is possible to perform this analysis overtime observing diffusion.

# %% [markdown]
# ## Data import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import os

from features_utils import *

# %%
#Instruments dataset
#import data
user = os.environ["USERNAME"]

#from home
#filename = "instrumentsdf.pkl"
#datafolder = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/".format(user)

#from work
filename = "09272018_instruments.pkl"
datafolder = "C:/Users/{}/Tradeteq Dropbox/Tradeteq Team/Clients/#GoFactoring/data analysis/".format(user)

inst = pd.read_pickle(datafolder+filename)
inst.head().transpose()
# Out:
# uid                                                    2744:79/231  \
# customer_id                                                2004008
# customer_name_1                                   jobs united GmbH
# debtor_id                                                       79
# debtor_name_1                                      Quadroni Linard
# invoice_number                                                2744
# invoice_date                                   2013-07-23 00:00:00
# due_date                                       2013-08-02 00:00:00
# invoice_amount                                               913.7
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                             913.7
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-09 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        231
# cancellation_date                                              NaT
# value_date                                     2013-08-02 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                    2744:79/231
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
#
# uid                                                    2861:79/232  \
# customer_id                                                2004008
# customer_name_1                                   jobs united GmbH
# debtor_id                                                       79
# debtor_name_1                                      Quadroni Linard
# invoice_number                                                2861
# invoice_date                                   2013-07-30 00:00:00
# due_date                                       2013-08-09 00:00:00
# invoice_amount                                             2233.45
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                           2233.45
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-23 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        232
# cancellation_date                                              NaT
# value_date                                     2013-08-09 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                    2861:79/232
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
#
# uid                                                           2932:79/233  \
# customer_id                                                       2004008
# customer_name_1                                          jobs united GmbH
# debtor_id                                                              79
# debtor_name_1                                             Quadroni Linard
# invoice_number                                                       2932
# invoice_date                                          2013-08-06 00:00:00
# due_date                                              2013-08-16 00:00:00
# invoice_amount                                                     1370.5
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date                   [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       8
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-09-23 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               233
# cancellation_date                                                     NaT
# value_date                                            2013-08-16 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                          Nein
# deduction_amount                                                        0
# payment_amount                                           [1370.5, 1370.5]
# payment_date                   [2016-01-30 00:00:00, 2016-01-30 00:00:00]
# document_status                                                historisch
# uid                                                           2932:79/233
# ttype                                                              [0, 5]
# nrecords                                                                2
# ttypeset                                                           (0, 5)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                     False
# last_payment_amount                                                1370.5
# total_repayment                                                    1370.5
# total_impairment                                                        0
# is_open                                                             False
# we_payment_share                                                        1
# has_purchase                                                        False
# has_deduction                                                       False
# is_due                                                               True
#
# uid                                                   1472:489/688  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      489
# debtor_name_1                                      Style Interiors
# invoice_number                                                1472
# invoice_date                                   2013-08-13 00:00:00
# due_date                                       2013-08-23 00:00:00
# invoice_amount                                              9195.1
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            9195.1
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-10-21 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        688
# cancellation_date                                              NaT
# value_date                                     2013-08-23 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   1472:489/688
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
#
# uid                                                          2042:512/645
# customer_id                                                       2004009
# customer_name_1                                          PM Personal GmbH
# debtor_id                                                             512
# debtor_name_1                                           Elektropartner AG
# invoice_number                                                       2042
# invoice_date                                          2013-08-13 00:00:00
# due_date                                              2013-08-23 00:00:00
# invoice_amount                                                     4594.6
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                      Kunde
# discharge_amount                                                  4430.25
# discharge_date                                        2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               645
# cancellation_date                                                     NaT
# value_date                                            2013-08-23 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                           [164.35, 164.35, 164.35, 164.35]
# payment_date            [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# document_status                                                historisch
# uid                                                          2042:512/645
# ttype                                                        [0, 5, 5, 6]
# nrecords                                                                4
# ttypeset                                                        (0, 5, 6)
# discharge_loss                                                     164.35
# has_impairment1                                                     False
# has_impairment2                                                      True
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                164.35
# total_repayment                                                    164.35
# total_impairment                                                   164.35
# is_open                                                             False
# we_payment_share                                                        1
# has_purchase                                                        False
# has_deduction                                                       False
# is_due                                                               True

# %%
inst[inst['has_prosecution']][[inst.columns[c] for c in range(len(inst.columns)) if c<50]].transpose()
# Out:
# uid                                                          2042:512/645  \
# customer_id                                                       2004009
# customer_name_1                                          PM Personal GmbH
# debtor_id                                                             512
# debtor_name_1                                           Elektropartner AG
# invoice_number                                                       2042
# invoice_date                                          2013-08-13 00:00:00
# due_date                                              2013-08-23 00:00:00
# invoice_amount                                                     4594.6
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                      Kunde
# discharge_amount                                                  4430.25
# discharge_date                                        2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               645
# cancellation_date                                                     NaT
# value_date                                            2013-08-23 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                           [164.35, 164.35, 164.35, 164.35]
# payment_date            [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# document_status                                                historisch
# uid                                                          2042:512/645
# ttype                                                        [0, 5, 5, 6]
# nrecords                                                                4
# ttypeset                                                        (0, 5, 6)
# discharge_loss                                                     164.35
# has_impairment1                                                     False
# has_impairment2                                                      True
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                164.35
# total_repayment                                                    164.35
# total_impairment                                                   164.35
# is_open                                                             False
#
# uid                                                          2043:512/646  \
# customer_id                                                       2004009
# customer_name_1                                          PM Personal GmbH
# debtor_id                                                             512
# debtor_name_1                                           Elektropartner AG
# invoice_number                                                       2043
# invoice_date                                          2013-09-10 00:00:00
# due_date                                              2013-09-20 00:00:00
# invoice_amount                                                    2751.85
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               646
# cancellation_date                                                     NaT
# value_date                                            2013-09-20 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                                   [997.65, 997.65, 997.65]
# payment_date            [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# document_status                                                historisch
# uid                                                          2043:512/646
# ttype                                                          [0, 5, 11]
# nrecords                                                                3
# ttypeset                                                       (0, 11, 5)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                997.65
# total_repayment                                                    997.65
# total_impairment                                                        0
# is_open                                                             False
#
# uid                                                   2044:512/647  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      512
# debtor_name_1                                    Elektropartner AG
# invoice_number                                                2044
# invoice_date                                   2013-09-17 00:00:00
# due_date                                       2013-09-27 00:00:00
# invoice_amount                                                2801
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                              2801
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-12-16 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        647
# cancellation_date                                              NaT
# value_date                                     2013-09-27 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   2044:512/647
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                   2045:512/648  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      512
# debtor_name_1                                    Elektropartner AG
# invoice_number                                                2045
# invoice_date                                   2013-09-24 00:00:00
# due_date                                       2013-10-04 00:00:00
# invoice_amount                                              2850.1
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            2850.1
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-12-16 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        648
# cancellation_date                                              NaT
# value_date                                     2013-10-04 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   2045:512/648
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                   2046:512/649  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      512
# debtor_name_1                                    Elektropartner AG
# invoice_number                                                2046
# invoice_date                                   2013-09-30 00:00:00
# due_date                                       2013-10-10 00:00:00
# invoice_amount                                              3120.4
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            3120.4
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-12-16 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        649
# cancellation_date                                              NaT
# value_date                                     2013-10-10 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   2046:512/649
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                   2047:512/650  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      512
# debtor_name_1                                    Elektropartner AG
# invoice_number                                                2047
# invoice_date                                   2013-10-08 00:00:00
# due_date                                       2013-10-18 00:00:00
# invoice_amount                                              2555.3
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            2555.3
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-12-16 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        650
# cancellation_date                                              NaT
# value_date                                     2013-10-18 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   2047:512/650
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                   1063:INTER715/11390  \
# customer_id                                                       2004019
# customer_name_1                             United Personal Management AG
# debtor_id                                                        INTER715
# debtor_name_1                                           Pergola Design AG
# invoice_number                                                       1063
# invoice_date                                          2014-04-16 00:00:00
# due_date                                              2014-04-26 00:00:00
# invoice_amount                                                     2257.2
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date            [2016-12-15 00:00:00, 2017-01-09 00:00:00, 201...
# transaction_type        [Purchase invoice, Reminder bill, Reminder bil...
# document_stack_id                                                    3573
# booking_text                                                          NaN
# input_date                                            2016-12-15 00:00:00
# creation_date                                         2016-12-15 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                  2017-02-15 00:00:00
# last_payment_date                                     2017-02-20 00:00:00
# reminder_date                                         2017-08-02 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                             11390
# cancellation_date                                                     NaT
# value_date                                            2014-04-16 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                    6
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                        [257.2, 257.2, 257.2, 257.2, 257.2]
# payment_date            [2017-02-20 00:00:00, 2017-02-20 00:00:00, 201...
# document_status                                                     offen
# uid                                                   1063:INTER715/11390
# ttype                                                     [0, 2, 2, 8, 1]
# nrecords                                                                5
# ttypeset                                                     (0, 8, 2, 1)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                         True
# is_pastdue180                                                        True
# has_prosecution                                                      True
# last_payment_amount                                                 257.2
# total_repayment                                                     257.2
# total_impairment                                                        0
# is_open                                                              True
#
# uid                                                  1108:717/1153  \
# customer_id                                                2004016
# customer_name_1                                inter personal GmbH
# debtor_id                                                      717
# debtor_name_1                                     Team Fortis GmbH
# invoice_number                                                1108
# invoice_date                                   2014-05-14 00:00:00
# due_date                                       2014-05-24 00:00:00
# invoice_amount                                             1542.25
# purchase_amount                                            1542.25
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2016-01-30 00:00:00, 2016-01-31 00:00:00]
# transaction_type             [Purchase invoice, incoming payments]
# document_stack_id                                               15
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                              2016-01-31 00:00:00
# reminder_date                                  2014-07-18 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                       1153
# cancellation_date                                              NaT
# value_date                                     2014-05-24 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                           NaN
# prosecution                                                     Ja
# deduction_amount                                                 0
# payment_amount                                  [1542.25, 1542.25]
# payment_date            [2016-01-31 00:00:00, 2016-01-31 00:00:00]
# document_status                                         historisch
# uid                                                  1108:717/1153
# ttype                                                       [0, 1]
# nrecords                                                         2
# ttypeset                                                    (0, 1)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                        1542.25
# total_repayment                                            1542.25
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                  1109:717/1154  \
# customer_id                                                2004016
# customer_name_1                                inter personal GmbH
# debtor_id                                                      717
# debtor_name_1                                     Team Fortis GmbH
# invoice_number                                                1109
# invoice_date                                   2014-05-14 00:00:00
# due_date                                       2014-05-24 00:00:00
# invoice_amount                                              8655.3
# purchase_amount                                             8655.3
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2016-01-30 00:00:00, 2016-01-31 00:00:00]
# transaction_type             [Purchase invoice, incoming payments]
# document_stack_id                                               15
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                              2016-01-31 00:00:00
# reminder_date                                  2014-07-18 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                       1154
# cancellation_date                                              NaT
# value_date                                     2014-05-24 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                           NaN
# prosecution                                                     Ja
# deduction_amount                                                 0
# payment_amount                                    [8655.3, 8655.3]
# payment_date            [2016-01-31 00:00:00, 2016-01-31 00:00:00]
# document_status                                         historisch
# uid                                                  1109:717/1154
# ttype                                                       [0, 1]
# nrecords                                                         2
# ttypeset                                                    (0, 1)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                         8655.3
# total_repayment                                             8655.3
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                  1110:717/1155  \
# customer_id                                                2004016
# customer_name_1                                inter personal GmbH
# debtor_id                                                      717
# debtor_name_1                                     Team Fortis GmbH
# invoice_number                                                1110
# invoice_date                                   2014-05-14 00:00:00
# due_date                                       2014-05-24 00:00:00
# invoice_amount                                             1542.25
# purchase_amount                                            1542.25
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2016-01-30 00:00:00, 2016-01-31 00:00:00]
# transaction_type             [Purchase invoice, incoming payments]
# document_stack_id                                               15
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                              2016-01-31 00:00:00
# reminder_date                                  2014-07-18 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                       1155
# cancellation_date                                              NaT
# value_date                                     2014-05-24 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                           NaN
# prosecution                                                     Ja
# deduction_amount                                                 0
# payment_amount                                  [1542.25, 1542.25]
# payment_date            [2016-01-31 00:00:00, 2016-01-31 00:00:00]
# document_status                                         historisch
# uid                                                  1110:717/1155
# ttype                                                       [0, 1]
# nrecords                                                         2
# ttypeset                                                    (0, 1)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                        1542.25
# total_repayment                                            1542.25
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                        ...                      \
# customer_id                                ...
# customer_name_1                            ...
# debtor_id                                  ...
# debtor_name_1                              ...
# invoice_number                             ...
# invoice_date                               ...
# due_date                                   ...
# invoice_amount                             ...
# purchase_amount                            ...
# purchase_amount_open                       ...
# discharge_type                             ...
# discharge_amount                           ...
# discharge_date                             ...
# posting_date                               ...
# transaction_type                           ...
# document_stack_id                          ...
# booking_text                               ...
# input_date                                 ...
# creation_date                              ...
# factoring_type                             ...
# debt_collection_date                       ...
# last_payment_date                          ...
# reminder_date                              ...
# test_feature_tested                        ...
# test_characteristic_id                     ...
# bill_id                                    ...
# cancellation_date                          ...
# value_date                                 ...
# currency                                   ...
# purchase_examination                       ...
# prosecution                                ...
# deduction_amount                           ...
# payment_amount                             ...
# payment_date                               ...
# document_status                            ...
# uid                                        ...
# ttype                                      ...
# nrecords                                   ...
# ttypeset                                   ...
# discharge_loss                             ...
# has_impairment1                            ...
# has_impairment2                            ...
# has_impairment3                            ...
# is_pastdue90                               ...
# is_pastdue180                              ...
# has_prosecution                            ...
# last_payment_amount                        ...
# total_repayment                            ...
# total_impairment                           ...
# is_open                                    ...
#
# uid                                            101516:101790/62383  \
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101790
# debtor_name_1                            Malergeschäft Ferati GmbH
# invoice_number                                              101516
# invoice_date                                   2018-06-25 00:00:00
# due_date                                       2018-07-05 00:00:00
# invoice_amount                                             1277.05
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2018-06-25 00:00:00, 2018-08-29 00:00:00]
# transaction_type                 [Purchase invoice, Reminder bill]
# document_stack_id                                            16935
# booking_text                                                   NaN
# input_date                                     2018-06-25 00:00:00
# creation_date                                  2018-06-25 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2018-08-29 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                      62383
# cancellation_date                                              NaT
# value_date                                     2018-06-25 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                              offen
# uid                                            101516:101790/62383
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# uid                                            101517:101790/62384  \
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101790
# debtor_name_1                            Malergeschäft Ferati GmbH
# invoice_number                                              101517
# invoice_date                                   2018-06-25 00:00:00
# due_date                                       2018-07-05 00:00:00
# invoice_amount                                             1277.05
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2018-06-25 00:00:00, 2018-08-29 00:00:00]
# transaction_type                 [Purchase invoice, Reminder bill]
# document_stack_id                                            16935
# booking_text                                                   NaN
# input_date                                     2018-06-25 00:00:00
# creation_date                                  2018-06-25 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2018-08-29 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                      62384
# cancellation_date                                              NaT
# value_date                                     2018-06-25 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                              offen
# uid                                            101517:101790/62384
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# uid                                            101518:101790/62385  \
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101790
# debtor_name_1                            Malergeschäft Ferati GmbH
# invoice_number                                              101518
# invoice_date                                   2018-06-25 00:00:00
# ...
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# uid                                                   101794:101786/63686  \
# customer_id                                                       2004078
# customer_name_1                                             PS Schweiz AG
# debtor_id                                                          101786
# debtor_name_1                                              Wood Living AG
# invoice_number                                                     101794
# invoice_date                                          2018-07-09 00:00:00
# due_date                                              2018-07-19 00:00:00
# invoice_amount                                                     1890.8
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date            [2018-07-09 00:00:00, 2018-08-29 00:00:00, 201...
# transaction_type         [Purchase invoice, Reminder bill, Reminder bill]
# document_stack_id                                                   17322
# booking_text                                                          NaN
# input_date                                            2018-07-09 00:00:00
# creation_date                                         2018-07-09 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                                     NaT
# reminder_date                                         2018-09-13 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                             63686
# cancellation_date                                                     NaT
# value_date                                            2018-07-09 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                      NaN
# payment_amount                                            [nan, nan, nan]
# payment_date                                              [NaT, NaT, NaT]
# document_status                                                     offen
# uid                                                   101794:101786/63686
# ttype                                                           [0, 2, 2]
# nrecords                                                                3
# ttypeset                                                           (0, 2)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                     0
# total_repayment                                                         0
# total_impairment                                                        0
# is_open                                                              True
#
# uid                                                   101795:101786/63687  \
# customer_id                                                       2004078
# customer_name_1                                             PS Schweiz AG
# debtor_id                                                          101786
# debtor_name_1                                              Wood Living AG
# invoice_number                                                     101795
# invoice_date                                          2018-07-09 00:00:00
# due_date                                              2018-07-19 00:00:00
# invoice_amount                                                     1890.8
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date            [2018-07-09 00:00:00, 2018-08-29 00:00:00, 201...
# transaction_type         [Purchase invoice, Reminder bill, Reminder bill]
# document_stack_id                                                   17322
# booking_text                                                          NaN
# input_date                                            2018-07-09 00:00:00
# creation_date                                         2018-07-09 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                                     NaT
# reminder_date                                         2018-09-13 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                             63687
# cancellation_date                                                     NaT
# value_date                                            2018-07-09 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                      NaN
# payment_amount                                            [nan, nan, nan]
# payment_date                                              [NaT, NaT, NaT]
# document_status                                                     offen
# uid                                                   101795:101786/63687
# ttype                                                           [0, 2, 2]
# nrecords                                                                3
# ttypeset                                                           (0, 2)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                     0
# total_repayment                                                         0
# total_impairment                                                        0
# is_open                                                              True
#
# uid                                            101970:101786/64436  \
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101786
# debtor_name_1                                       Wood Living AG
# invoice_number                                              101970
# invoice_date                                   2018-07-17 00:00:00
# due_date                                       2018-07-27 00:00:00
# invoice_amount                                              1117.3
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2018-07-17 00:00:00, 2018-09-13 00:00:00]
# transaction_type                 [Purchase invoice, Reminder bill]
# document_stack_id                                            17520
# booking_text                                                   NaN
# input_date                                     2018-07-17 00:00:00
# creation_date                                  2018-07-17 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2018-09-13 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                      64436
# cancellation_date                                              NaT
# value_date                                     2018-07-17 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                              offen
# uid                                            101970:101786/64436
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# uid                                            102031:101786/65082
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101786
# debtor_name_1                                       Wood Living AG
# invoice_number                                              102031
# invoice_date                                   2018-07-23 00:00:00
# due_date                                       2018-08-02 00:00:00
# invoice_amount                                             1001.25
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2018-07-23 00:00:00, 2018-09-13 00:00:00]
# transaction_type                 [Purchase invoice, Reminder bill]
# document_stack_id                                            17676
# booking_text                                                   NaN
# input_date                                     2018-07-23 00:00:00
# creation_date                                  2018-07-23 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2018-09-13 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                      65082
# cancellation_date                                              NaT
# value_date                                     2018-07-23 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                              offen
# uid                                            102031:101786/65082
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# [50 rows x 1026 columns]

# %%
pamount = inst.payment_amount.apply(lambda x:len(x))
pdate = inst.payment_amount.apply(lambda x:len(x))

# %% [markdown]
# ## 1. Defining snapshot slices

# %% [markdown]
# In order to create snapshots of different time frames, the report date will be progressively changed and used to slice the dataframe.

# %%
ReportDate = datetime.datetime(2018, 9, 28) #date data was received

daterange = pd.date_range(start=inst.invoice_date.min(), end=ReportDate, freq='M')

# %%
len(daterange)
# Out:
# 62

# %%
pd.to_datetime(str(daterange[0]).split(' ')[0], yearfirst=True)
# Out:
# Timestamp('2013-07-31 00:00:00')

# %%
daterange[0]<ReportDate
# Out:
# True

# %%
#this is very slow
for snap in range(len(daterange)):
    label = "sshot_"+str(snap)+'_'
    repdate = pd.to_datetime(str(daterange[snap]).split(' ')[0], yearfirst=True)
    inst[label]=False
    inst.loc[inst.invoice_date<repdate, label]=True
    add_main_features(inst, repdate, prefix=label)

# %%
selnum=48
print(daterange[selnum])
selector = 'sshot_'+str(selnum)+'_'
inst[inst[selector] & inst['has_purchase']][[c for c in inst.columns if selector in c]+ \
                     ['invoice_date','payment_date','dates_to_count', 
                      'purchase_amount', 'has_purchase', 'due_date']].iloc[1000:1010].transpose()
# Out:
# 2017-07-31 00:00:00
# uid                                                 40012220216:0260002/1942  \
# sshot_48_                                                               True
# sshot_48_discharge_loss                                                    0
# sshot_48_has_impairment1                                               False
# sshot_48_has_impairment2                                               False
# sshot_48_total_impairment                                                  0
# sshot_48_has_prosecution                                               False
# sshot_48_has_purchase                                                   True
# sshot_48_has_deduction                                                 False
# sshot_48_has_discharge                                                 False
# sshot_48_payment_date      [2016-06-09 00:00:00, 2016-06-09 00:00:00, 201...
# sshot_48_payment_amount                     [9855.0, 9855.0, 9855.0, 9855.0]
# sshot_48_total_repayment                                                9855
# sshot_48_is_pastdue90                                                  False
# sshot_48_is_pastdue180                                                 False
# sshot_48_is_open                                                       False
# invoice_date                                             2016-02-22 00:00:00
# payment_date               [2016-06-09 00:00:00, 2016-06-09 00:00:00, 201...
# dates_to_count                                                             4
# purchase_amount                                                         9855
# has_purchase                                                            True
# due_date                                                 2016-04-21 00:00:00
#
# uid                                                 40013220216:0260002/1943  \
# sshot_48_                                                               True
# sshot_48_discharge_loss                                                    0
# sshot_48_has_impairment1                                               False
# sshot_48_has_impairment2                                               False
# sshot_48_total_impairment                                                  0
# sshot_48_has_prosecution                                               False
# sshot_48_has_purchase                                                   True
# sshot_48_has_deduction                                                 False
# sshot_48_has_discharge                                                 False
# sshot_48_payment_date      [2016-06-09 00:00:00, 2016-06-09 00:00:00, 201...
# sshot_48_payment_amount                     [9855.0, 9855.0, 9855.0, 9855.0]
# sshot_48_total_repayment                                                9855
# sshot_48_is_pastdue90                                                  False
# sshot_48_is_pastdue180                                                 False
# sshot_48_is_open                                                       False
# invoice_date                                             2016-02-22 00:00:00
# payment_date               [2016-06-09 00:00:00, 2016-06-09 00:00:00, 201...
# dates_to_count                                                             4
# purchase_amount                                                         9855
# has_purchase                                                            True
# due_date                                                 2016-04-21 00:00:00
#
# uid                                                          15385:4024/1944  \
# sshot_48_                                                               True
# sshot_48_discharge_loss                                                    0
# sshot_48_has_impairment1                                               False
# sshot_48_has_impairment2                                               False
# sshot_48_total_impairment                                                  0
# sshot_48_has_prosecution                                               False
# sshot_48_has_purchase                                                   True
# sshot_48_has_deduction                                                 False
# sshot_48_has_discharge                                                 False
# sshot_48_payment_date      [2016-03-04 00:00:00, 2016-03-04 00:00:00, 201...
# sshot_48_payment_amount                             [9072.0, 9072.0, 9072.0]
# sshot_48_total_repayment                                                9072
# sshot_48_is_pastdue90                                                  False
# sshot_48_is_pastdue180                                                 False
# sshot_48_is_open                                                       False
# invoice_date                                             2016-02-22 00:00:00
# payment_date               [2016-03-04 00:00:00, 2016-03-04 00:00:00, 201...
# dates_to_count                                                             3
# purchase_amount                                                         9072
# has_purchase                                                            True
# due_date                                                 2016-03-03 00:00:00
#
# uid                                                               660:8/1945  \
# sshot_48_                                                               True
# sshot_48_discharge_loss                                                    0
# sshot_48_has_impairment1                                               False
# sshot_48_has_impairment2                                               False
# sshot_48_total_impairment                                                  0
# sshot_48_has_prosecution                                               False
# sshot_48_has_purchase                                                   True
# sshot_48_has_deduction                                                 False
# sshot_48_has_discharge                                                 False
# sshot_48_payment_date      [2016-04-28 00:00:00, 2016-04-28 00:00:00, 201...
# sshot_48_payment_amount                     [9081.4, 9081.4, 9081.4, 9081.4]
# sshot_48_total_repayment                                              9081.4
# sshot_48_is_pastdue90                                                  False
# sshot_48_is_pastdue180                                                 False
# sshot_48_is_open                                                       False
# invoice_date                                             2016-02-22 00:00:00
# payment_date               [2016-04-28 00:00:00, 2016-04-28 00:00:00, 201...
# dates_to_count                                                             4
# purchase_amount                                                       9081.4
# has_purchase                                                            True
# due_date                                                 2016-03-23 00:00:00
#
# uid                                                               661:8/1946  \
# sshot_48_                                                               True
# sshot_48_discharge_loss                                                    0
# sshot_48_has_impairment1                                               False
# sshot_48_has_impairment2                                               False
# sshot_48_total_impairment                                                  0
# sshot_48_has_prosecution                                               False
# sshot_48_has_purchase                                                   True
# sshot_48_has_deduction                                                 False
# sshot_48_has_discharge                                                 False
# sshot_48_payment_date      [2016-04-28 00:00:00, 2016-04-28 00:00:00, 201...
# sshot_48_payment_amount                     [9303.5, 9303.5, 9303.5, 9303.5]
# sshot_48_total_repayment                                              9303.5
# sshot_48_is_pastdue90                                                  False
# sshot_48_is_pastdue180                                                 False
# sshot_48_is_open                                                       False
# invoice_date                                             2016-02-22 00:00:00
# payment_date               [2016-04-28 00:00:00, 2016-04-28 00:00:00, 201...
# dates_to_count                                                             4
# purchase_amount                                                       9303.5
# has_purchase                                                            True
# due_date                                                 2016-03-23 00:00:00
#
# uid                                                               662:8/1947  \
# sshot_48_                                                               True
# sshot_48_discharge_loss                                                    0
# sshot_48_has_impairment1                                               False
# sshot_48_has_impairment2                                               False
# sshot_48_total_impairment                                                  0
# sshot_48_has_prosecution                                               False
# sshot_48_has_purchase                                                   True
# sshot_48_has_deduction                                                 False
# sshot_48_has_discharge                                                 False
# sshot_48_payment_date      [2016-04-28 00:00:00, 2016-04-28 00:00:00, 201...
# sshot_48_payment_amount                 [11999.4, 11999.4, 11999.4, 11999.4]
# sshot_48_total_repayment                                             11999.4
# sshot_48_is_pastdue90                                                  False
# sshot_48_is_pastdue180                                                 False
# sshot_48_is_open                                                       False
# invoice_date                                             2016-02-22 00:00:00
# payment_date               [2016-04-28 00:00:00, 2016-04-28 00:00:00, 201...
# dates_to_count                                                             4
# purchase_amount                                                      11999.4
# has_purchase                                                            True
# due_date                                                 2016-03-23 00:00:00
#
# uid                                                               663:8/1948  \
# sshot_48_                                                               True
# sshot_48_discharge_loss                                                    0
# sshot_48_has_impairment1                                               False
# sshot_48_has_impairment2                                               False
# sshot_48_total_impairment                                                  0
# sshot_48_has_prosecution                                               False
# sshot_48_has_purchase                                                   True
# sshot_48_has_deduction                                                 False
# sshot_48_has_discharge                                                 False
# sshot_48_payment_date      [2016-05-11 00:00:00, 2016-05-11 00:00:00, 201...
# sshot_48_payment_amount                         [194.4, 194.4, 194.4, 194.4]
# sshot_48_total_repayment                                               194.4
# sshot_48_is_pastdue90                                                  False
# sshot_48_is_pastdue180                                                 False
# sshot_48_is_open                                                       False
# invoice_date                                             2016-02-22 00:00:00
# payment_date               [2016-05-11 00:00:00, 2016-05-11 00:00:00, 201...
# dates_to_count                                                             4
# purchase_amount                                                        194.4
# has_purchase                                                            True
# due_date                                                 2016-03-23 00:00:00
#
# uid                                                 160039:10012/1965  \
# sshot_48_                                                        True
# sshot_48_discharge_loss                                             0
# sshot_48_has_impairment1                                        False
# sshot_48_has_impairment2                                        False
# sshot_48_total_impairment                                           0
# sshot_48_has_prosecution                                        False
# sshot_48_has_purchase                                            True
# sshot_48_has_deduction                                          False
# sshot_48_has_discharge                                          False
# sshot_48_payment_date      [2016-03-31 00:00:00, 2016-03-31 00:00:00]
# sshot_48_payment_amount                              [1188.0, 1188.0]
# sshot_48_total_repayment                                         1188
# sshot_48_is_pastdue90                                           False
# sshot_48_is_pastdue180                                          False
# sshot_48_is_open                                                False
# invoice_date                                      2016-02-23 00:00:00
# payment_date               [2016-03-31 00:00:00, 2016-03-31 00:00:00]
# dates_to_count                                                      2
# purchase_amount                                                  1188
# has_purchase                                                     True
# due_date                                          2016-03-24 00:00:00
#
# uid                                                 160042:10012/1968  \
# sshot_48_                                                        True
# sshot_48_discharge_loss                                             0
# sshot_48_has_impairment1                                        False
# sshot_48_has_impairment2                                        False
# sshot_48_total_impairment                                           0
# sshot_48_has_prosecution                                        False
# sshot_48_has_purchase                                            True
# sshot_48_has_deduction                                          False
# sshot_48_has_discharge                                          False
# sshot_48_payment_date      [2016-03-31 00:00:00, 2016-03-31 00:00:00]
# sshot_48_payment_amount                              [1188.0, 1188.0]
# sshot_48_total_repayment                                         1188
# sshot_48_is_pastdue90                                           False
# sshot_48_is_pastdue180                                          False
# sshot_48_is_open                                                False
# invoice_date                                      2016-02-23 00:00:00
# payment_date               [2016-03-31 00:00:00, 2016-03-31 00:00:00]
# dates_to_count                                                      2
# purchase_amount                                                  1188
# has_purchase                                                     True
# due_date                                          2016-04-23 00:00:00
#
# uid                                                        160040:10019/1966
# sshot_48_                                                               True
# sshot_48_discharge_loss                                                    0
# sshot_48_has_impairment1                                               False
# sshot_48_has_impairment2                                               False
# sshot_48_total_impairment                                                  0
# sshot_48_has_prosecution                                               False
# sshot_48_has_purchase                                                   True
# sshot_48_has_deduction                                                 False
# sshot_48_has_discharge                                                 False
# sshot_48_payment_date      [2016-05-11 00:00:00, 2016-05-11 00:00:00, 201...
# sshot_48_payment_amount                             [1674.0, 1674.0, 1674.0]
# sshot_48_total_repayment                                                1674
# sshot_48_is_pastdue90                                                  False
# sshot_48_is_pastdue180                                                 False
# sshot_48_is_open                                                       False
# invoice_date                                             2016-02-23 00:00:00
# payment_date               [2016-05-11 00:00:00, 2016-05-11 00:00:00, 201...
# dates_to_count                                                             3
# purchase_amount                                                         1674
# has_purchase                                                            True
# due_date                                                 2016-04-23 00:00:00

# %%
print(daterange[4])
inst[inst['sshot_5_']][[c for c in inst.columns if 'sshot_5_' in c] + ['dates_to_count']].iloc[10:25].transpose()
# Out:
# 2013-11-30 00:00:00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sshot_5_'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-9941431f522f> in <module>()
#       1
#       2 print(daterange[4])
# ----> 3 inst[inst['sshot_5_']][[c for c in inst.columns if 'sshot_5_' in c] + ['dates_to_count']].iloc[10:25].transpose()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sshot_5_'

# %%
inst.loc['2043:512/646'].due_date
# Out:
# Timestamp('2013-09-20 00:00:00')

# %%
inst[inst.payment_amount.apply(lambda x:len(x))>1].head().transpose()
# Out:
# uid                                                    2744:79/231  \
# customer_id                                                2004008
# customer_name_1                                   jobs united GmbH
# debtor_id                                                       79
# debtor_name_1                                      Quadroni Linard
# invoice_number                                                2744
# invoice_date                                   2013-07-23 00:00:00
# due_date                                       2013-08-02 00:00:00
# invoice_amount                                               913.7
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                             913.7
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-09 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        231
# cancellation_date                                              NaT
# value_date                                     2013-08-02 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                    2744:79/231
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
# sshot_0                                                       True
# sshot_0discharge_loss                                            0
# sshot_0has_impairment1                                       False
# sshot_0has_impairment2                                       False
# sshot_0has_prosecution                                       False
# dates_to_count                                                   0
#
# uid                                                    2861:79/232  \
# customer_id                                                2004008
# customer_name_1                                   jobs united GmbH
# debtor_id                                                       79
# debtor_name_1                                      Quadroni Linard
# invoice_number                                                2861
# invoice_date                                   2013-07-30 00:00:00
# due_date                                       2013-08-09 00:00:00
# invoice_amount                                             2233.45
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                           2233.45
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-23 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        232
# cancellation_date                                              NaT
# value_date                                     2013-08-09 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                    2861:79/232
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
# sshot_0                                                       True
# sshot_0discharge_loss                                            0
# sshot_0has_impairment1                                       False
# sshot_0has_impairment2                                       False
# sshot_0has_prosecution                                       False
# dates_to_count                                                   0
#
# uid                                                           2932:79/233  \
# customer_id                                                       2004008
# customer_name_1                                          jobs united GmbH
# debtor_id                                                              79
# debtor_name_1                                             Quadroni Linard
# invoice_number                                                       2932
# invoice_date                                          2013-08-06 00:00:00
# due_date                                              2013-08-16 00:00:00
# invoice_amount                                                     1370.5
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date                   [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       8
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-09-23 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               233
# cancellation_date                                                     NaT
# value_date                                            2013-08-16 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                          Nein
# deduction_amount                                                        0
# payment_amount                                           [1370.5, 1370.5]
# payment_date                   [2016-01-30 00:00:00, 2016-01-30 00:00:00]
# document_status                                                historisch
# uid                                                           2932:79/233
# ttype                                                              [0, 5]
# nrecords                                                                2
# ttypeset                                                           (0, 5)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                     False
# last_payment_amount                                                1370.5
# total_repayment                                                    1370.5
# total_impairment                                                        0
# is_open                                                             False
# we_payment_share                                                        1
# has_purchase                                                        False
# has_deduction                                                       False
# is_due                                                               True
# sshot_0                                                             False
# sshot_0discharge_loss                                                   0
# sshot_0has_impairment1                                              False
# sshot_0has_impairment2                                              False
# sshot_0has_prosecution                                              False
# dates_to_count                                                          0
#
# uid                                                   1472:489/688  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      489
# debtor_name_1                                      Style Interiors
# invoice_number                                                1472
# invoice_date                                   2013-08-13 00:00:00
# due_date                                       2013-08-23 00:00:00
# invoice_amount                                              9195.1
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            9195.1
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-10-21 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        688
# cancellation_date                                              NaT
# value_date                                     2013-08-23 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   1472:489/688
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
# sshot_0                                                      False
# sshot_0discharge_loss                                            0
# sshot_0has_impairment1                                       False
# sshot_0has_impairment2                                       False
# sshot_0has_prosecution                                       False
# dates_to_count                                                   0
#
# uid                                                          2042:512/645
# customer_id                                                       2004009
# customer_name_1                                          PM Personal GmbH
# debtor_id                                                             512
# debtor_name_1                                           Elektropartner AG
# invoice_number                                                       2042
# invoice_date                                          2013-08-13 00:00:00
# due_date                                              2013-08-23 00:00:00
# invoice_amount                                                     4594.6
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                      Kunde
# discharge_amount                                                  4430.25
# discharge_date                                        2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               645
# cancellation_date                                                     NaT
# value_date                                            2013-08-23 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                           [164.35, 164.35, 164.35, 164.35]
# payment_date            [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# document_status                                                historisch
# uid                                                          2042:512/645
# ttype                                                        [0, 5, 5, 6]
# nrecords                                                                4
# ttypeset                                                        (0, 5, 6)
# discharge_loss                                                     164.35
# has_impairment1                                                     False
# has_impairment2                                                      True
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                164.35
# total_repayment                                                    164.35
# total_impairment                                                   164.35
# is_open                                                             False
# we_payment_share                                                        1
# has_purchase                                                        False
# has_deduction                                                       False
# is_due                                                               True
# sshot_0                                                             False
# sshot_0discharge_loss                                              164.35
# sshot_0has_impairment1                                              False
# sshot_0has_impairment2                                              False
# sshot_0has_prosecution                                               True
# dates_to_count                                                          0

# %%
def select_payment(x):
    payments = x.payment_amount
    filter = x.dates_to_count
    return type(payments)

inst[["payment_amount", "dates_to_count"]].apply(select_payment, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-acaac7e4658b> in <module>()
#       4     return type(payments)
#       5
# ----> 6 inst[["payment_amount", "dates_to_count"]].apply(select_payment, axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['dates_to_count'] not in index"
