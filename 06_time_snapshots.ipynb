# %% [markdown]
# # Time snapshots for network analysis

# %% [markdown]
# This notebook creates time snapshots of the given portfolio, in order to study how network structure could influence impairments/overdues diffusion.
# In the previous steps, impairments and overdues has been calculated using as report date the date in which the data was received.
# Using snapshots, it is possible to perform this analysis overtime observing diffusion.

# %% [markdown]
# ## Data import

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
import os

from features_utils import *

# %%
#Instruments dataset
#import data
user = os.environ["USERNAME"]

#from home
#filename = "instrumentsdf.pkl"
#datafolder = "C:/Users/{}/Dropbox/University/MscDataScience_Birkbeck/thesis_project/data/".format(user)

#from work
filename = "09272018_instruments.pkl"
datafolder = "C:/Users/{}/Tradeteq Dropbox/Tradeteq Team/Clients/#GoFactoring/data analysis/".format(user)

inst = pd.read_pickle(datafolder+filename)
inst.head().transpose()
# Out:
# uid                                                    2744:79/231  \
# customer_id                                                2004008
# customer_name_1                                   jobs united GmbH
# debtor_id                                                       79
# debtor_name_1                                      Quadroni Linard
# invoice_number                                                2744
# invoice_date                                   2013-07-23 00:00:00
# due_date                                       2013-08-02 00:00:00
# invoice_amount                                               913.7
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                             913.7
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-09 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        231
# cancellation_date                                              NaT
# value_date                                     2013-08-02 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                    2744:79/231
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
#
# uid                                                    2861:79/232  \
# customer_id                                                2004008
# customer_name_1                                   jobs united GmbH
# debtor_id                                                       79
# debtor_name_1                                      Quadroni Linard
# invoice_number                                                2861
# invoice_date                                   2013-07-30 00:00:00
# due_date                                       2013-08-09 00:00:00
# invoice_amount                                             2233.45
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                           2233.45
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                8
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-09-23 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        232
# cancellation_date                                              NaT
# value_date                                     2013-08-09 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                    2861:79/232
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
#
# uid                                                           2932:79/233  \
# customer_id                                                       2004008
# customer_name_1                                          jobs united GmbH
# debtor_id                                                              79
# debtor_name_1                                             Quadroni Linard
# invoice_number                                                       2932
# invoice_date                                          2013-08-06 00:00:00
# due_date                                              2013-08-16 00:00:00
# invoice_amount                                                     1370.5
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date                   [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       8
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-09-23 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               233
# cancellation_date                                                     NaT
# value_date                                            2013-08-16 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                          Nein
# deduction_amount                                                        0
# payment_amount                                           [1370.5, 1370.5]
# payment_date                   [2016-01-30 00:00:00, 2016-01-30 00:00:00]
# document_status                                                historisch
# uid                                                           2932:79/233
# ttype                                                              [0, 5]
# nrecords                                                                2
# ttypeset                                                           (0, 5)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                     False
# last_payment_amount                                                1370.5
# total_repayment                                                    1370.5
# total_impairment                                                        0
# is_open                                                             False
# we_payment_share                                                        1
# has_purchase                                                        False
# has_deduction                                                       False
# is_due                                                               True
#
# uid                                                   1472:489/688  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      489
# debtor_name_1                                      Style Interiors
# invoice_number                                                1472
# invoice_date                                   2013-08-13 00:00:00
# due_date                                       2013-08-23 00:00:00
# invoice_amount                                              9195.1
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            9195.1
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-10-21 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        688
# cancellation_date                                              NaT
# value_date                                     2013-08-23 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                   Nein
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   1472:489/688
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                              False
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
# we_payment_share                                               NaN
# has_purchase                                                 False
# has_deduction                                                False
# is_due                                                        True
#
# uid                                                          2042:512/645
# customer_id                                                       2004009
# customer_name_1                                          PM Personal GmbH
# debtor_id                                                             512
# debtor_name_1                                           Elektropartner AG
# invoice_number                                                       2042
# invoice_date                                          2013-08-13 00:00:00
# due_date                                              2013-08-23 00:00:00
# invoice_amount                                                     4594.6
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                      Kunde
# discharge_amount                                                  4430.25
# discharge_date                                        2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               645
# cancellation_date                                                     NaT
# value_date                                            2013-08-23 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                           [164.35, 164.35, 164.35, 164.35]
# payment_date            [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# document_status                                                historisch
# uid                                                          2042:512/645
# ttype                                                        [0, 5, 5, 6]
# nrecords                                                                4
# ttypeset                                                        (0, 5, 6)
# discharge_loss                                                     164.35
# has_impairment1                                                     False
# has_impairment2                                                      True
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                164.35
# total_repayment                                                    164.35
# total_impairment                                                   164.35
# is_open                                                             False
# we_payment_share                                                        1
# has_purchase                                                        False
# has_deduction                                                       False
# is_due                                                               True

# %%
inst[['invoice_date','debtor_id']]
# Out:
#                     invoice_date debtor_id
# uid
# 2744:79/231           2013-07-23        79
# 2861:79/232           2013-07-30        79
# 2932:79/233           2013-08-06        79
# 1472:489/688          2013-08-13       489
# 2042:512/645          2013-08-13       512
# 2998:79/234           2013-08-13        79
# 3043:506/229          2013-08-20       506
# 3098:79/235           2013-08-20        79
# 1533:489/689          2013-08-27       489
# 1603:527/651          2013-09-03       527
# 1604:527/652          2013-09-03       527
# 1623:489/690          2013-09-10       489
# 2043:512/646          2013-09-10       512
# 3348:79/236           2013-09-10        79
# 3378:506/230          2013-09-17       506
# 2044:512/647          2013-09-17       512
# 3399:79/237           2013-09-17        79
# 1748:489/691          2013-09-24       489
# 2045:512/648          2013-09-24       512
# 3541:79/238           2013-09-24        79
# 1764:489/692          2013-09-30       489
# 2046:512/649          2013-09-30       512
# 1793:489/693          2013-10-01       489
# 3627:79/239           2013-10-01        79
# 1811:489/694          2013-10-08       489
# 2047:512/650          2013-10-08       512
# 3842:79/240           2013-10-15        79
# 1894:489/695          2013-10-22       489
# 1915:489/696          2013-10-22       489
# 3938:79/241           2013-10-22        79
# ...                          ...       ...
# 71181:582154/55287    2018-12-08    582154
# 71182:582154/55288    2018-12-08    582154
# 2017-3638:102/47561   2018-12-18       102
# 2017-3639:102/47562   2018-12-18       102
# 2017-3640:102/47563   2018-12-18       102
# 2017-3641:102/47564   2018-12-18       102
# 2017-3642:102/47565   2018-12-18       102
# 2017-3643:102/47566   2018-12-18       102
# 2017-3616:29/47540    2018-12-18        29
# 2017-3617:29/47541    2018-12-18        29
# 2017-3618:29/47542    2018-12-18        29
# 2017-3619:29/47543    2018-12-18        29
# 2017-3620:29/47544    2018-12-18        29
# 2017-3621:29/47545    2018-12-18        29
# 2017-3623:29/47547    2018-12-18        29
# 2017-3624:29/47548    2018-12-18        29
# 2017-3625:29/47549    2018-12-18        29
# 2017-3626:29/47550    2018-12-18        29
# 2017-3627:29/47551    2018-12-18        29
# 2017-3628:29/47552    2018-12-18        29
# 2017-3629:29/47553    2018-12-18        29
# 2017-3630:29/47554    2018-12-18        29
# 2017-3631:29/47555    2018-12-18        29
# 2017-3632:29/47556    2018-12-18        29
# 2017-3633:29/47557    2018-12-18        29
# 2017-3634:29/47558    2018-12-18        29
# 2017-3635:29/47567    2018-12-18        29
# 2017-3636:29/47559    2018-12-18        29
# 2017-3637:29/47560    2018-12-18        29
# 2017-3622:69/47546    2018-12-18        69
#
# [59820 rows x 2 columns]

# %%
inst[inst['has_prosecution']][[inst.columns[c] for c in range(len(inst.columns)) if c<50]].transpose()
# Out:
# uid                                                          2042:512/645  \
# customer_id                                                       2004009
# customer_name_1                                          PM Personal GmbH
# debtor_id                                                             512
# debtor_name_1                                           Elektropartner AG
# invoice_number                                                       2042
# invoice_date                                          2013-08-13 00:00:00
# due_date                                              2013-08-23 00:00:00
# invoice_amount                                                     4594.6
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                      Kunde
# discharge_amount                                                  4430.25
# discharge_date                                        2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               645
# cancellation_date                                                     NaT
# value_date                                            2013-08-23 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                           [164.35, 164.35, 164.35, 164.35]
# payment_date            [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# document_status                                                historisch
# uid                                                          2042:512/645
# ttype                                                        [0, 5, 5, 6]
# nrecords                                                                4
# ttypeset                                                        (0, 5, 6)
# discharge_loss                                                     164.35
# has_impairment1                                                     False
# has_impairment2                                                      True
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                164.35
# total_repayment                                                    164.35
# total_impairment                                                   164.35
# is_open                                                             False
#
# uid                                                          2043:512/646  \
# customer_id                                                       2004009
# customer_name_1                                          PM Personal GmbH
# debtor_id                                                             512
# debtor_name_1                                           Elektropartner AG
# invoice_number                                                       2043
# invoice_date                                          2013-09-10 00:00:00
# due_date                                              2013-09-20 00:00:00
# invoice_amount                                                    2751.85
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type        [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                       9
# booking_text                                                    Migration
# input_date                                            2016-01-30 00:00:00
# creation_date                                         2016-01-30 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                     2016-01-30 00:00:00
# reminder_date                                         2013-12-16 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                               646
# cancellation_date                                                     NaT
# value_date                                            2013-09-20 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                                   [997.65, 997.65, 997.65]
# payment_date            [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# document_status                                                historisch
# uid                                                          2043:512/646
# ttype                                                          [0, 5, 11]
# nrecords                                                                3
# ttypeset                                                       (0, 11, 5)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                997.65
# total_repayment                                                    997.65
# total_impairment                                                        0
# is_open                                                             False
#
# uid                                                   2044:512/647  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      512
# debtor_name_1                                    Elektropartner AG
# invoice_number                                                2044
# invoice_date                                   2013-09-17 00:00:00
# due_date                                       2013-09-27 00:00:00
# invoice_amount                                                2801
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                              2801
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-12-16 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        647
# cancellation_date                                              NaT
# value_date                                     2013-09-27 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   2044:512/647
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                   2045:512/648  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      512
# debtor_name_1                                    Elektropartner AG
# invoice_number                                                2045
# invoice_date                                   2013-09-24 00:00:00
# due_date                                       2013-10-04 00:00:00
# invoice_amount                                              2850.1
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            2850.1
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-12-16 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        648
# cancellation_date                                              NaT
# value_date                                     2013-10-04 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   2045:512/648
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                   2046:512/649  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      512
# debtor_name_1                                    Elektropartner AG
# invoice_number                                                2046
# invoice_date                                   2013-09-30 00:00:00
# due_date                                       2013-10-10 00:00:00
# invoice_amount                                              3120.4
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            3120.4
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-12-16 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        649
# cancellation_date                                              NaT
# value_date                                     2013-10-10 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   2046:512/649
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                   2047:512/650  \
# customer_id                                                2004009
# customer_name_1                                   PM Personal GmbH
# debtor_id                                                      512
# debtor_name_1                                    Elektropartner AG
# invoice_number                                                2047
# invoice_date                                   2013-10-08 00:00:00
# due_date                                       2013-10-18 00:00:00
# invoice_amount                                              2555.3
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                               Kunde
# discharge_amount                                            2555.3
# discharge_date                                 2016-03-22 00:00:00
# posting_date            [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type         [Purchase invoice, Cancel invoice client]
# document_stack_id                                                9
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2013-12-16 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                        650
# cancellation_date                                              NaT
# value_date                                     2013-10-18 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                         historisch
# uid                                                   2047:512/650
# ttype                                                       [0, 6]
# nrecords                                                         2
# ttypeset                                                    (0, 6)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                   1063:INTER715/11390  \
# customer_id                                                       2004019
# customer_name_1                             United Personal Management AG
# debtor_id                                                        INTER715
# debtor_name_1                                           Pergola Design AG
# invoice_number                                                       1063
# invoice_date                                          2014-04-16 00:00:00
# due_date                                              2014-04-26 00:00:00
# invoice_amount                                                     2257.2
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date            [2016-12-15 00:00:00, 2017-01-09 00:00:00, 201...
# transaction_type        [Purchase invoice, Reminder bill, Reminder bil...
# document_stack_id                                                    3573
# booking_text                                                          NaN
# input_date                                            2016-12-15 00:00:00
# creation_date                                         2016-12-15 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                  2017-02-15 00:00:00
# last_payment_date                                     2017-02-20 00:00:00
# reminder_date                                         2017-08-02 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                             11390
# cancellation_date                                                     NaT
# value_date                                            2014-04-16 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                    6
# prosecution                                                            Ja
# deduction_amount                                                        0
# payment_amount                        [257.2, 257.2, 257.2, 257.2, 257.2]
# payment_date            [2017-02-20 00:00:00, 2017-02-20 00:00:00, 201...
# document_status                                                     offen
# uid                                                   1063:INTER715/11390
# ttype                                                     [0, 2, 2, 8, 1]
# nrecords                                                                5
# ttypeset                                                     (0, 8, 2, 1)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                         True
# is_pastdue180                                                        True
# has_prosecution                                                      True
# last_payment_amount                                                 257.2
# total_repayment                                                     257.2
# total_impairment                                                        0
# is_open                                                              True
#
# uid                                                  1108:717/1153  \
# customer_id                                                2004016
# customer_name_1                                inter personal GmbH
# debtor_id                                                      717
# debtor_name_1                                     Team Fortis GmbH
# invoice_number                                                1108
# invoice_date                                   2014-05-14 00:00:00
# due_date                                       2014-05-24 00:00:00
# invoice_amount                                             1542.25
# purchase_amount                                            1542.25
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2016-01-30 00:00:00, 2016-01-31 00:00:00]
# transaction_type             [Purchase invoice, incoming payments]
# document_stack_id                                               15
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                              2016-01-31 00:00:00
# reminder_date                                  2014-07-18 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                       1153
# cancellation_date                                              NaT
# value_date                                     2014-05-24 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                           NaN
# prosecution                                                     Ja
# deduction_amount                                                 0
# payment_amount                                  [1542.25, 1542.25]
# payment_date            [2016-01-31 00:00:00, 2016-01-31 00:00:00]
# document_status                                         historisch
# uid                                                  1108:717/1153
# ttype                                                       [0, 1]
# nrecords                                                         2
# ttypeset                                                    (0, 1)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                        1542.25
# total_repayment                                            1542.25
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                  1109:717/1154  \
# customer_id                                                2004016
# customer_name_1                                inter personal GmbH
# debtor_id                                                      717
# debtor_name_1                                     Team Fortis GmbH
# invoice_number                                                1109
# invoice_date                                   2014-05-14 00:00:00
# due_date                                       2014-05-24 00:00:00
# invoice_amount                                              8655.3
# purchase_amount                                             8655.3
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2016-01-30 00:00:00, 2016-01-31 00:00:00]
# transaction_type             [Purchase invoice, incoming payments]
# document_stack_id                                               15
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                              2016-01-31 00:00:00
# reminder_date                                  2014-07-18 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                       1154
# cancellation_date                                              NaT
# value_date                                     2014-05-24 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                           NaN
# prosecution                                                     Ja
# deduction_amount                                                 0
# payment_amount                                    [8655.3, 8655.3]
# payment_date            [2016-01-31 00:00:00, 2016-01-31 00:00:00]
# document_status                                         historisch
# uid                                                  1109:717/1154
# ttype                                                       [0, 1]
# nrecords                                                         2
# ttypeset                                                    (0, 1)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                         8655.3
# total_repayment                                             8655.3
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                                  1110:717/1155  \
# customer_id                                                2004016
# customer_name_1                                inter personal GmbH
# debtor_id                                                      717
# debtor_name_1                                     Team Fortis GmbH
# invoice_number                                                1110
# invoice_date                                   2014-05-14 00:00:00
# due_date                                       2014-05-24 00:00:00
# invoice_amount                                             1542.25
# purchase_amount                                            1542.25
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2016-01-30 00:00:00, 2016-01-31 00:00:00]
# transaction_type             [Purchase invoice, incoming payments]
# document_stack_id                                               15
# booking_text                                             Migration
# input_date                                     2016-01-30 00:00:00
# creation_date                                  2016-01-30 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                              2016-01-31 00:00:00
# reminder_date                                  2014-07-18 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                       1155
# cancellation_date                                              NaT
# value_date                                     2014-05-24 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                           NaN
# prosecution                                                     Ja
# deduction_amount                                                 0
# payment_amount                                  [1542.25, 1542.25]
# payment_date            [2016-01-31 00:00:00, 2016-01-31 00:00:00]
# document_status                                         historisch
# uid                                                  1110:717/1155
# ttype                                                       [0, 1]
# nrecords                                                         2
# ttypeset                                                    (0, 1)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                        1542.25
# total_repayment                                            1542.25
# total_impairment                                                 0
# is_open                                                      False
#
# uid                                        ...                      \
# customer_id                                ...
# customer_name_1                            ...
# debtor_id                                  ...
# debtor_name_1                              ...
# invoice_number                             ...
# invoice_date                               ...
# due_date                                   ...
# invoice_amount                             ...
# purchase_amount                            ...
# purchase_amount_open                       ...
# discharge_type                             ...
# discharge_amount                           ...
# discharge_date                             ...
# posting_date                               ...
# transaction_type                           ...
# document_stack_id                          ...
# booking_text                               ...
# input_date                                 ...
# creation_date                              ...
# factoring_type                             ...
# debt_collection_date                       ...
# last_payment_date                          ...
# reminder_date                              ...
# test_feature_tested                        ...
# test_characteristic_id                     ...
# bill_id                                    ...
# cancellation_date                          ...
# value_date                                 ...
# currency                                   ...
# purchase_examination                       ...
# prosecution                                ...
# deduction_amount                           ...
# payment_amount                             ...
# payment_date                               ...
# document_status                            ...
# uid                                        ...
# ttype                                      ...
# nrecords                                   ...
# ttypeset                                   ...
# discharge_loss                             ...
# has_impairment1                            ...
# has_impairment2                            ...
# has_impairment3                            ...
# is_pastdue90                               ...
# is_pastdue180                              ...
# has_prosecution                            ...
# last_payment_amount                        ...
# total_repayment                            ...
# total_impairment                           ...
# is_open                                    ...
#
# uid                                            101516:101790/62383  \
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101790
# debtor_name_1                            Malergeschäft Ferati GmbH
# invoice_number                                              101516
# invoice_date                                   2018-06-25 00:00:00
# due_date                                       2018-07-05 00:00:00
# invoice_amount                                             1277.05
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2018-06-25 00:00:00, 2018-08-29 00:00:00]
# transaction_type                 [Purchase invoice, Reminder bill]
# document_stack_id                                            16935
# booking_text                                                   NaN
# input_date                                     2018-06-25 00:00:00
# creation_date                                  2018-06-25 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2018-08-29 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                      62383
# cancellation_date                                              NaT
# value_date                                     2018-06-25 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                              offen
# uid                                            101516:101790/62383
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# uid                                            101517:101790/62384  \
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101790
# debtor_name_1                            Malergeschäft Ferati GmbH
# invoice_number                                              101517
# invoice_date                                   2018-06-25 00:00:00
# due_date                                       2018-07-05 00:00:00
# invoice_amount                                             1277.05
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2018-06-25 00:00:00, 2018-08-29 00:00:00]
# transaction_type                 [Purchase invoice, Reminder bill]
# document_stack_id                                            16935
# booking_text                                                   NaN
# input_date                                     2018-06-25 00:00:00
# creation_date                                  2018-06-25 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2018-08-29 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                      62384
# cancellation_date                                              NaT
# value_date                                     2018-06-25 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                              offen
# uid                                            101517:101790/62384
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# uid                                            101518:101790/62385  \
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101790
# debtor_name_1                            Malergeschäft Ferati GmbH
# invoice_number                                              101518
# invoice_date                                   2018-06-25 00:00:00
# ...
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# uid                                                   101794:101786/63686  \
# customer_id                                                       2004078
# customer_name_1                                             PS Schweiz AG
# debtor_id                                                          101786
# debtor_name_1                                              Wood Living AG
# invoice_number                                                     101794
# invoice_date                                          2018-07-09 00:00:00
# due_date                                              2018-07-19 00:00:00
# invoice_amount                                                     1890.8
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date            [2018-07-09 00:00:00, 2018-08-29 00:00:00, 201...
# transaction_type         [Purchase invoice, Reminder bill, Reminder bill]
# document_stack_id                                                   17322
# booking_text                                                          NaN
# input_date                                            2018-07-09 00:00:00
# creation_date                                         2018-07-09 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                                     NaT
# reminder_date                                         2018-09-13 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                             63686
# cancellation_date                                                     NaT
# value_date                                            2018-07-09 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                      NaN
# payment_amount                                            [nan, nan, nan]
# payment_date                                              [NaT, NaT, NaT]
# document_status                                                     offen
# uid                                                   101794:101786/63686
# ttype                                                           [0, 2, 2]
# nrecords                                                                3
# ttypeset                                                           (0, 2)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                     0
# total_repayment                                                         0
# total_impairment                                                        0
# is_open                                                              True
#
# uid                                                   101795:101786/63687  \
# customer_id                                                       2004078
# customer_name_1                                             PS Schweiz AG
# debtor_id                                                          101786
# debtor_name_1                                              Wood Living AG
# invoice_number                                                     101795
# invoice_date                                          2018-07-09 00:00:00
# due_date                                              2018-07-19 00:00:00
# invoice_amount                                                     1890.8
# purchase_amount                                                         0
# purchase_amount_open                                                    0
# discharge_type                                                        NaN
# discharge_amount                                                      NaN
# discharge_date                                                        NaT
# posting_date            [2018-07-09 00:00:00, 2018-08-29 00:00:00, 201...
# transaction_type         [Purchase invoice, Reminder bill, Reminder bill]
# document_stack_id                                                   17322
# booking_text                                                          NaN
# input_date                                            2018-07-09 00:00:00
# creation_date                                         2018-07-09 00:00:00
# factoring_type                                               Full Service
# debt_collection_date                                                  NaT
# last_payment_date                                                     NaT
# reminder_date                                         2018-09-13 00:00:00
# test_feature_tested                                                   NaN
# test_characteristic_id                                                NaN
# bill_id                                                             63687
# cancellation_date                                                     NaT
# value_date                                            2018-07-09 00:00:00
# currency                                                Schweizer Franken
# purchase_examination                                                   14
# prosecution                                                            Ja
# deduction_amount                                                      NaN
# payment_amount                                            [nan, nan, nan]
# payment_date                                              [NaT, NaT, NaT]
# document_status                                                     offen
# uid                                                   101795:101786/63687
# ttype                                                           [0, 2, 2]
# nrecords                                                                3
# ttypeset                                                           (0, 2)
# discharge_loss                                                          0
# has_impairment1                                                     False
# has_impairment2                                                     False
# has_impairment3                                                     False
# is_pastdue90                                                        False
# is_pastdue180                                                       False
# has_prosecution                                                      True
# last_payment_amount                                                     0
# total_repayment                                                         0
# total_impairment                                                        0
# is_open                                                              True
#
# uid                                            101970:101786/64436  \
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101786
# debtor_name_1                                       Wood Living AG
# invoice_number                                              101970
# invoice_date                                   2018-07-17 00:00:00
# due_date                                       2018-07-27 00:00:00
# invoice_amount                                              1117.3
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2018-07-17 00:00:00, 2018-09-13 00:00:00]
# transaction_type                 [Purchase invoice, Reminder bill]
# document_stack_id                                            17520
# booking_text                                                   NaN
# input_date                                     2018-07-17 00:00:00
# creation_date                                  2018-07-17 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2018-09-13 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                      64436
# cancellation_date                                              NaT
# value_date                                     2018-07-17 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                              offen
# uid                                            101970:101786/64436
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# uid                                            102031:101786/65082
# customer_id                                                2004078
# customer_name_1                                      PS Schweiz AG
# debtor_id                                                   101786
# debtor_name_1                                       Wood Living AG
# invoice_number                                              102031
# invoice_date                                   2018-07-23 00:00:00
# due_date                                       2018-08-02 00:00:00
# invoice_amount                                             1001.25
# purchase_amount                                                  0
# purchase_amount_open                                             0
# discharge_type                                                 NaN
# discharge_amount                                               NaN
# discharge_date                                                 NaT
# posting_date            [2018-07-23 00:00:00, 2018-09-13 00:00:00]
# transaction_type                 [Purchase invoice, Reminder bill]
# document_stack_id                                            17676
# booking_text                                                   NaN
# input_date                                     2018-07-23 00:00:00
# creation_date                                  2018-07-23 00:00:00
# factoring_type                                        Full Service
# debt_collection_date                                           NaT
# last_payment_date                                              NaT
# reminder_date                                  2018-09-13 00:00:00
# test_feature_tested                                            NaN
# test_characteristic_id                                         NaN
# bill_id                                                      65082
# cancellation_date                                              NaT
# value_date                                     2018-07-23 00:00:00
# currency                                         Schweizer Franken
# purchase_examination                                            14
# prosecution                                                     Ja
# deduction_amount                                               NaN
# payment_amount                                          [nan, nan]
# payment_date                                            [NaT, NaT]
# document_status                                              offen
# uid                                            102031:101786/65082
# ttype                                                       [0, 2]
# nrecords                                                         2
# ttypeset                                                    (0, 2)
# discharge_loss                                                   0
# has_impairment1                                              False
# has_impairment2                                              False
# has_impairment3                                              False
# is_pastdue90                                                 False
# is_pastdue180                                                False
# has_prosecution                                               True
# last_payment_amount                                              0
# total_repayment                                                  0
# total_impairment                                                 0
# is_open                                                       True
#
# [50 rows x 1026 columns]

# %%
pamount = inst.payment_amount.apply(lambda x:len(x))
pdate = inst.payment_amount.apply(lambda x:len(x))

# %% [markdown]
# ## 1. Defining snapshot slices

# %% [markdown]
# In order to create snapshots of different time frames, the report date will be progressively changed and used to slice the dataframe.

# %%
ReportDate = datetime.datetime(2018, 9, 28) #date data was received

daterange = pd.date_range(start=inst.invoice_date.min(), end=ReportDate, freq='M')

# %%
len(daterange)
# Out:
# 62

# %%
pd.to_datetime(str(daterange[0]).split(' ')[0], yearfirst=True)
# Out:
# Timestamp('2013-07-31 00:00:00')

# %%
daterange[0]<ReportDate
# Out:
# True

# %%
#this is very slow

for snap in range(len(daterange)):
    label = "sshot_"+str(snap)+'_'
    repdate = pd.to_datetime(str(daterange[snap]).split(' ')[0], yearfirst=True)
    inst[label]=False
    inst.loc[inst.invoice_date<repdate, label]=True
    add_main_features(inst, repdate, prefix=label)

#from work
datafolder2 = 'C:/Users/{0}/Tradeteq Dropbox/Davide Mariani/thesis_project/'.format(user)
filename2 = 'snapshots.pkl'
inst.to_pickle(datafolder2+filename2)


#just load the file snapshots.pkl
#inst = pd.read_pickle(datafolder2+filename2)
# Out:
# Addding main network features for snapshot with date < 2013-07-31 00:00:00
# Addding main network features for snapshot with date < 2013-08-31 00:00:00
# Addding main network features for snapshot with date < 2013-09-30 00:00:00
# Addding main network features for snapshot with date < 2013-10-31 00:00:00
# Addding main network features for snapshot with date < 2013-11-30 00:00:00
# Addding main network features for snapshot with date < 2013-12-31 00:00:00
# Addding main network features for snapshot with date < 2014-01-31 00:00:00
# Addding main network features for snapshot with date < 2014-02-28 00:00:00
# Addding main network features for snapshot with date < 2014-03-31 00:00:00
# Addding main network features for snapshot with date < 2014-04-30 00:00:00
# Addding main network features for snapshot with date < 2014-05-31 00:00:00
# Addding main network features for snapshot with date < 2014-06-30 00:00:00
# Addding main network features for snapshot with date < 2014-07-31 00:00:00
# Addding main network features for snapshot with date < 2014-08-31 00:00:00
# Addding main network features for snapshot with date < 2014-09-30 00:00:00
# Addding main network features for snapshot with date < 2014-10-31 00:00:00
# Addding main network features for snapshot with date < 2014-11-30 00:00:00
# Addding main network features for snapshot with date < 2014-12-31 00:00:00
# Addding main network features for snapshot with date < 2015-01-31 00:00:00
# Addding main network features for snapshot with date < 2015-02-28 00:00:00
# Addding main network features for snapshot with date < 2015-03-31 00:00:00
# Addding main network features for snapshot with date < 2015-04-30 00:00:00
# Addding main network features for snapshot with date < 2015-05-31 00:00:00
# Addding main network features for snapshot with date < 2015-06-30 00:00:00
# Addding main network features for snapshot with date < 2015-07-31 00:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-65f2a4ab875f> in <module>
#       6     inst[label]=False
#       7     inst.loc[inst.invoice_date<repdate, label]=True
# ----> 8     add_main_features(inst, repdate, prefix=label)
#       9
#      10 #from work
#
# ~\Tradeteq Dropbox\Davide Mariani\thesis_project\networkAnalysisForML\features_utils.py in add_main_features(inst, ReportDate, impthr, imp2thr, purthr, dedthr, prefix, date_debtor_sort)
#     121         inst["last_payment_amount"] = xor0(inst["payment_amount"].apply(lambda x: x[-1]))
#     122     else:
# --> 123         inst.loc[inst[prefix],'tmp_dates_to_count'] = inst.loc[inst[prefix],"payment_date"].apply(lambda x:sum(pd.Series(x)<ReportDate)) #this retrieve the index of the last payment snapshot to snapshot (it is a temp column)
#     124         inst.loc[inst[prefix],prefix+"payment_date"] = inst.loc[inst[prefix],["payment_date", "tmp_dates_to_count"]].apply(select_date, axis=1)
#     125         inst.loc[inst[prefix],prefix+"payment_amount"] = inst.loc[inst[prefix],["payment_amount", "tmp_dates_to_count"]].apply(select_payment, axis=1)
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ~\Tradeteq Dropbox\Davide Mariani\thesis_project\networkAnalysisForML\features_utils.py in <lambda>(x)
#     121         inst["last_payment_amount"] = xor0(inst["payment_amount"].apply(lambda x: x[-1]))
#     122     else:
# --> 123         inst.loc[inst[prefix],'tmp_dates_to_count'] = inst.loc[inst[prefix],"payment_date"].apply(lambda x:sum(pd.Series(x)<ReportDate)) #this retrieve the index of the last payment snapshot to snapshot (it is a temp column)
#     124         inst.loc[inst[prefix],prefix+"payment_date"] = inst.loc[inst[prefix],["payment_date", "tmp_dates_to_count"]].apply(select_date, axis=1)
#     125         inst.loc[inst[prefix],prefix+"payment_amount"] = inst.loc[inst[prefix],["payment_amount", "tmp_dates_to_count"]].apply(select_payment, axis=1)
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1228
#    1229             res_values = dispatch_to_index_op(op, self, other,
# -> 1230                                               pd.DatetimeIndex)
#    1231
#    1232             return self._constructor(res_values, index=self.index,
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\ops.py in dispatch_to_index_op(op, left, right, index_class)
#    1099         left_idx = left_idx._shallow_copy(freq=None)
#    1100     try:
# -> 1101         result = op(left_idx, right)
#    1102     except NullFrequencyError:
#    1103         # DatetimeIndex and TimedeltaIndex with freq == None raise ValueError
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\indexes\datetimes.py in wrapper(self, other)
#     116
#     117             other = _to_m8(other, tz=self.tz)
# --> 118             result = func(other)
#     119             if isna(other):
#     120                 result.fill(nat_result)
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\indexes\base.py in cmp_method(self, other)
#      96         # representations
#      97         if needs_i8_conversion(self) and needs_i8_conversion(other):
# ---> 98             return self._evaluate_compare(other, op)
#      99
#     100         from .multi import MultiIndex
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\indexes\datetimelike.py in _evaluate_compare(self, other, op)
#     312                 # ndarray scalar
#     313                 other = [other.item()]
# --> 314             other = type(self)(other)
#     315
#     316         # compare
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\indexes\datetimes.py in __new__(cls, data, freq, start, end, periods, tz, normalize, closed, ambiguous, dayfirst, yearfirst, dtype, copy, name, verify_integrity)
#     397                 is_integer_dtype(data)):
#     398             data = tools.to_datetime(data, dayfirst=dayfirst,
# --> 399                                      yearfirst=yearfirst)
#     400
#     401         if issubclass(data.dtype.type, np.datetime64) or is_datetimetz(data):
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     461             result = _convert_listlike(arg, box, format, name=arg.name)
#     462     elif is_list_like(arg):
# --> 463         cache_array = _maybe_cache(arg, format, cache, tz, _convert_listlike)
#     464         if not cache_array.empty:
#     465             result = _convert_and_box_cache(arg, cache_array, box, errors)
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\tools\datetimes.py in _maybe_cache(arg, format, cache, tz, convert_listlike)
#      59     """
#      60     from pandas import Series
# ---> 61     cache_array = Series()
#      62     if cache:
#      63         # Perform a quicker unique check
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     214                 data = data._data
#     215             elif isinstance(data, dict):
# --> 216                 data, index = self._init_dict(data, index, dtype)
#     217                 dtype = None
#     218                 copy = False
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\series.py in _init_dict(self, data, index, dtype)
#     315
#     316         # Input is now list-like, so rely on "standard" construction:
# --> 317         s = Series(values, index=keys, dtype=dtype)
#     318
#     319         # Now we just make sure the order is respected, if any
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     273             else:
#     274                 data = _sanitize_array(data, index, dtype, copy,
# --> 275                                        raise_cast_failure=True)
#     276
#     277                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    4130         subarr = _try_cast(arr, False)
#    4131     else:
# -> 4132         subarr = _try_cast(data, False)
#    4133
#    4134     # scalar like, GH
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\series.py in _try_cast(arr, take_fast_path)
#    4042
#    4043         try:
# -> 4044             subarr = maybe_cast_to_datetime(arr, dtype)
#    4045             # Take care in creating object arrays (but iterators are not
#    4046             # supported):
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\dtypes\cast.py in maybe_cast_to_datetime(value, dtype, errors)
#    1086         elif not (is_array and not (issubclass(value.dtype.type, np.integer) or
#    1087                                     value.dtype == np.object_)):
# -> 1088             value = maybe_infer_to_datetimelike(value)
#    1089
#    1090     return value
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\dtypes\cast.py in maybe_infer_to_datetimelike(value, convert_dates)
#     885     if isinstance(value, (ABCDatetimeIndex, ABCPeriodIndex)):
#     886         return value
# --> 887     elif isinstance(value, ABCSeries):
#     888         if isinstance(value._values, ABCDatetimeIndex):
#     889             return value._values
#
# KeyboardInterrupt:

# %%
def select_date(x):
    """
    This function is used to select the payment dates in a time snapshot, where we need to exlude dates happening after the reportdate of that particular snapshot.
    It is meant to be used inside an 'apply' with axis=1 to be rowwise.
    """
    dates = x.payment_date
    last_item = int(x.tmp_dates_to_count)
    return dates[:last_item]

prefix = 'sshot_0_'
inst.loc[inst['sshot_0_'],'tmp_dates_to_count'] = inst.loc[inst['sshot_0_'],"payment_date"].apply(lambda x:sum(pd.Series(x)<ReportDate)) #this retrieve the index of the last payment snapshot to snapshot (it is a temp column)
inst.loc[inst['sshot_0_'],prefix+"payment_date"] = inst.loc[inst['sshot_0_'],["payment_date", "tmp_dates_to_count"]].apply(select_date, axis=1)

# %%
inst.columns
# Out:
# Index(['customer_id', 'customer_name_1', 'debtor_id', 'debtor_name_1',
#        'invoice_number', 'invoice_date', 'due_date', 'invoice_amount',
#        'purchase_amount', 'purchase_amount_open', 'discharge_type',
#        'discharge_amount', 'discharge_date', 'posting_date',
#        'transaction_type', 'document_stack_id', 'booking_text', 'input_date',
#        'creation_date', 'factoring_type', 'debt_collection_date',
#        'last_payment_date', 'reminder_date', 'test_feature_tested',
#        'test_characteristic_id', 'bill_id', 'cancellation_date', 'value_date',
#        'currency', 'purchase_examination', 'prosecution', 'deduction_amount',
#        'payment_amount', 'payment_date', 'document_status', 'uid', 'ttype',
#        'nrecords', 'ttypeset', 'discharge_loss', 'has_impairment1',
#        'has_impairment2', 'has_impairment3', 'is_pastdue90', 'is_pastdue180',
#        'has_prosecution', 'last_payment_amount', 'total_repayment',
#        'total_impairment', 'is_open', 'we_payment_share', 'has_purchase',
#        'has_deduction', 'is_due', 'sshot_0_', 'tmp_dates_to_count',
#        'sshot_0_payment_date'],
#       dtype='object')

# %%
inst[["payment_date", "tmp_dates_to_count"]].apply(select_date, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-2c5309d633cb> in <module>
# ----> 1 inst[["payment_date", "tmp_dates_to_count"]].apply(select_date, axis=1)
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~\Anaconda3\envs\bokeh_last\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-20-a1adfa712945> in select_date(x)
#       5     """
#       6     dates = x.payment_date
# ----> 7     last_item = int(x.tmp_dates_to_count)
#       8     return dates[:last_item]
#       9
#
# ValueError: ('cannot convert float NaN to integer', 'occurred at index 2932:79/233')

# %%
inst.loc[inst['sshot_0_'],["payment_date", "tmp_dates_to_count"]]
# Out:
#             payment_date  tmp_dates_to_count
# uid
# 2744:79/231   [NaT, NaT]                 0.0
# 2861:79/232   [NaT, NaT]                 0.0

# %%
inst['sshot_0_']
# Out:
# uid
# 2744:79/231             True
# 2861:79/232             True
# 2932:79/233            False
# 1472:489/688           False
# 2042:512/645           False
# 2998:79/234            False
# 3043:506/229           False
# 3098:79/235            False
# 1533:489/689           False
# 1603:527/651           False
# 1604:527/652           False
# 1623:489/690           False
# 2043:512/646           False
# 3348:79/236            False
# 3378:506/230           False
# 2044:512/647           False
# 3399:79/237            False
# 1748:489/691           False
# 2045:512/648           False
# 3541:79/238            False
# 1764:489/692           False
# 2046:512/649           False
# 1793:489/693           False
# 3627:79/239            False
# 1811:489/694           False
# 2047:512/650           False
# 3842:79/240            False
# 1894:489/695           False
# 1915:489/696           False
# 3938:79/241            False
#                        ...
# 71181:582154/55287     False
# 71182:582154/55288     False
# 2017-3638:102/47561    False
# 2017-3639:102/47562    False
# 2017-3640:102/47563    False
# 2017-3641:102/47564    False
# 2017-3642:102/47565    False
# 2017-3643:102/47566    False
# 2017-3616:29/47540     False
# 2017-3617:29/47541     False
# 2017-3618:29/47542     False
# 2017-3619:29/47543     False
# 2017-3620:29/47544     False
# 2017-3621:29/47545     False
# 2017-3623:29/47547     False
# 2017-3624:29/47548     False
# 2017-3625:29/47549     False
# 2017-3626:29/47550     False
# 2017-3627:29/47551     False
# 2017-3628:29/47552     False
# 2017-3629:29/47553     False
# 2017-3630:29/47554     False
# 2017-3631:29/47555     False
# 2017-3632:29/47556     False
# 2017-3633:29/47557     False
# 2017-3634:29/47558     False
# 2017-3635:29/47567     False
# 2017-3636:29/47559     False
# 2017-3637:29/47560     False
# 2017-3622:69/47546     False
# Name: sshot_0_, Length: 59820, dtype: bool

# %%
#this is a check cell
selnum=56
print(daterange[selnum])
selector = 'sshot_'+str(selnum)+'_'
inst[inst[selector]][[c for c in inst.columns if selector in c]+ \
                     ['invoice_date','payment_date','tmp_dates_to_count', 
                      'purchase_amount', 'has_purchase', 'due_date']].transpose()
# Out:
# 2018-03-31 00:00:00
# uid                                     2744:79/231          2861:79/232  \
# sshot_56_                                      True                 True
# sshot_56_payment_date                            []                   []
# sshot_56_payment_amount                          []                   []
# sshot_56_last_payment_amount                      0                    0
# sshot_56_last_payment_date                      NaT                  NaT
# sshot_56_total_repayment                          0                    0
# sshot_56_is_pastdue90                         False                False
# sshot_56_is_pastdue180                        False                False
# sshot_56_payment_date_mismatch                  NaN                  NaN
# sshot_56_is_open                              False                False
# sshot_56_we_payment_share                       NaN                  NaN
# sshot_56_is_due                               False                False
# invoice_date                    2013-07-23 00:00:00  2013-07-30 00:00:00
# payment_date                             [NaT, NaT]           [NaT, NaT]
# tmp_dates_to_count                                0                    0
# purchase_amount                                   0                    0
# has_purchase                                  False                False
# due_date                        2013-08-02 00:00:00  2013-08-09 00:00:00
#
# uid                                                            2932:79/233  \
# sshot_56_                                                             True
# sshot_56_payment_date           [2016-01-30 00:00:00, 2016-01-30 00:00:00]
# sshot_56_payment_amount                                   [1370.5, 1370.5]
# sshot_56_last_payment_amount                                        1370.5
# sshot_56_last_payment_date                             2016-01-30 00:00:00
# sshot_56_total_repayment                                            1370.5
# sshot_56_is_pastdue90                                                False
# sshot_56_is_pastdue180                                               False
# sshot_56_payment_date_mismatch                                         897
# sshot_56_is_open                                                     False
# sshot_56_we_payment_share                                                1
# sshot_56_is_due                                                      False
# invoice_date                                           2013-08-06 00:00:00
# payment_date                    [2016-01-30 00:00:00, 2016-01-30 00:00:00]
# tmp_dates_to_count                                                       2
# purchase_amount                                                          0
# has_purchase                                                         False
# due_date                                               2013-08-16 00:00:00
#
# uid                                    1472:489/688  \
# sshot_56_                                      True
# sshot_56_payment_date                            []
# sshot_56_payment_amount                          []
# sshot_56_last_payment_amount                      0
# sshot_56_last_payment_date                      NaT
# sshot_56_total_repayment                          0
# sshot_56_is_pastdue90                         False
# sshot_56_is_pastdue180                        False
# sshot_56_payment_date_mismatch                  NaN
# sshot_56_is_open                              False
# sshot_56_we_payment_share                       NaN
# sshot_56_is_due                               False
# invoice_date                    2013-08-13 00:00:00
# payment_date                             [NaT, NaT]
# tmp_dates_to_count                                0
# purchase_amount                                   0
# has_purchase                                  False
# due_date                        2013-08-23 00:00:00
#
# uid                                                                  2042:512/645  \
# sshot_56_                                                                    True
# sshot_56_payment_date           [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# sshot_56_payment_amount                          [164.35, 164.35, 164.35, 164.35]
# sshot_56_last_payment_amount                                               164.35
# sshot_56_last_payment_date                                    2016-01-30 00:00:00
# sshot_56_total_repayment                                                   164.35
# sshot_56_is_pastdue90                                                       False
# sshot_56_is_pastdue180                                                      False
# sshot_56_payment_date_mismatch                                                890
# sshot_56_is_open                                                            False
# sshot_56_we_payment_share                                                       1
# sshot_56_is_due                                                             False
# invoice_date                                                  2013-08-13 00:00:00
# payment_date                    [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# tmp_dates_to_count                                                              4
# purchase_amount                                                                 0
# has_purchase                                                                False
# due_date                                                      2013-08-23 00:00:00
#
# uid                                     2998:79/234  \
# sshot_56_                                      True
# sshot_56_payment_date                            []
# sshot_56_payment_amount                          []
# sshot_56_last_payment_amount                      0
# sshot_56_last_payment_date                      NaT
# sshot_56_total_repayment                          0
# sshot_56_is_pastdue90                         False
# sshot_56_is_pastdue180                        False
# sshot_56_payment_date_mismatch                  NaN
# sshot_56_is_open                              False
# sshot_56_we_payment_share                       NaN
# sshot_56_is_due                               False
# invoice_date                    2013-08-13 00:00:00
# payment_date                             [NaT, NaT]
# tmp_dates_to_count                                0
# purchase_amount                                   0
# has_purchase                                  False
# due_date                        2013-08-23 00:00:00
#
# uid                                                                  3043:506/229  \
# sshot_56_                                                                    True
# sshot_56_payment_date           [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# sshot_56_payment_amount                          [1119.0, 1119.0, 1119.0, 1119.0]
# sshot_56_last_payment_amount                                                 1119
# sshot_56_last_payment_date                                    2016-01-30 00:00:00
# sshot_56_total_repayment                                                     1119
# sshot_56_is_pastdue90                                                       False
# sshot_56_is_pastdue180                                                      False
# sshot_56_payment_date_mismatch                                                883
# sshot_56_is_open                                                            False
# sshot_56_we_payment_share                                                       1
# sshot_56_is_due                                                             False
# invoice_date                                                  2013-08-20 00:00:00
# payment_date                    [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# tmp_dates_to_count                                                              4
# purchase_amount                                                                 0
# has_purchase                                                                False
# due_date                                                      2013-08-30 00:00:00
#
# uid                                     3098:79/235         1533:489/689  \
# sshot_56_                                      True                 True
# sshot_56_payment_date                            []                   []
# sshot_56_payment_amount                          []                   []
# sshot_56_last_payment_amount                      0                    0
# sshot_56_last_payment_date                      NaT                  NaT
# sshot_56_total_repayment                          0                    0
# sshot_56_is_pastdue90                         False                False
# sshot_56_is_pastdue180                        False                False
# sshot_56_payment_date_mismatch                  NaN                  NaN
# sshot_56_is_open                              False                False
# sshot_56_we_payment_share                       NaN                  NaN
# sshot_56_is_due                               False                False
# invoice_date                    2013-08-20 00:00:00  2013-08-27 00:00:00
# payment_date                             [NaT, NaT]           [NaT, NaT]
# tmp_dates_to_count                                0                    0
# purchase_amount                                   0                    0
# has_purchase                                  False                False
# due_date                        2013-08-30 00:00:00  2013-09-06 00:00:00
#
# uid                                    1603:527/651  \
# sshot_56_                                      True
# sshot_56_payment_date                            []
# sshot_56_payment_amount                          []
# sshot_56_last_payment_amount                      0
# sshot_56_last_payment_date                      NaT
# sshot_56_total_repayment                          0
# sshot_56_is_pastdue90                         False
# sshot_56_is_pastdue180                        False
# sshot_56_payment_date_mismatch                  NaN
# sshot_56_is_open                              False
# sshot_56_we_payment_share                       NaN
# sshot_56_is_due                               False
# invoice_date                    2013-09-03 00:00:00
# payment_date                             [NaT, NaT]
# tmp_dates_to_count                                0
# purchase_amount                                   0
# has_purchase                                  False
# due_date                        2013-09-13 00:00:00
#
# uid                                                   ...                          \
# sshot_56_                                             ...
# sshot_56_payment_date                                 ...
# sshot_56_payment_amount                               ...
# sshot_56_last_payment_amount                          ...
# sshot_56_last_payment_date                            ...
# sshot_56_total_repayment                              ...
# sshot_56_is_pastdue90                                 ...
# sshot_56_is_pastdue180                                ...
# sshot_56_payment_date_mismatch                        ...
# sshot_56_is_open                                      ...
# sshot_56_we_payment_share                             ...
# sshot_56_is_due                                       ...
# invoice_date                                          ...
# payment_date                                          ...
# tmp_dates_to_count                                    ...
# purchase_amount                                       ...
# has_purchase                                          ...
# due_date                                              ...
#
# uid                                                                 3066:23/54992  \
# sshot_56_                                                                    True
# sshot_56_payment_date                                                          []
# sshot_56_payment_amount                                                        []
# sshot_56_last_payment_amount                                                    0
# sshot_56_last_payment_date                                                    NaT
# sshot_56_total_repayment                                                        0
# sshot_56_is_pastdue90                                                       False
# sshot_56_is_pastdue180                                                      False
# sshot_56_payment_date_mismatch                                                NaN
# sshot_56_is_open                                                             True
# sshot_56_we_payment_share                                                     NaN
# sshot_56_is_due                                                             False
# invoice_date                                                  2018-03-30 00:00:00
# payment_date                    [2018-07-02 00:00:00, 2018-07-02 00:00:00, 201...
# tmp_dates_to_count                                                              4
# purchase_amount                                                                 0
# has_purchase                                                                False
# due_date                                                      2018-04-29 00:00:00
#
# uid                                                          3081:29/55953  \
# sshot_56_                                                             True
# sshot_56_payment_date                                                   []
# sshot_56_payment_amount                                                 []
# sshot_56_last_payment_amount                                             0
# sshot_56_last_payment_date                                             NaT
# sshot_56_total_repayment                                                 0
# sshot_56_is_pastdue90                                                False
# sshot_56_is_pastdue180                                               False
# sshot_56_payment_date_mismatch                                         NaN
# sshot_56_is_open                                                      True
# sshot_56_we_payment_share                                              NaN
# sshot_56_is_due                                                      False
# invoice_date                                           2018-03-30 00:00:00
# payment_date                    [2018-04-13 00:00:00, 2018-04-13 00:00:00]
# tmp_dates_to_count                                                       2
# purchase_amount                                                     5774.7
# has_purchase                                                          True
# due_date                                               2018-04-29 00:00:00
#
# uid                                                          3071:30/54994  \
# sshot_56_                                                             True
# sshot_56_payment_date                                                   []
# sshot_56_payment_amount                                                 []
# sshot_56_last_payment_amount                                             0
# sshot_56_last_payment_date                                             NaT
# sshot_56_total_repayment                                                 0
# sshot_56_is_pastdue90                                                False
# sshot_56_is_pastdue180                                               False
# sshot_56_payment_date_mismatch                                         NaN
# sshot_56_is_open                                                      True
# sshot_56_we_payment_share                                              NaN
# sshot_56_is_due                                                      False
# invoice_date                                           2018-03-30 00:00:00
# payment_date                    [2018-04-25 00:00:00, 2018-04-25 00:00:00]
# tmp_dates_to_count                                                       2
# purchase_amount                                                     201.75
# has_purchase                                                          True
# due_date                                               2018-04-29 00:00:00
#
# uid                                                          3082:34/55001  \
# sshot_56_                                                             True
# sshot_56_payment_date                                                   []
# sshot_56_payment_amount                                                 []
# sshot_56_last_payment_amount                                             0
# sshot_56_last_payment_date                                             NaT
# sshot_56_total_repayment                                                 0
# sshot_56_is_pastdue90                                                False
# sshot_56_is_pastdue180                                               False
# sshot_56_payment_date_mismatch                                         NaN
# sshot_56_is_open                                                      True
# sshot_56_we_payment_share                                              NaN
# sshot_56_is_due                                                      False
# invoice_date                                           2018-03-30 00:00:00
# payment_date                    [2018-05-02 00:00:00, 2018-05-02 00:00:00]
# tmp_dates_to_count                                                       2
# purchase_amount                                                    4654.79
# has_purchase                                                          True
# due_date                                               2018-04-29 00:00:00
#
# uid                                                                 3077:35/54999  \
# sshot_56_                                                                    True
# sshot_56_payment_date                                                          []
# sshot_56_payment_amount                                                        []
# sshot_56_last_payment_amount                                                    0
# sshot_56_last_payment_date                                                    NaT
# sshot_56_total_repayment                                                        0
# sshot_56_is_pastdue90                                                       False
# sshot_56_is_pastdue180                                                      False
# sshot_56_payment_date_mismatch                                                NaN
# sshot_56_is_open                                                             True
# sshot_56_we_payment_share                                                     NaN
# sshot_56_is_due                                                             False
# invoice_date                                                  2018-03-30 00:00:00
# payment_date                    [2018-05-16 00:00:00, 2018-05-16 00:00:00, 201...
# tmp_dates_to_count                                                              3
# purchase_amount                                                            131.85
# has_purchase                                                                 True
# due_date                                                      2018-04-29 00:00:00
#
# uid                                                          3076:55/54998  \
# sshot_56_                                                             True
# sshot_56_payment_date                                                   []
# sshot_56_payment_amount                                                 []
# sshot_56_last_payment_amount                                             0
# sshot_56_last_payment_date                                             NaT
# sshot_56_total_repayment                                                 0
# sshot_56_is_pastdue90                                                False
# sshot_56_is_pastdue180                                               False
# sshot_56_payment_date_mismatch                                         NaN
# sshot_56_is_open                                                      True
# sshot_56_we_payment_share                                              NaN
# sshot_56_is_due                                                      False
# invoice_date                                           2018-03-30 00:00:00
# payment_date                    [2018-05-08 00:00:00, 2018-05-08 00:00:00]
# tmp_dates_to_count                                                       2
# purchase_amount                                                       66.6
# has_purchase                                                          True
# due_date                                               2018-04-29 00:00:00
#
# uid                                                                 3058:56/54988  \
# sshot_56_                                                                    True
# sshot_56_payment_date                                                          []
# sshot_56_payment_amount                                                        []
# sshot_56_last_payment_amount                                                    0
# sshot_56_last_payment_date                                                    NaT
# sshot_56_total_repayment                                                        0
# sshot_56_is_pastdue90                                                       False
# sshot_56_is_pastdue180                                                      False
# sshot_56_payment_date_mismatch                                                NaN
# sshot_56_is_open                                                             True
# sshot_56_we_payment_share                                                     NaN
# sshot_56_is_due                                                             False
# invoice_date                                                  2018-03-30 00:00:00
# payment_date                    [2018-08-24 00:00:00, 2018-08-24 00:00:00, 201...
# tmp_dates_to_count                                                              4
# purchase_amount                                                                 0
# has_purchase                                                                False
# due_date                                                      2018-04-29 00:00:00
#
# uid                                                                 3059:59/54989  \
# sshot_56_                                                                    True
# sshot_56_payment_date                                                          []
# sshot_56_payment_amount                                                        []
# sshot_56_last_payment_amount                                                    0
# sshot_56_last_payment_date                                                    NaT
# sshot_56_total_repayment                                                        0
# sshot_56_is_pastdue90                                                       False
# sshot_56_is_pastdue180                                                      False
# sshot_56_payment_date_mismatch                                                NaN
# sshot_56_is_open                                                             True
# sshot_56_we_payment_share                                                     NaN
# sshot_56_is_due                                                             False
# invoice_date                                                  2018-03-30 00:00:00
# payment_date                    [2018-05-09 00:00:00, 2018-05-09 00:00:00, 201...
# tmp_dates_to_count                                                              3
# purchase_amount                                                              1874
# has_purchase                                                                 True
# due_date                                                      2018-04-29 00:00:00
#
# uid                                                           3070:7/54993  \
# sshot_56_                                                             True
# sshot_56_payment_date                                                   []
# sshot_56_payment_amount                                                 []
# sshot_56_last_payment_amount                                             0
# sshot_56_last_payment_date                                             NaT
# sshot_56_total_repayment                                                 0
# sshot_56_is_pastdue90                                                False
# sshot_56_is_pastdue180                                               False
# sshot_56_payment_date_mismatch                                         NaN
# sshot_56_is_open                                                      True
# sshot_56_we_payment_share                                              NaN
# sshot_56_is_due                                                      False
# invoice_date                                           2018-03-30 00:00:00
# payment_date                    [2018-04-26 00:00:00, 2018-04-26 00:00:00]
# tmp_dates_to_count                                                       2
# purchase_amount                                                     336.15
# has_purchase                                                          True
# due_date                                               2018-04-29 00:00:00
#
# uid                                                                 3072:71/54995
# sshot_56_                                                                    True
# sshot_56_payment_date                                                          []
# sshot_56_payment_amount                                                        []
# sshot_56_last_payment_amount                                                    0
# sshot_56_last_payment_date                                                    NaT
# sshot_56_total_repayment                                                        0
# sshot_56_is_pastdue90                                                       False
# sshot_56_is_pastdue180                                                      False
# sshot_56_payment_date_mismatch                                                NaN
# sshot_56_is_open                                                             True
# sshot_56_we_payment_share                                                     NaN
# sshot_56_is_due                                                             False
# invoice_date                                                  2018-03-30 00:00:00
# payment_date                    [2018-05-31 00:00:00, 2018-05-31 00:00:00, 201...
# tmp_dates_to_count                                                              4
# purchase_amount                                                             967.6
# has_purchase                                                                 True
# due_date                                                      2018-04-29 00:00:00
#
# [18 rows x 44295 columns]

# %%
inst.columns
# Out:
# Index(['customer_id', 'customer_name_1', 'debtor_id', 'debtor_name_1',
#        'invoice_number', 'invoice_date', 'due_date', 'invoice_amount',
#        'purchase_amount', 'purchase_amount_open',
#        ...
#        'sshot_0_cd_pd_mismatch_mean', 'sshot_0_cd_pd_mismatch_std',
#        'sshot_1_cd_lent_c', 'sshot_1_cd_repaid_c', 'sshot_1_cd_pastdue90_c',
#        'sshot_1_cd_pastdue180_c', 'sshot_1_cd_trend_a',
#        'sshot_1_cd_we_payment_share', 'sshot_1_cd_pd_mismatch_mean',
#        'sshot_1_cd_pd_mismatch_std'],
#       dtype='object', length=1047)

# %%
#this much more slow
#Adding buyer/seller pair attributes for a certain snapshot

for selnum in range(0,8): #test#(len(daterange)):
    prefix = "cd_" #stands for customer/debtor
    g_cb = inst[inst['sshot_'+str(selnum)+'_']].groupby(["customer_name_1", "debtor_name_1"])
    decision_date_col = "value_date"


    print("Adding buyer/seller pair attributes to snapshot {}...".format(selnum))
    selector = 'sshot_'+str(selnum)+'_'
    for (customer, debtor), igroup in g_cb:
        #for each instrument in this group, already sorted by invoice_date
        for idx, (id, ii) in enumerate(igroup.iterrows()):
            add_node_stats(inst, igroup, idx, id, ii, decision_date_col, prefix, prefix_read=selector)

#Adding the ratio columns for the previously calculated stats
#cl = [prefix+"repaid_", prefix+"impaired1_", prefix+"impaired2_", 
#      prefix+"pastdue90_", prefix+"pastdue180_"]
#for c in cl:
#    inst[c+"r"] = inst[c+"c"] / inst[prefix+"lent_c"]
# Out:
# Adding buyer/seller pair attributes to snapshot 0...
# Adding buyer/seller pair attributes to snapshot 1...
# Adding buyer/seller pair attributes to snapshot 2...
# Adding buyer/seller pair attributes to snapshot 3...
# Adding buyer/seller pair attributes to snapshot 4...
# Adding buyer/seller pair attributes to snapshot 5...
# Adding buyer/seller pair attributes to snapshot 6...
# Adding buyer/seller pair attributes to snapshot 7...

# %%
inst[inst['sshot_7_']].transpose()
# Out:
# uid                                                         2744:79/231  \
# customer_id                                                     2004008
# customer_name_1                                        jobs united GmbH
# debtor_id                                                            79
# debtor_name_1                                           Quadroni Linard
# invoice_number                                                     2744
# invoice_date                                        2013-07-23 00:00:00
# due_date                                            2013-08-02 00:00:00
# invoice_amount                                                    913.7
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                  913.7
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     8
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2013-09-09 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             231
# cancellation_date                                                   NaT
# value_date                                          2013-08-02 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                                0
# sshot_4_cd_pastdue180_c                                               0
# sshot_4_cd_trend_a                                                    0
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                     0
# sshot_5_cd_repaid_c                                                   0
# sshot_5_cd_pastdue90_c                                                0
# sshot_5_cd_pastdue180_c                                               0
# sshot_5_cd_trend_a                                                    0
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                     0
# sshot_6_cd_repaid_c                                                   0
# sshot_6_cd_pastdue90_c                                                0
# sshot_6_cd_pastdue180_c                                               0
# sshot_6_cd_trend_a                                                    0
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                     0
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                                    0
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                                         2861:79/232  \
# customer_id                                                     2004008
# customer_name_1                                        jobs united GmbH
# debtor_id                                                            79
# debtor_name_1                                           Quadroni Linard
# invoice_number                                                     2861
# invoice_date                                        2013-07-30 00:00:00
# due_date                                            2013-08-09 00:00:00
# invoice_amount                                                  2233.45
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                2233.45
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     8
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2013-09-23 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             232
# cancellation_date                                                   NaT
# value_date                                          2013-08-09 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                                0
# sshot_4_cd_pastdue180_c                                               0
# sshot_4_cd_trend_a                                                    0
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                     1
# sshot_5_cd_repaid_c                                                   0
# sshot_5_cd_pastdue90_c                                                0
# sshot_5_cd_pastdue180_c                                               0
# sshot_5_cd_trend_a                                                    0
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                     1
# sshot_6_cd_repaid_c                                                   0
# sshot_6_cd_pastdue90_c                                                0
# sshot_6_cd_pastdue180_c                                               0
# sshot_6_cd_trend_a                                                    0
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                     1
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                                    0
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                                                2932:79/233  \
# customer_id                                                            2004008
# customer_name_1                                               jobs united GmbH
# debtor_id                                                                   79
# debtor_name_1                                                  Quadroni Linard
# invoice_number                                                            2932
# invoice_date                                               2013-08-06 00:00:00
# due_date                                                   2013-08-16 00:00:00
# invoice_amount                                                          1370.5
# purchase_amount                                                              0
# purchase_amount_open                                                         0
# discharge_type                                                             NaN
# discharge_amount                                                           NaN
# discharge_date                                                             NaT
# posting_date                        [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type             [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                            8
# booking_text                                                         Migration
# input_date                                                 2016-01-30 00:00:00
# creation_date                                              2016-01-30 00:00:00
# factoring_type                                                    Full Service
# debt_collection_date                                                       NaT
# last_payment_date                                          2016-01-30 00:00:00
# reminder_date                                              2013-09-23 00:00:00
# test_feature_tested                                                        NaN
# test_characteristic_id                                                     NaN
# bill_id                                                                    233
# cancellation_date                                                          NaT
# value_date                                                 2013-08-16 00:00:00
# currency                                                     Schweizer Franken
# purchase_examination                                                        14
# ...                                                                        ...
# sshot_4_cd_pastdue90_c                                                       0
# sshot_4_cd_pastdue180_c                                                      0
# sshot_4_cd_trend_a                                                      7.1852
# sshot_4_cd_we_payment_share                                                NaN
# sshot_4_cd_pd_mismatch_mean                                                NaN
# sshot_4_cd_pd_mismatch_std                                                 NaN
# sshot_5_cd_lent_c                                                            2
# sshot_5_cd_repaid_c                                                          0
# sshot_5_cd_pastdue90_c                                                       0
# sshot_5_cd_pastdue180_c                                                      0
# sshot_5_cd_trend_a                                                      7.1852
# sshot_5_cd_we_payment_share                                                NaN
# sshot_5_cd_pd_mismatch_mean                                                NaN
# sshot_5_cd_pd_mismatch_std                                                 NaN
# sshot_6_cd_lent_c                                                            2
# sshot_6_cd_repaid_c                                                          0
# sshot_6_cd_pastdue90_c                                                       0
# sshot_6_cd_pastdue180_c                                                      0
# sshot_6_cd_trend_a                                                      7.1852
# sshot_6_cd_we_payment_share                                                NaN
# sshot_6_cd_pd_mismatch_mean                                                NaN
# sshot_6_cd_pd_mismatch_std                                                 NaN
# sshot_7_cd_lent_c                                                            2
# sshot_7_cd_repaid_c                                                          0
# sshot_7_cd_pastdue90_c                                                       0
# sshot_7_cd_pastdue180_c                                                      0
# sshot_7_cd_trend_a                                                      7.1852
# sshot_7_cd_we_payment_share                                                NaN
# sshot_7_cd_pd_mismatch_mean                                                NaN
# sshot_7_cd_pd_mismatch_std                                                 NaN
#
# uid                                                        1472:489/688  \
# customer_id                                                     2004009
# customer_name_1                                        PM Personal GmbH
# debtor_id                                                           489
# debtor_name_1                                           Style Interiors
# invoice_number                                                     1472
# invoice_date                                        2013-08-13 00:00:00
# due_date                                            2013-08-23 00:00:00
# invoice_amount                                                   9195.1
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                 9195.1
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     9
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2013-10-21 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             688
# cancellation_date                                                   NaT
# value_date                                          2013-08-23 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                                0
# sshot_4_cd_pastdue180_c                                               0
# sshot_4_cd_trend_a                                                    0
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                     0
# sshot_5_cd_repaid_c                                                   0
# sshot_5_cd_pastdue90_c                                                0
# sshot_5_cd_pastdue180_c                                               0
# sshot_5_cd_trend_a                                                    0
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                     0
# sshot_6_cd_repaid_c                                                   0
# sshot_6_cd_pastdue90_c                                                0
# sshot_6_cd_pastdue180_c                                               0
# sshot_6_cd_trend_a                                                    0
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                     0
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                                    0
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                                               2042:512/645  \
# customer_id                                                            2004009
# customer_name_1                                               PM Personal GmbH
# debtor_id                                                                  512
# debtor_name_1                                                Elektropartner AG
# invoice_number                                                            2042
# invoice_date                                               2013-08-13 00:00:00
# due_date                                                   2013-08-23 00:00:00
# invoice_amount                                                          4594.6
# purchase_amount                                                              0
# purchase_amount_open                                                         0
# discharge_type                                                           Kunde
# discharge_amount                                                       4430.25
# discharge_date                                             2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00, 201...
# transaction_type             [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                            9
# booking_text                                                         Migration
# input_date                                                 2016-01-30 00:00:00
# creation_date                                              2016-01-30 00:00:00
# factoring_type                                                    Full Service
# debt_collection_date                                                       NaT
# last_payment_date                                          2016-01-30 00:00:00
# reminder_date                                              2013-12-16 00:00:00
# test_feature_tested                                                        NaN
# test_characteristic_id                                                     NaN
# bill_id                                                                    645
# cancellation_date                                                          NaT
# value_date                                                 2013-08-23 00:00:00
# currency                                                     Schweizer Franken
# purchase_examination                                                        14
# ...                                                                        ...
# sshot_4_cd_pastdue90_c                                                       0
# sshot_4_cd_pastdue180_c                                                      0
# sshot_4_cd_trend_a                                                           0
# sshot_4_cd_we_payment_share                                                NaN
# sshot_4_cd_pd_mismatch_mean                                                NaN
# sshot_4_cd_pd_mismatch_std                                                 NaN
# sshot_5_cd_lent_c                                                            0
# sshot_5_cd_repaid_c                                                          0
# sshot_5_cd_pastdue90_c                                                       0
# sshot_5_cd_pastdue180_c                                                      0
# sshot_5_cd_trend_a                                                           0
# sshot_5_cd_we_payment_share                                                NaN
# sshot_5_cd_pd_mismatch_mean                                                NaN
# sshot_5_cd_pd_mismatch_std                                                 NaN
# sshot_6_cd_lent_c                                                            0
# sshot_6_cd_repaid_c                                                          0
# sshot_6_cd_pastdue90_c                                                       0
# sshot_6_cd_pastdue180_c                                                      0
# sshot_6_cd_trend_a                                                           0
# sshot_6_cd_we_payment_share                                                NaN
# sshot_6_cd_pd_mismatch_mean                                                NaN
# sshot_6_cd_pd_mismatch_std                                                 NaN
# sshot_7_cd_lent_c                                                            0
# sshot_7_cd_repaid_c                                                          0
# sshot_7_cd_pastdue90_c                                                       0
# sshot_7_cd_pastdue180_c                                                      0
# sshot_7_cd_trend_a                                                           0
# sshot_7_cd_we_payment_share                                                NaN
# sshot_7_cd_pd_mismatch_mean                                                NaN
# sshot_7_cd_pd_mismatch_std                                                 NaN
#
# uid                                                         2998:79/234  \
# customer_id                                                     2004008
# customer_name_1                                        jobs united GmbH
# debtor_id                                                            79
# debtor_name_1                                           Quadroni Linard
# invoice_number                                                     2998
# invoice_date                                        2013-08-13 00:00:00
# due_date                                            2013-08-23 00:00:00
# invoice_amount                                                  2233.45
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                2233.45
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     8
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2013-09-23 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             234
# cancellation_date                                                   NaT
# value_date                                          2013-08-23 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                                0
# sshot_4_cd_pastdue180_c                                               0
# sshot_4_cd_trend_a                                               5.4311
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                     3
# sshot_5_cd_repaid_c                                                   0
# sshot_5_cd_pastdue90_c                                                0
# sshot_5_cd_pastdue180_c                                               0
# sshot_5_cd_trend_a                                               5.4311
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                     3
# sshot_6_cd_repaid_c                                                   0
# sshot_6_cd_pastdue90_c                                                0
# sshot_6_cd_pastdue180_c                                               0
# sshot_6_cd_trend_a                                               5.4311
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                     3
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                               5.4311
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                                               3043:506/229  \
# customer_id                                                            2004008
# customer_name_1                                               jobs united GmbH
# debtor_id                                                                  506
# debtor_name_1                                                 Elektro DOM GmbH
# invoice_number                                                            3043
# invoice_date                                               2013-08-20 00:00:00
# due_date                                                   2013-08-30 00:00:00
# invoice_amount                                                          1880.8
# purchase_amount                                                              0
# purchase_amount_open                                                         0
# discharge_type                                                           Kunde
# discharge_amount                                                         761.8
# discharge_date                                             2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-01-30 00:00:00, 201...
# transaction_type             [Purchase invoice, Subsequent assignment of th...
# document_stack_id                                                            8
# booking_text                                                         Migration
# input_date                                                 2016-01-30 00:00:00
# creation_date                                              2016-01-30 00:00:00
# factoring_type                                                    Full Service
# debt_collection_date                                                       NaT
# last_payment_date                                          2016-01-30 00:00:00
# reminder_date                                              2013-10-21 00:00:00
# test_feature_tested                                                        NaN
# test_characteristic_id                                                     NaN
# bill_id                                                                    229
# cancellation_date                                                          NaT
# value_date                                                 2013-08-30 00:00:00
# currency                                                     Schweizer Franken
# purchase_examination                                                        14
# ...                                                                        ...
# sshot_4_cd_pastdue90_c                                                       0
# sshot_4_cd_pastdue180_c                                                      0
# sshot_4_cd_trend_a                                                           0
# sshot_4_cd_we_payment_share                                                NaN
# sshot_4_cd_pd_mismatch_mean                                                NaN
# sshot_4_cd_pd_mismatch_std                                                 NaN
# sshot_5_cd_lent_c                                                            0
# sshot_5_cd_repaid_c                                                          0
# sshot_5_cd_pastdue90_c                                                       0
# sshot_5_cd_pastdue180_c                                                      0
# sshot_5_cd_trend_a                                                           0
# sshot_5_cd_we_payment_share                                                NaN
# sshot_5_cd_pd_mismatch_mean                                                NaN
# sshot_5_cd_pd_mismatch_std                                                 NaN
# sshot_6_cd_lent_c                                                            0
# sshot_6_cd_repaid_c                                                          0
# sshot_6_cd_pastdue90_c                                                       0
# sshot_6_cd_pastdue180_c                                                      0
# sshot_6_cd_trend_a                                                           0
# sshot_6_cd_we_payment_share                                                NaN
# sshot_6_cd_pd_mismatch_mean                                                NaN
# sshot_6_cd_pd_mismatch_std                                                 NaN
# sshot_7_cd_lent_c                                                            0
# sshot_7_cd_repaid_c                                                          0
# sshot_7_cd_pastdue90_c                                                       0
# sshot_7_cd_pastdue180_c                                                      0
# sshot_7_cd_trend_a                                                           0
# sshot_7_cd_we_payment_share                                                NaN
# sshot_7_cd_pd_mismatch_mean                                                NaN
# sshot_7_cd_pd_mismatch_std                                                 NaN
#
# uid                                                         3098:79/235  \
# customer_id                                                     2004008
# customer_name_1                                        jobs united GmbH
# debtor_id                                                            79
# debtor_name_1                                           Quadroni Linard
# invoice_number                                                     3098
# invoice_date                                        2013-08-20 00:00:00
# due_date                                            2013-08-30 00:00:00
# invoice_amount                                                   1370.5
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                 1370.5
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     8
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2013-09-23 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             235
# cancellation_date                                                   NaT
# value_date                                          2013-08-30 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                                0
# sshot_4_cd_pastdue180_c                                               0
# sshot_4_cd_trend_a                                              5.73538
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                     4
# sshot_5_cd_repaid_c                                                   0
# sshot_5_cd_pastdue90_c                                                0
# sshot_5_cd_pastdue180_c                                               0
# sshot_5_cd_trend_a                                              5.73538
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                     4
# sshot_6_cd_repaid_c                                                   0
# sshot_6_cd_pastdue90_c                                                0
# sshot_6_cd_pastdue180_c                                               0
# sshot_6_cd_trend_a                                              5.73538
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                     4
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                              5.73538
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                                        1533:489/689  \
# customer_id                                                     2004009
# customer_name_1                                        PM Personal GmbH
# debtor_id                                                           489
# debtor_name_1                                           Style Interiors
# invoice_number                                                     1533
# invoice_date                                        2013-08-27 00:00:00
# due_date                                            2013-09-06 00:00:00
# invoice_amount                                                   2589.3
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                 2589.3
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     9
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2013-04-11 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             689
# cancellation_date                                                   NaT
# value_date                                          2013-09-06 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                                0
# sshot_4_cd_pastdue180_c                                               0
# sshot_4_cd_trend_a                                                    0
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                     1
# sshot_5_cd_repaid_c                                                   0
# sshot_5_cd_pastdue90_c                                                0
# sshot_5_cd_pastdue180_c                                               0
# sshot_5_cd_trend_a                                                    0
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                     1
# sshot_6_cd_repaid_c                                                   0
# sshot_6_cd_pastdue90_c                                                0
# sshot_6_cd_pastdue180_c                                               0
# sshot_6_cd_trend_a                                                    0
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                     1
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                                    0
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                                        1603:527/651  \
# customer_id                                                     2004009
# customer_name_1                                        PM Personal GmbH
# debtor_id                                                           527
# debtor_name_1                                        Ilanz Keramik GmbH
# invoice_number                                                     1603
# invoice_date                                        2013-09-03 00:00:00
# due_date                                            2013-09-13 00:00:00
# invoice_amount                                                   1066.8
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                 1066.8
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     9
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2013-04-11 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             651
# cancellation_date                                                   NaT
# value_date                                          2013-09-13 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                                0
# sshot_4_cd_pastdue180_c                                               0
# sshot_4_cd_trend_a                                                    0
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                     0
# sshot_5_cd_repaid_c                                                   0
# sshot_5_cd_pastdue90_c                                                0
# sshot_5_cd_pastdue180_c                                               0
# sshot_5_cd_trend_a                                                    0
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                     0
# sshot_6_cd_repaid_c                                                   0
# sshot_6_cd_pastdue90_c                                                0
# sshot_6_cd_pastdue180_c                                               0
# sshot_6_cd_trend_a                                                    0
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                     0
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                                    0
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                             ...                      \
# customer_id                                     ...
# ...
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                   NaN
# sshot_5_cd_repaid_c                                                 NaN
# sshot_5_cd_pastdue90_c                                              NaN
# sshot_5_cd_pastdue180_c                                             NaN
# sshot_5_cd_trend_a                                                  NaN
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                   NaN
# sshot_6_cd_repaid_c                                                 NaN
# sshot_6_cd_pastdue90_c                                              NaN
# sshot_6_cd_pastdue180_c                                             NaN
# sshot_6_cd_trend_a                                                  NaN
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                    44
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                             -3.39864
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                                        5562:381/294  \
# customer_id                                                     2004008
# customer_name_1                                        jobs united GmbH
# debtor_id                                                           381
# debtor_name_1                                         Trigon Elektro AG
# invoice_number                                                     5562
# invoice_date                                        2014-02-25 00:00:00
# due_date                                            2014-03-07 00:00:00
# invoice_amount                                                  2864.15
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                2864.15
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     8
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2014-02-06 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             294
# cancellation_date                                                   NaT
# value_date                                          2014-03-07 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                              NaN
# sshot_4_cd_pastdue180_c                                             NaN
# sshot_4_cd_trend_a                                                  NaN
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                   NaN
# sshot_5_cd_repaid_c                                                 NaN
# sshot_5_cd_pastdue90_c                                              NaN
# sshot_5_cd_pastdue180_c                                             NaN
# sshot_5_cd_trend_a                                                  NaN
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                   NaN
# sshot_6_cd_repaid_c                                                 NaN
# sshot_6_cd_pastdue90_c                                              NaN
# sshot_6_cd_pastdue180_c                                             NaN
# sshot_6_cd_trend_a                                                  NaN
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                    45
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                              -3.2458
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                                        5568:381/295  \
# customer_id                                                     2004008
# customer_name_1                                        jobs united GmbH
# debtor_id                                                           381
# debtor_name_1                                         Trigon Elektro AG
# invoice_number                                                     5568
# invoice_date                                        2014-02-25 00:00:00
# due_date                                            2014-03-07 00:00:00
# invoice_amount                                                   768.95
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                 768.95
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     8
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2014-02-06 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             295
# cancellation_date                                                   NaT
# value_date                                          2014-03-07 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                              NaN
# sshot_4_cd_pastdue180_c                                             NaN
# sshot_4_cd_trend_a                                                  NaN
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                   NaN
# sshot_5_cd_repaid_c                                                 NaN
# sshot_5_cd_pastdue90_c                                              NaN
# sshot_5_cd_pastdue180_c                                             NaN
# sshot_5_cd_trend_a                                                  NaN
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                   NaN
# sshot_6_cd_repaid_c                                                 NaN
# sshot_6_cd_pastdue90_c                                              NaN
# sshot_6_cd_pastdue180_c                                             NaN
# sshot_6_cd_trend_a                                                  NaN
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                    46
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                             -3.11567
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# uid                                                        5569:381/296
# customer_id                                                     2004008
# customer_name_1                                        jobs united GmbH
# debtor_id                                                           381
# debtor_name_1                                         Trigon Elektro AG
# invoice_number                                                     5569
# invoice_date                                        2014-02-25 00:00:00
# due_date                                            2014-03-07 00:00:00
# invoice_amount                                                    722.5
# purchase_amount                                                       0
# purchase_amount_open                                                  0
# discharge_type                                                    Kunde
# discharge_amount                                                  722.5
# discharge_date                                      2016-03-22 00:00:00
# posting_date                 [2016-01-30 00:00:00, 2016-03-22 00:00:00]
# transaction_type              [Purchase invoice, Cancel invoice client]
# document_stack_id                                                     8
# booking_text                                                  Migration
# input_date                                          2016-01-30 00:00:00
# creation_date                                       2016-01-30 00:00:00
# factoring_type                                             Full Service
# debt_collection_date                                                NaT
# last_payment_date                                                   NaT
# reminder_date                                       2014-02-06 00:00:00
# test_feature_tested                                                 NaN
# test_characteristic_id                                              NaN
# bill_id                                                             296
# cancellation_date                                                   NaT
# value_date                                          2014-03-07 00:00:00
# currency                                              Schweizer Franken
# purchase_examination                                                 14
# ...                                                                 ...
# sshot_4_cd_pastdue90_c                                              NaN
# sshot_4_cd_pastdue180_c                                             NaN
# sshot_4_cd_trend_a                                                  NaN
# sshot_4_cd_we_payment_share                                         NaN
# sshot_4_cd_pd_mismatch_mean                                         NaN
# sshot_4_cd_pd_mismatch_std                                          NaN
# sshot_5_cd_lent_c                                                   NaN
# sshot_5_cd_repaid_c                                                 NaN
# sshot_5_cd_pastdue90_c                                              NaN
# sshot_5_cd_pastdue180_c                                             NaN
# sshot_5_cd_trend_a                                                  NaN
# sshot_5_cd_we_payment_share                                         NaN
# sshot_5_cd_pd_mismatch_mean                                         NaN
# sshot_5_cd_pd_mismatch_std                                          NaN
# sshot_6_cd_lent_c                                                   NaN
# sshot_6_cd_repaid_c                                                 NaN
# sshot_6_cd_pastdue90_c                                              NaN
# sshot_6_cd_pastdue180_c                                             NaN
# sshot_6_cd_trend_a                                                  NaN
# sshot_6_cd_we_payment_share                                         NaN
# sshot_6_cd_pd_mismatch_mean                                         NaN
# sshot_6_cd_pd_mismatch_std                                          NaN
# sshot_7_cd_lent_c                                                    47
# sshot_7_cd_repaid_c                                                   0
# sshot_7_cd_pastdue90_c                                                0
# sshot_7_cd_pastdue180_c                                               0
# sshot_7_cd_trend_a                                             -3.23123
# sshot_7_cd_we_payment_share                                         NaN
# sshot_7_cd_pd_mismatch_mean                                         NaN
# sshot_7_cd_pd_mismatch_std                                          NaN
#
# [1095 rows x 87 columns]
